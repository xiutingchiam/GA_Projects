# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 3: Web APIs & NLP

# %% [markdown]
# # Table of Contents:
# - [Import Libraries](#Import-Libraries)
# - [Functions](#Functions)
# - [Import Data](#Import-Data)
# - [Modeling](#Modeling)
# - [Model Evaluation](#Model-Evaluation)
# - [Conclusion](#Conclusion)
# - [Future Improvement](#Future-Improvement)

# %% [markdown]
# # Import Libraries

# %%
# Basics
import numpy as np
import pandas as pd
import time

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import scipy.stats as stats

# %matplotlib inline
plt.style.use('ggplot')

# Vectorizing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Optimizing hyperparameters
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# Modeling and model evaluation
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import f1_score

# Modeling - KNeigbors Classifier
from sklearn.neighbors import KNeighborsClassifier

# Modelling - Logistic Regression
from sklearn.linear_model import LogisticRegression

# Modelling - Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ---

# %% [markdown]
# # Functions

# %%
# Function to calculate and display classification metrics
def class_metrics(model, X, y):
    # Generate predictions
    y_pred = model.best_estimator_.predict(X)
    y_pred_prob = model.best_estimator_.predict_proba(X_test)[:,1]
    # confusion matrix and unravel
    tn, fp, fn, tp = confusion_matrix(y, y_pred).ravel()
    
    # Accuracy
    accuracy = round((tp+tn)/len(y), 2)
    print(f'Accuracy: {accuracy}')
    # Sensitivity
    sensitivity = round(tp/(tp+fn), 2)
    print(f'Sensitivity: {sensitivity}')
    # Specificity
    specificity = round(tn/(tn+fp), 2)
    print(f'Specificity: {specificity}')
    # Precision
    precision = round(tp/(tp+fp), 2)
    print(f'Precision: {precision}')
    # F1-Score
    f1score = round(f1_score(y, y_pred, average='binary'), 2)
    print(f'F1: {f1score}')
    # AUC Score
    auc = round(roc_auc_score(y, y_pred_prob), 2)
    print(f'AUC: {auc}')
    
    # Return y_pred, y_pred_prob, and auc score for plotting roc curve
    return y_pred, y_pred_prob, accuracy, sensitivity, specificity, precision, f1score, auc

# %%
def confusion_matrix_plot(y_test, y_pred, title):
    cf_matrix = confusion_matrix(y_test, y_pred)
    group_names = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    hm = sns.heatmap(cf_matrix, annot = labels, fmt = '', cmap = 'Blues')
    hm.set_title(title)

# %%
# Plot ROC curve
def plot_roc_auc(y_pred_prob, auc, model_title, tranformation_title):
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    # Plot ROC curve
    plt.plot([0, 1], [0, 1], 'k--', label = 'baseline')
    plt.plot(fpr, tpr, label = f'AUC = {auc}', color = 'teal')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{model_title}, {tranformation_title} (ROC Curve)')
    plt.legend()
    plt.show()

# %%
# Display all observations that have been classified wrongly
def display_misclassification(y_pred):
    pd.options.display.max_colwidth = 120
    pd.options.display.max_rows = 150
    combined = list(zip(X_test, y_test, y_pred))
    misclassification = pd.DataFrame(columns = ["text", "actual", "predicted"]) 
    for text, actual, prediction in combined:
        if actual != prediction:
            row = pd.DataFrame({'text':[text], 'actual':[actual], 'predicted':[prediction]})
            misclassification = misclassification.append(row, ignore_index = True)
            
    for i in ['actual', 'predicted']:
        misclassification[i] = misclassification[i].map({0: 'surfing', 1: 'scubadiving'})
        
    return misclassification

# %% [markdown]
# ---

# %% [markdown]
# # Import Data

# %%
# Import cleaned subreddits
df = pd.read_csv("../data/subreddits_cleaned2.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  diving                                               text
# 0           0       1  go tomorrow open water cert doc told swimmer e...
# 1           1       1                                        swimmer ear
# 2           2       1                                    big hungry fish
# 3           3       1  dusk blue heron bridge rivera beach fl usa x20...
# 4           4       1     mark v inspire helmet lamp decoration building

# %%
# drop 'Unnamed: 0' column
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.isna().sum()
# Out:
# diving     0
# text      23
# dtype: int64

# %%
df[df['text'].isna()]
# Out:
#       diving text
# 35         1  NaN
# 41         1  NaN
# 91         1  NaN
# 101        1  NaN
# 177        1  NaN
# 253        1  NaN
# 590        1  NaN
# 677        1  NaN
# 706        1  NaN
# 708        1  NaN
# 1338       1  NaN
# 2072       0  NaN
# 2204       0  NaN
# 2274       0  NaN
# 2311       0  NaN
# 2568       0  NaN
# 2569       0  NaN
# 2662       0  NaN
# 2932       0  NaN
# 2947       0  NaN
# 2948       0  NaN
# 3197       0  NaN
# 3538       0  NaN

# %%
df = df.dropna().reset_index(drop = True)

# %%
df[df['text'].isna()]
# Out:
# Empty DataFrame
# Columns: [diving, text]
# Index: []

# %%
df.isna().sum()
# Out:
# diving    0
# text      0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Modeling
# To find out which is the best machine learning model for our classification problem, we will be building 8 different types of models for comparison purposes. These models will be built upon 4 different types of supervised machine learning classification algorithms, including Logistic Regression, Random Forest Classifier, KNeignbors Classifier and Naives Bayes, and 2 different word vectorizers, CountVectorizer and Tfidf Vectorizer.
#
# Hyperparameter tuning using GridSearchCV will be done to determine the optimal hyperparameters, in order to extract the maximum performance out of each machine learning model.
#
#
#
# ## Machine Learning Algorithms Used:
# ### Logistic Regression
# Logistic regression is a calculation used to predict a binary outcome: either something happens, or does not. This can be exhibited as Yes/No, Pass/Fail, Alive/Dead, and in the case of this project, whether the a subreddit text belongs to scubadiving or not. Independent variables are analyzed to determine the binary outcome with the results falling into one of two categories. The independent variables can be categorical or numeric, whereas the dependent/target variable is always categorical.
#
# ### Random Forest Classifier
# Random forest Classifier is a classification Algorithm Random forest, like its name implies, consists of a large number of individual decision trees that operate as an ensemble. The key principle underlying the random forest approach comprises the construction of many “simple” decision trees in the training stage and the majority vote (mode) across them in the classification stage. Among other benefits, this voting strategy has the effect of correcting for the undesirable property of decision trees to overfit training data
#
# ### KNeighbors Classifier
# K-nearest neighbors (k-NN) is a pattern recognition algorithm that uses training datasets to find the k closest relatives in future examples. When k-NN is used in classification, you calculate to place data within the category of its nearest neighbor. If k = 1, then it would be placed in the class nearest 1. K is classified by a plurality poll of its neighbors. [(source)](https://monkeylearn.com/blog/classification-algorithms/)
#
# ## Vectorizers Used:
# ### Count Vectorizer
# Count vectorizer is a basic vectorizer which takes each word token from the dataset and turns it into a feature. As a whole it converts a collection of text documents to a sparse matrix of token counts.
#
# ### Tfidf Vectorizer
# TF-IDF (term frequency–inverse document frequency) vectorizes words by taking into account the frequency of a word in a given text and the frequency between text. The importance increases proportionally to the number of times a word appears in the text but is offset by the frequency of the word in the corpus. If a word is common in most text, the word is suppressed and rare words are given more influence showing they are highly specific for a particular document.

# %% [markdown]
# ## Train Test Split

# %%
X = df['text']
y = df['diving']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state=42)

# %% [markdown]
# ---

# %% [markdown]
# ## Baseline Model
# ### Zero Rate Classifier
# For a two outcome model, it will be right more often than not by just going with the odds. Selecting the majority group (ZeroR classifier) is insightful as a baseline. In this case, we have a balanced classification problem, hence we will just use 0.50 as the baseline accuracy score.

# %%
df["diving"].value_counts(normalize = True)
# Out:
# 0    0.501287
# 1    0.498713
# Name: diving, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Logistic Regression - CountVectorizer
# ### Model with best scores after hypertuning:

# %%
# Set up pipeline
lr_cvec_pipe = Pipeline([('cvec', CountVectorizer()), 
                         ('lr', LogisticRegression(random_state = 42))])

# Hyperparameters tuning
lr_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
                  'cvec__max_features' : [5500, 6000, 6500, 7000],
                  'cvec__ngram_range': [(1,1), (1,2)],
                  'lr__C': np.linspace(0.7, 2, 10),
                  'lr__solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
                  'lr__penalty' : ['l1', 'l2', 'elasticnet', None]}

# GridSearchCV
lr_cvec_gs = GridSearchCV(lr_cvec_pipe, 
                          param_grid = lr_cvec_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = -1) 

start_time = time.time()

# Fit model
lr_cvec_gs.fit(X_train, y_train)

# Show metrics and best parameters
print(lr_cvec_gs.best_params_)
lc_y_pred, lc_y_pred_prob, lc_accuracy, lc_sensitivity, lc_specificity, lc_precision, lc_f1score, lc_auc = class_metrics(
    lr_cvec_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 1600 candidates, totalling 8000 fits
# C:\Users\xiuti\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81090992 ...        nan        nan        nan]
#   warnings.warn(
# {'cvec__max_features': 6500, 'cvec__ngram_range': (1, 2), 'lr__C': 1.2777777777777777, 'lr__penalty': 'l2', 'lr__solver': 'newton-cg'}
# Accuracy: 0.85
# Sensitivity: 0.83
# Specificity: 0.88
# Precision: 0.88
# F1: 0.85
# AUC: 0.93
# Elapsed time: 136.7 seconds

# %% [markdown]
# #### Hyperparameters Setting Example 1:
#
# lr_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
#                   'cvec__max_features' : [6000, 6500, 7000],
#                   'cvec__ngram_range': [(1,1), (1,2)],
#                   'lr__C': np.linspace(1, 2, 10),
#                   'lr__solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
#                   'lr__penalty' : ['l1', 'l2', 'elasticnet', None]}
#
# Fitting 5 folds for each of 1200 candidates, totalling 6000 fits
#
# {'cvec__max_features': 6000, 'cvec__ngram_range': (1, 2), 'lr__C': 1.0, 'lr__penalty': 'l2', 'lr__solver': 'newton-cg'}
#
# Accuracy: 0.85
# Sensitivity: 0.83
# Specificity: 0.88
# Precision: 0.87
# F1: 0.85
# AUC: 0.93
#
# Elapsed time: 177.18 seconds

# %% [markdown]
# #### Note:
# 'cvec__max_df' : [.9, .95]' and 'cvec__min_df' : [0.5, 1]' were removed from the params as they did not make a difference to the score metrics.

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, lc_y_pred, 'Logistic Regression (CountVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(lc_y_pred_prob, lc_auc, 'Logistic Regression', 'CountVectorizer')

# %% [markdown]
# With a AUC score of 0.93, this model is quite a good model as it has a decently strong ability to measure separability between the the two subreddit categories.

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(lc_y_pred)
# Out:
#                                                                                                                         text  \
# 0                                                                                                  diy trilobite line cutter
# 1                                                                                                   activity best complement
# 2                                                          mentawaii island 2019 5 u perfect poo stance love go back someday
# 3    shark life australia change dramatically summer winter completely different shark population reside many offshore ro...
# 4                                                                             nitrox incident analysis one seriously injured
# 5    place north shore hi everyone new hop see knew good place north shore massachusetts look place gloucester rockport a...
# 6    impromptu bali trip bring rent wife surprised ticket bali may trip isnt dedicate trip ill try much possible wonder g...
# 7                                                                                                                 day corona
# 8                                                                                     joe rogan experience 1749 shane dorian
# 9             present boyfriend planning go indonesia covid ever end 4 month get divemaster good present trip thanks advance
# 10                                                       nantucket mv live south eastern go mv summer time havent heard much
# 11                                                                                                   learnt deadly art pearl
# 12                                                                                           shark kill dolphin brings shore
# 13                                                                                            bought sherwood regulator know
# 14                                      first time first time tomorrow stoke real experience advice guidance appreciate help
# 15                                                                                                 ever wonder look like top
# 16                                     52 spending weekend wendover friday saturday interested meeting dinner drink let know
# 17   fin recommendation cold warm water hi recently get back love recommendation fin look last long time get back lot pla...
# 18                                                     human really consume 300 million ton antarctic krill per year extinct
# 19   help nice question hello everyone question isnt simple think someone might able help love dream somewhat person work...
# 20                                                                                                         love around gilis
# 21                                                                                                             shadeonme com
# 22                                                                                                                   ya need
# 23   ireland planning trip ireland scotland january plan first leg trip ireland go around whole country want know good sp...
# 24                                                                                          tell damage look way close thing
# 25   guy store get giant 9 foot trouble store hang ceiling put wall store face belly beginner stoke get new deal saw last...
# 26                                                                                                      appropriate response
# 27                                                                                                                  question
# 28                                                                                                               swimmer ear
# 29                                                  big challenge interested learn appreciate information someone know learn
# 30                                                                                                         ocean cueva pargo
# 31   men v woman wetsuits main difference men woman wetsuits guess little space around bust could woman typically use men...
# 32                                                                                                                   brownie
# 33                                                                                                               life change
# 34                                                                                                         high fashion boot
# 35   temple adventure v urban nomad adventure dsd pondicherry hello planning go discover visit pondicherry dec 2021 pleas...
# 36                                                                                             different kind farmer apparel
# 37                                                                                                                sum nicely
# 38                                                                                               beginner friend keep buying
# 39                                                                                     throwaway extreme first world problem
# 40                                                                                          scoobslens insta like stuff hehe
# 41                                                                                     man ginnie spring high spring florida
# 42   bahamas head nassau area mid jan wonder nassau paradise island area know eleuthera island spending day try gauge wor...
# 43   december 16 super typhoon rai category 5 direct hit tiny island siargao first island struck typhoon hurricane since ...
# 44                                                                                                    runnin d3000s go wrong
# 45   havent already take photo scan card wallet steal weekend cert try get replacement card padi website aud 79 00 outrag...
# 46                                                                                                                       irl
# 47   wetsuit bcd recs hi look recommendation new wetsuit bcd current one hand never actually shop either thing live tiny ...
# 48               use twin jet max snorkel hello bought twin jet max change plan family decide go snorkel could still use fin
# 49   fiji atm arrive denarau oz none tour boat seem run mainland break yet since island open ive found local take youre n...
# 39       surfing  scubadiving
# 40       surfing  scubadiving
# 41   scubadiving      surfing
# 42       surfing  scubadiving
# 43       surfing  scubadiving
# 44       surfing  scubadiving
# 45   scubadiving      surfing
# 46   scubadiving      surfing
# 47   scubadiving      surfing
# 48   scubadiving      surfing
# 49       surfing  scubadiving
# 50       surfing  scubadiving
# 51   scubadiving      surfing
# 52   scubadiving      surfing
# 53   scubadiving      surfing
# 54       surfing  scubadiving
# 55   scubadiving      surfing
# 56   scubadiving      surfing
# 57       surfing  scubadiving
# 58   scubadiving      surfing
# 59       surfing  scubadiving
# 60       surfing  scubadiving
# 61   scubadiving      surfing
# 62   scubadiving      surfing
# 63       surfing  scubadiving
# 64       surfing  scubadiving
# 65       surfing  scubadiving
# 66   scubadiving      surfing
# 67       surfing  scubadiving
# 68   scubadiving      surfing
# 69       surfing  scubadiving
# 70   scubadiving      surfing
# 71   scubadiving      surfing
# 72       surfing  scubadiving
# 73       surfing  scubadiving
# 74   scubadiving      surfing
# 75   scubadiving      surfing
# 76   scubadiving      surfing
# 77       surfing  scubadiving
# 78       surfing  scubadiving
# 79       surfing  scubadiving
# 80   scubadiving      surfing
# 81   scubadiving      surfing
# 82   scubadiving      surfing
# 83       surfing  scubadiving
# 84       surfing  scubadiving
# 85   scubadiving      surfing
# 86   scubadiving      surfing
# 87       surfing  scubadiving
# 88   scubadiving      surfing
# 89   scubadiving      surfing
# 90   scubadiving      surfing
# 91   scubadiving      surfing
# 92       surfing  scubadiving
# 93   scubadiving      surfing
# 94   scubadiving      surfing
# 95       surfing  scubadiving
# 96       surfing  scubadiving
# 97   scubadiving      surfing
# 98       surfing  scubadiving
# 99       surfing  scubadiving
# 100      surfing  scubadiving
# 101  scubadiving      surfing
# 102  scubadiving      surfing
# 103  scubadiving      surfing
# 104  scubadiving      surfing
# 105      surfing  scubadiving
# 106  scubadiving      surfing
# 107  scubadiving      surfing
# 108      surfing  scubadiving
# 109  scubadiving      surfing
# 110      surfing  scubadiving
# 111      surfing  scubadiving
# 112  scubadiving      surfing
# 113      surfing  scubadiving
# 114  scubadiving      surfing
# 115  scubadiving      surfing
# 116  scubadiving      surfing
# 117  scubadiving      surfing
# 118      surfing  scubadiving
# 119  scubadiving      surfing
# 120  scubadiving      surfing
# 121      surfing  scubadiving
# 122  scubadiving      surfing
# 123      surfing  scubadiving
# 124  scubadiving      surfing
# 125  scubadiving      surfing
# 126  scubadiving      surfing
# 127  scubadiving      surfing
# 128      surfing  scubadiving
# 129      surfing  scubadiving
# 130  scubadiving      surfing
# 131  scubadiving      surfing
# 132  scubadiving      surfing
# 133  scubadiving      surfing
# 134  scubadiving      surfing
# 135  scubadiving      surfing
# 136  scubadiving      surfing
# 137      surfing  scubadiving
# 138  scubadiving      surfing
# 139      surfing  scubadiving
# 140      surfing  scubadiving

# %% [markdown]
# ### Word Coefficients

# %% [markdown]
# ##### Words with Positive Coefficients

# %%
coef_names = lr_cvec_gs.best_estimator_.named_steps.cvec.get_feature_names()
coef_vals = np.exp(lr_cvec_gs.best_estimator_.named_steps['lr'].coef_[0])

coef_df = pd.DataFrame ({
    'word' : coef_names,
    'coef' : coef_vals}).set_index('word')

coef_df.reindex(coef_df['coef'].sort_values(ascending=False).index)[:20]
# Out:
#                  coef
# word
# underwater  14.351916
# bali         9.354177
# octopus      7.313505
# sea          6.341867
# reef         5.596135
# wreck        5.563314
# bonaire      5.424057
# turtle       5.300797
# equipment    5.281240
# gear         5.217498
# snorkel      5.117194
# com          5.007110
# certify      4.978786
# cuttlefish   4.909955
# concept      4.808242
# computer     4.731256
# open         4.597014
# nudibranch   4.506090
# course       4.249890
# cozumel      4.249578

# %% [markdown]
# ##### Words with Negative Coefficients

# %%
coef_df.reindex(coef_df['coef'].sort_values(ascending=True).index)[:20]
# Out:
#                coef
# word
# surfer     0.082949
# surfboard  0.109669
# ride       0.196154
# kook       0.196699
# paddle     0.214631
# repair     0.222918
# winter     0.228199
# session    0.233042
# morning    0.259905
# quiver     0.260956
# shape      0.261041
# surfed     0.279536
# custom     0.283507
# rain       0.295331
# yesterday  0.301478
# barrel     0.302117
# use        0.302186
# break      0.311177
# etiquette  0.315725
# nazar      0.322299

# %% [markdown]
# ---

# %% [markdown]
# # Logistic Regression - TfidfVectorizer

# %%
# Set up pipleline
lr_tfidf_pipe = Pipeline([('tfidf',TfidfVectorizer()),
                          ('lr',LogisticRegression(solver = 'liblinear'))])

# Pipe parameters
lr_tfidf_params = {'tfidf__max_features': [6000, 6500, 7000],
                   'tfidf__ngram_range': [(1,1), (1,2)],
                   'lr__penalty': ['l1', 'l2'],
                   'lr__C': np.linspace(4, 7, 20)}

start_time = time.time()

# tfidf grid search
# Instantiate GridSearchCV.
lr_tfidf_gs = GridSearchCV(lr_tfidf_pipe, 
                           lr_tfidf_params, 
                           cv = 5,
                           verbose = 1,
                           n_jobs = 7) 

# Fit grid search
lr_tfidf_gs.fit(X_train, y_train)

# Show best params, metrics and unpack function return values into variables
print(lr_tfidf_gs.best_params_)
lt_y_pred, lt_y_pred_prob, lt_accuracy, lt_sensitivity, lt_specificity, lt_precision, lt_f1score, lt_auc = class_metrics(
    lr_tfidf_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# {'lr__C': 5.105263157894736, 'lr__penalty': 'l2', 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 2)}
# Accuracy: 0.87
# Sensitivity: 0.84
# Specificity: 0.91
# Precision: 0.9
# F1: 0.87
# AUC: 0.95
# Elapsed time: 45.92 seconds

# %% [markdown]
# #### Hyperparameters setting example 1:
# lr_tfidf_params = {'tfidf__max_features': [5500, 6000, 6500],
#                    'tfidf__ngram_range': [(1,1), (1,2)],
#                    'lr__penalty' : ['l1', 'l2', 'elasticnet'],
#                    'lr__C': np.linspace(1, 5, 5),
#                    'lr__solver':['newton-cg', 'lbfgs', 'liblinear']}
#
#
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
#
# {'lr__C': 5.0, 'lr__penalty': 'l2', 'lr__solver': 'lbfgs', 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 2)}
#
# Accuracy: 0.87
# Sensitivity: 0.84
# Specificity: 0.91
# Precision: 0.9
# F1: 0.87
# AUC: 0.95
#
# Elapsed time: 28.55 seconds
#
#
# #### Hyperparameters setting example 2:
# lr_tfidf_params = {'tfidf__max_features': [5000, 5500, 6000],
#                    'tfidf__ngram_range': [(1,1), (1,2)],
#                    'lr__penalty': ['l1', 'l2'],
#                    'lr__C': np.linspace(0.01, 1.5, 20)}
#
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
#
# {'lr__C': 1.0, 'lr__penalty': 'l2', 'tfidf__max_features': 5500, 'tfidf__ngram_range': (1, 1)}
#
# Accuracy: 0.87
# Sensitivity: 0.84
# Specificity: 0.91
# Precision: 0.9
# F1: 0.87
# AUC: 0.94
#
# Elapsed time: 42.75 seconds
#
#
# #### Note:
# From the above example, it can be seen that adding 'tfidf__max_df' : [0.1, 0.4, 0.7]' and 'tfidf__min_df' : [0.7, 1, 1.2]' to the parameters did not help to improve the model, hence it was removed so that the model can run more efficiently.

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, lt_y_pred, 'Logistic Regression (TfidfVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(lt_y_pred_prob, lt_auc, 'Logistic Regression', 'TfidfVectorizer')

# %% [markdown]
# With a AUC score of 0.95, this model has a better AUC score that the Logistic Regression Model and Count Vectorizer, which means that this is a good model with good measure of separability between the two subreddit categories.

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(lt_y_pred)
# Out:
#                                                                                                                         text  \
# 0                                                                                                  diy trilobite line cutter
# 1                                                                                                     jacob well texas could
# 2                                                                                                   activity best complement
# 3                                                          mentawaii island 2019 5 u perfect poo stance love go back someday
# 4    shark life australia change dramatically summer winter completely different shark population reside many offshore ro...
# 5                                                                             nitrox incident analysis one seriously injured
# 6    place north shore hi everyone new hop see knew good place north shore massachusetts look place gloucester rockport a...
# 7    impromptu bali trip bring rent wife surprised ticket bali may trip isnt dedicate trip ill try much possible wonder g...
# 8                                                                                                                 day corona
# 9                                                                                     joe rogan experience 1749 shane dorian
# 10            present boyfriend planning go indonesia covid ever end 4 month get divemaster good present trip thanks advance
# 11                                                       nantucket mv live south eastern go mv summer time havent heard much
# 12                                                                                                   learnt deadly art pearl
# 13                                                                                           shark kill dolphin brings shore
# 14                                     52 spending weekend wendover friday saturday interested meeting dinner drink let know
# 15   fin recommendation cold warm water hi recently get back love recommendation fin look last long time get back lot pla...
# 16                                                     human really consume 300 million ton antarctic krill per year extinct
# 17   try hand make weight since two son get multiply expense three look cost weight severe sticker shock decide try make ...
# 18   help nice question hello everyone question isnt simple think someone might able help love dream somewhat person work...
# 19                                                                                                         love around gilis
# 20                                                                                                             shadeonme com
# 21                                                                                                                   ya need
# 22   ireland planning trip ireland scotland january plan first leg trip ireland go around whole country want know good sp...
# 23                                                                                          tell damage look way close thing
# 24                                                                                                                  question
# 25                                                  big challenge interested learn appreciate information someone know learn
# 26   men v woman wetsuits main difference men woman wetsuits guess little space around bust could woman typically use men...
# 27   scubadiving      surfing
# 28   scubadiving      surfing
# 29       surfing  scubadiving
# 30       surfing  scubadiving
# 31       surfing  scubadiving
# 32       surfing  scubadiving
# 33   scubadiving      surfing
# 34       surfing  scubadiving
# 35       surfing  scubadiving
# 36       surfing  scubadiving
# 37   scubadiving      surfing
# 38   scubadiving      surfing
# 39   scubadiving      surfing
# 40   scubadiving      surfing
# 41       surfing  scubadiving
# 42   scubadiving      surfing
# 43   scubadiving      surfing
# 44   scubadiving      surfing
# 45       surfing  scubadiving
# 46   scubadiving      surfing
# 47   scubadiving      surfing
# 48   scubadiving      surfing
# 49       surfing  scubadiving
# 50       surfing  scubadiving
# 51   scubadiving      surfing
# 52       surfing  scubadiving
# 53   scubadiving      surfing
# 54   scubadiving      surfing
# 55       surfing  scubadiving
# 56   scubadiving      surfing
# 57   scubadiving      surfing
# 58       surfing  scubadiving
# 59   scubadiving      surfing
# 60   scubadiving      surfing
# 61   scubadiving      surfing
# 62   scubadiving      surfing
# 63       surfing  scubadiving
# 64       surfing  scubadiving
# 65       surfing  scubadiving
# 66   scubadiving      surfing
# 67   scubadiving      surfing
# 68       surfing  scubadiving
# 69       surfing  scubadiving
# 70   scubadiving      surfing
# 71   scubadiving      surfing
# 72   scubadiving      surfing
# 73   scubadiving      surfing
# 74   scubadiving      surfing
# 75   scubadiving      surfing
# 76   scubadiving      surfing
# 77       surfing  scubadiving
# 78   scubadiving      surfing
# 79   scubadiving      surfing
# 80       surfing  scubadiving
# 81       surfing  scubadiving
# 82   scubadiving      surfing
# 83       surfing  scubadiving
# 84       surfing  scubadiving
# 85   scubadiving      surfing
# 86       surfing  scubadiving
# 87   scubadiving      surfing
# 88   scubadiving      surfing
# 89   scubadiving      surfing
# 90       surfing  scubadiving
# 91   scubadiving      surfing
# 92       surfing  scubadiving
# 93       surfing  scubadiving
# 94       surfing  scubadiving
# 95   scubadiving      surfing
# 96   scubadiving      surfing
# 97   scubadiving      surfing
# 98   scubadiving      surfing
# 99   scubadiving      surfing
# 100  scubadiving      surfing
# 101  scubadiving      surfing
# 102  scubadiving      surfing
# 103  scubadiving      surfing
# 104      surfing  scubadiving
# 105  scubadiving      surfing
# 106      surfing  scubadiving
# 107  scubadiving      surfing
# 108  scubadiving      surfing
# 109  scubadiving      surfing
# 110  scubadiving      surfing
# 111  scubadiving      surfing
# 112      surfing  scubadiving
# 113      surfing  scubadiving
# 114      surfing  scubadiving
# 115  scubadiving      surfing
# 116  scubadiving      surfing
# 117  scubadiving      surfing
# 118  scubadiving      surfing
# 119  scubadiving      surfing
# 120  scubadiving      surfing
# 121  scubadiving      surfing
# 122  scubadiving      surfing
# 123      surfing  scubadiving
# 124      surfing  scubadiving
# 125      surfing  scubadiving

# %%
coef_names = lr_tfidf_gs.best_estimator_.named_steps['tfidf'].get_feature_names()
coef_vals = lr_tfidf_gs.best_estimator_.named_steps['lr'].coef_[0]

coef_df = pd.DataFrame ({
    'word' : coef_names,
    'coef' : coef_vals}).set_index('word')

coef_df.reindex(coef_df['coef'].sort_values(ascending=False).index)[:20]
# Out:
#                    coef
# word
# underwater     6.630013
# bali           4.714728
# sea            4.356657
# open           4.267845
# gear           4.127601
# certify        4.074857
# computer       3.964749
# reef           3.873575
# equipment      3.862796
# course         3.761237
# octopus        3.728063
# certification  3.642339
# padi           3.603478
# mask           3.599225
# snorkel        3.460913
# com            3.425256
# wreck          3.374158
# island         3.325003
# turtle         3.277600
# bonaire        3.177694

# %%
coef_df.reindex(coef_df['coef'].sort_values(ascending = True).index)[:20]
# Out:
#                coef
# word
# surfer    -6.248414
# surfboard -5.216310
# kook      -3.927988
# ride      -3.704780
# repair    -3.679268
# paddle    -3.669844
# session   -3.296608
# winter    -3.269509
# shape     -3.231808
# surfed    -3.086244
# break     -2.996529
# swell     -2.981087
# morning   -2.870150
# use       -2.845665
# custom    -2.678052
# rain      -2.668920
# barrel    -2.580733
# quiver    -2.578556
# rid       -2.554317
# beach     -2.507196

# %% [markdown]
# ---

# %% [markdown]
# # Random Forest - CountVectorization

# %%
# Set up pipeline
rf_cvec_pipe = Pipeline([('cvec', CountVectorizer()), 
                         ('rf', RandomForestClassifier(random_state = 42))])

# Hyperparameters tuning
rf_cvec_params = {'cvec__max_features': [6000, 6500, 7000],
                  'cvec__ngram_range': [(1,1), (1,2)],
                  'rf__n_estimators' : [1000, 1100, 1200],
                  'rf__max_depth': [1, 2, 3]}

# GridSearchCV
rf_cvec_gs = GridSearchCV(rf_cvec_pipe, 
                          param_grid = rf_cvec_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = 7) 

start_time = time.time()

# Fit model
rf_cvec_gs.fit(X_train, y_train)

# Show best params, metrics and unpack values into variables
print(rf_cvec_gs.best_params_)
rc_y_pred, rc_y_pred_prob, rc_accuracy, rc_sensitivity, rc_specificity, rc_precision, rc_f1score, rc_auc = class_metrics(
    rf_cvec_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# {'cvec__max_features': 6500, 'cvec__ngram_range': (1, 2), 'rf__max_depth': 2, 'rf__n_estimators': 1100}
# Accuracy: 0.8
# Sensitivity: 0.82
# Specificity: 0.77
# Precision: 0.78
# F1: 0.8
# AUC: 0.9
# Elapsed time: 51.36 seconds

# %% [markdown]
# #### Hyperparameters setting 1:
# rf_cvec_params = {'cvec__max_features': [5500, 6000, 6500],
#                   'cvec__ngram_range': [(1,1), (1,2)],
#                   'rf__n_estimators' : [1000, 1100, 1200],
#                   'rf__max_depth': [4, 5, 6]}
#
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# {'cvec__max_features': 6500, 'cvec__ngram_range': (1, 2), 'rf__max_depth': 4, 'rf__n_estimators': 1000}
#
# Accuracy: 0.79
# Sensitivity: 0.85
# Specificity: 0.73
# Precision: 0.76
# F1: 0.8
# AUC: 0.9
#
# Elapsed time: 158.37 seconds

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, rc_y_pred, 'Random Forest (CountVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(rc_y_pred_prob, rc_auc, 'Random Forest', 'CountVectorizer')

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(rc_y_pred)
# Out:
#                                                                                                                         text  \
# 0    logo contest oceanic geo 2 0 computer atomic aquatic z2 regulator help run 2nd large group facebook uncensored weve ...
# 1                                                                                       fibreglass weave visible second hand
# 2                                                                                                  diy trilobite line cutter
# 3                                                                                                                crowd party
# 4                                                                                                     jacob well texas could
# ..                                                                                                                       ...
# 194                                                                                                                  morning
# 195                                                                         think ecological effect spearfishing sustainable
# 196                                                                                                              evo seaside
# 197  think take first class 2 instructor student instructor say student instructor could completely wrong title try becom...
# 198                                                                                                       ok one wild enough
#
#           actual    predicted
# 0    scubadiving      surfing
# 1        surfing  scubadiving
# 2    scubadiving      surfing
# 3        surfing  scubadiving
# 4    scubadiving      surfing
# ..           ...          ...
# 194  scubadiving      surfing
# 195  scubadiving      surfing
# 196      surfing  scubadiving
# 197  scubadiving      surfing
# 198      surfing  scubadiving
#
# [199 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Random Forest - TfidfVectorizer

# %%
# Set up pipeline
rf_tfidf_pipe = Pipeline([('tfidf',TfidfVectorizer()),
                         ('rf', RandomForestClassifier(random_state = 42))])

# Hyperparameters tuning
rf_tfidf_params = {'tfidf__max_features': [6500, 7000, 7500],
                   'tfidf__ngram_range': [(1,1), (1,2), (2,2)],
                   'rf__n_estimators' : [1000, 1200, 1400],
                   'rf__max_depth': np.arange(36, 45, 2)}

# GridSearchCV
rf_tfidf_gs = GridSearchCV(rf_tfidf_pipe, 
                          param_grid = rf_tfidf_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = -1) 

start_time = time.time()

# Fit model
rf_tfidf_gs.fit(X_train, y_train)

# Show metrics and best parameters
print(rf_tfidf_gs.best_params_)
rt_y_pred, rt_y_pred_prob, rt_accuracy, rt_sensitivity, rt_specificity, rt_precision, rt_f1score, rt_auc = class_metrics(
    rf_tfidf_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# {'rf__max_depth': 40, 'rf__n_estimators': 1200, 'tfidf__max_features': 7000, 'tfidf__ngram_range': (1, 1)}
# Accuracy: 0.83
# Sensitivity: 0.84
# Specificity: 0.82
# Precision: 0.82
# F1: 0.83
# AUC: 0.92
# Elapsed time: 247.5 seconds

# %% [markdown]
# #### Hyperparameters setting example 1:
# rf_tfidf_params = {'tfidf__max_features': [6200, 6500, 7000],
#                    'tfidf__ngram_range': [(1,1), (1,2)],
#                    'rf__n_estimators' : [600, 800, 1000],
#                    'rf__max_depth': [7, 9, 11]}
#
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# {'rf__max_depth': 11, 'rf__n_estimators': 800, 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 2)}
#
# Accuracy: 0.8
# Sensitivity: 0.83
# Specificity: 0.77
# Precision: 0.79
# F1: 0.81
# AUC: 0.9
#
# Elapsed time: 55.74 seconds
#
#
# #### Hyperparameters setting example 2:
# rf_tfidf_params = {'tfidf__max_features': [6000, 6500, 7000],
#                    'tfidf__ngram_range': [(1,1), (1,2)],
#                    'rf__n_estimators' : [600, 800, 1000],
#                    'rf__max_depth': np.arange(18, 31, 2)}
#
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
#
# {'rf__max_depth': 28, 'rf__n_estimators': 1000, 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 1)}
#
# Accuracy: 0.82
# Sensitivity: 0.85
# Specificity: 0.8
# Precision: 0.81
# F1: 0.83
# AUC: 0.91
#
# Elapsed time: 141.92 seconds
#
# #### Hyperparameters setting example 3:
# rf_tfidf_params = {'tfidf__max_features': [7000, 7500, 8000],
#                    'tfidf__ngram_range': [(1,1), (1,2), (2,2)],
#                    'rf__n_estimators' : [1000, 1200, 1400],
#                    'rf__max_depth': np.arange(30, 39, 2)}
#
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
#
# {'rf__max_depth': 38, 'rf__n_estimators': 1200, 'tfidf__max_features': 7000, 'tfidf__ngram_range': (1, 1)}
#
# Accuracy: 0.83
# Sensitivity: 0.84
# Specificity: 0.82
# Precision: 0.82
# F1: 0.83
# AUC: 0.92
#
# Elapsed time: 247.35 seconds

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, rt_y_pred, 'Random Forest (TfidfVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(rt_y_pred_prob, rt_auc, 'Random Forest', 'TfidfVectorizer')

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(rt_y_pred)
# Out:
#                                                                                                                         text  \
# 0                                                                                                  diy trilobite line cutter
# 1                                                                                                     jacob well texas could
# 2                                                                                                               get advanced
# 3                                                                                                   activity best complement
# 4                                                          mentawaii island 2019 5 u perfect poo stance love go back someday
# ..                                                                                                                       ...
# 160                                                                                                              evo seaside
# 161                                                                                         weight help determine feel water
# 162  think take first class 2 instructor student instructor say student instructor could completely wrong title try becom...
# 163                                                                              go hong kong give much description possible
# 164                                                                                       look affordable spot work remotely
#
#           actual    predicted
# 0    scubadiving      surfing
# 1    scubadiving      surfing
# 2    scubadiving      surfing
# 3        surfing  scubadiving
# 4        surfing  scubadiving
# ..           ...          ...
# 160      surfing  scubadiving
# 161      surfing  scubadiving
# 162  scubadiving      surfing
# 163  scubadiving      surfing
# 164      surfing  scubadiving
#
# [165 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# # KNN Model - CountVectorizer

# %%
# Set up pipeline
knn_cvec_pipe = Pipeline([('cvec', CountVectorizer()), 
                         ('knn', KNeighborsClassifier())])

# Hyperparameters tuning
knn_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
                   'cvec__max_features' : [6500, 7000, 7500],
                   'cvec__ngram_range': [(1,1), (1,2)],
                   'knn__p': [1, 2],
                   'knn__weights' : ['uniform', 'distance'],
                   'knn__metric': ['minkowski', 'euclidean'],
                   'knn__n_neighbors': np.arange(1, 7, 2)}

# GridSearchCV
knn_cvec_gs = GridSearchCV(knn_cvec_pipe, 
                          param_grid = knn_cvec_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = -1) 

start_time = time.time()

# Fit model
knn_cvec_gs.fit(X_train, y_train)

# Show metrics and best parameters
print(knn_cvec_gs.best_params_)
kc_y_pred, kc_y_pred_prob, kc_accuracy, kc_sensitivity, kc_specificity, kc_precision, kc_f1score, kc_auc = class_metrics(
    knn_cvec_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# {'cvec__max_features': 7000, 'cvec__ngram_range': (1, 1), 'knn__metric': 'minkowski', 'knn__n_neighbors': 3, 'knn__p': 2, 'knn__weights': 'distance'}
# Accuracy: 0.71
# Sensitivity: 0.59
# Specificity: 0.82
# Precision: 0.77
# F1: 0.67
# AUC: 0.78
# Elapsed time: 13.79 seconds

# %% [markdown]
# #### Hyperparameters setting example 1:
# knn_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
#                    'cvec__max_features' : [5000, 6000, 7000],
#                    'cvec__ngram_range': [(1,1), (1,2)],
#                    'knn__p': [1, 2],
#                    'knn__weights' : ['uniform', 'distance'],
#                    'knn__metric': ['minkowski', 'euclidean'],
#                    'knn__n_neighbors': np.arange(5, 10, 1)}
#
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
#
# {'cvec__max_features': 7000, 'cvec__ngram_range': (1, 1), 'knn__metric': 'minkowski', 'knn__n_neighbors': 6, 'knn__p': 2, 'knn__weights': 'distance'}
#
# Accuracy: 0.7
# Sensitivity: 0.53
# Specificity: 0.87
# Precision: 0.8
# F1: 0.64
# AUC: 0.79
#
# Elapsed time: 26.8 seconds
#
# #### Hyperparameters setting example 2:
# knn_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
#                    'cvec__max_features' : [6000, 6500, 7000],
#                    'cvec__ngram_range': [(1,1), (1,2)],
#                    'knn__p': [1, 2],
#                    'knn__weights' : ['uniform', 'distance'],
#                    'knn__metric': ['minkowski', 'euclidean'],
#                    'knn__n_neighbors': np.arange(1, 10, 2)}
#
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
#
# {'cvec__max_features': 7000, 'cvec__ngram_range': (1, 1), 'knn__metric': 'minkowski', 'knn__n_neighbors': 3, 'knn__p': 2, 'knn__weights': 'distance'}
#
# Accuracy: 0.71
# Sensitivity: 0.59
# Specificity: 0.82
# Precision: 0.77
# F1: 0.67
# AUC: 0.78
#
# Elapsed time: 22.31 seconds

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, kc_y_pred, 'KNN (CountVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(kc_y_pred_prob, kc_auc, 'KNN', 'CountVectorizer')

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(kc_y_pred)
# Out:
#                                                                                                                         text  \
# 0    write contemptuous comment wanker video show cut 2 people proceeds steal zero skill guy told post clip since love ju...
# 1    dickhead surfer make learn almost impossible begin mostly post vent also get feedback ive consistently year socal fe...
# 2    impression baleal camp late learner adult recently return trip maui take number lesson first time great time live an...
# 3                                                                                                  diy trilobite line cutter
# 4                                                                                                 progress storm look advice
# ..                                                                                                                       ...
# 280                                                                              go hong kong give much description possible
# 281                                                                 southern right whale teach swim calf coast quintay chile
# 282                                                                                                       ok one wild enough
# 283                             couldnt pas 70 shortboard inflatable actually work great pleasantly surprised well storm lol
# 284                                                                                       look affordable spot work remotely
#
#           actual    predicted
# 0        surfing  scubadiving
# 1        surfing  scubadiving
# 2        surfing  scubadiving
# 3    scubadiving      surfing
# 4        surfing  scubadiving
# ..           ...          ...
# 280  scubadiving      surfing
# 281  scubadiving      surfing
# 282      surfing  scubadiving
# 283      surfing  scubadiving
# 284      surfing  scubadiving
#
# [285 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# # KNN Model - TfidfVectorizer

# %%
# Set up pipeline
knn_tfidf_pipe = Pipeline([('tfidf',TfidfVectorizer()),
                          ('knn', KNeighborsClassifier())])

# Hyperparameters tuning
knn_tfidf_params = {'tfidf__max_features': [6500, 7000, 7500],
                    'tfidf__ngram_range': [(1,1), (1,2)],
                    'knn__p': [1, 2],
                    'knn__weights' : ['uniform', 'distance'],
                    'knn__metric': ['minkowski', 'euclidean'],
                    'knn__n_neighbors': np.arange(5, 10, 2)}

# GridSearchCV
knn_tfidf_gs = GridSearchCV(knn_tfidf_pipe, 
                          param_grid = knn_tfidf_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = 7) 

start_time = time.time()

# Fit model
knn_tfidf_gs.fit(X_train, y_train)

# Show metrics and best parameters
print(knn_tfidf_gs.best_params_)
kt_y_pred, kt_y_pred_prob, kt_accuracy, kt_sensitivity, kt_specificity, kt_precision, kt_f1score, kt_auc = class_metrics(
    knn_tfidf_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 7, 'knn__p': 2, 'knn__weights': 'distance', 'tfidf__max_features': 7000, 'tfidf__ngram_range': (1, 1)}
# Accuracy: 0.75
# Sensitivity: 0.55
# Specificity: 0.94
# Precision: 0.91
# F1: 0.69
# AUC: 0.88
# Elapsed time: 20.13 seconds

# %% [markdown]
# #### Hyperparameters setting example 1:
# knn_tfidf_params = {'tfidf__max_features': [5000, 5500, 6500],
#                     'tfidf__ngram_range': [(1,1), (1,2)],
#                     'knn__p': [1, 2],
#                     'knn__weights' : ['uniform', 'distance'],
#                     'knn__metric': ['minkowski', 'euclidean'],
#                     'knn__n_neighbors': np.arange(5, 10, 2)}
#
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
#
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 9, 'knn__p': 2, 'knn__weights': 'distance', 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 1)}
#
# Accuracy: 0.54
# Sensitivity: 0.08
# Specificity: 1.0
# Precision: 1.0
# F1: 0.16
# AUC: 0.86
#
# Elapsed time: 19.68 seconds
#
# #### Hyperparameters setting example 2:
# knn_tfidf_params = {'tfidf__max_features': [6000, 6500, 7000],
#                     'tfidf__ngram_range': [(1,1), (1,2)],
#                     'knn__p': [1, 2],
#                     'knn__weights' : ['uniform', 'distance'],
#                     'knn__metric': ['minkowski', 'euclidean'],
#                     'knn__n_neighbors': np.arange(5, 10, 2)}
#
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
#
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 7, 'knn__p': 2, 'knn__weights': 'distance', 'tfidf__max_features': 7000, 'tfidf__ngram_range': (1, 1)}
#
# Accuracy: 0.75
# Sensitivity: 0.55
# Specificity: 0.94
# Precision: 0.91
# F1: 0.69
# AUC: 0.88
#
# Elapsed time: 18.26 seconds

# %% [markdown]
# #### Note:
# 'tfidf__min_df' and 'tfidf__max_df' were removed as they did not make any difference to the model scores.
# It is noted that we should use a odd number for n_neighbors as a problem might arise where an observation could encounter a scenario whereby half the neighbors belong to binary class 1, and the other half belong to binary class 0.

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix_plot(y_test, kc_y_pred, 'KNN (TfidfVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(kt_y_pred_prob, kt_auc, 'KNN', 'TfidfVectorizer')

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(kt_y_pred)
# Out:
#                                                                                                                         text  \
# 0                                                                                           world deepest pool deep dubai 4k
# 1                                                                                                           flordia key clue
# 2                                                                                                  diy trilobite line cutter
# 3                                                      color grade underwater clip adobe premiere pro critter hunter footage
# 4                                                               gopro hero 7 black best accessory make good underwater video
# ..                                                                                                                       ...
# 240                                                                         think ecological effect spearfishing sustainable
# 241  think take first class 2 instructor student instructor say student instructor could completely wrong title try becom...
# 242                                                                              go hong kong give much description possible
# 243                                                                 southern right whale teach swim calf coast quintay chile
# 244                                                                                       look affordable spot work remotely
#
#           actual    predicted
# 0    scubadiving      surfing
# 1    scubadiving      surfing
# 2    scubadiving      surfing
# 3    scubadiving      surfing
# 4    scubadiving      surfing
# ..           ...          ...
# 240  scubadiving      surfing
# 241  scubadiving      surfing
# 242  scubadiving      surfing
# 243  scubadiving      surfing
# 244      surfing  scubadiving
#
# [245 rows x 3 columns]

# %%
# Set up pipeline
knn_cvec_pipe = Pipeline([('cvec', CountVectorizer()), 
                         ('knn', KNeighborsClassifier())])

# Hyperparameters tuning
knn_cvec_params = {'cvec__ngram_range' : [(1, 1), (1, 2)],
                   'cvec__max_features' : [6500, 7000, 7500],
                   'cvec__ngram_range': [(1,1), (1,2)],
                   'knn__p': [1, 2],
                   'knn__weights' : ['uniform', 'distance'],
                   'knn__metric': ['minkowski', 'euclidean'],
                   'knn__n_neighbors': np.arange(1, 7, 2)}

# GridSearchCV
knn_cvec_gs = GridSearchCV(knn_cvec_pipe, 
                          param_grid = knn_cvec_params, 
                          cv = 5,
                          verbose = 1,
                          n_jobs = -1) 

start_time = time.time()

# Fit model
knn_cvec_gs.fit(X_train, y_train)

# Show metrics and best parameters
print(knn_cvec_gs.best_params_)
kc_y_pred, kc_y_pred_prob, kc_accuracy, kc_sensitivity, kc_specificity, kc_precision, kc_f1score, kc_auc = class_metrics(
    knn_cvec_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')

# %% [markdown]
# ---

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# | Models                   | Vectorizer      |   Accuracy |   F1-Score |   AUC Score |
# |:-------------------------|:----------------|-----------:|-----------:|------------:|
# | Logistic Regression      | CountVectorizer |       0.85 |       0.85 |        0.93 |
# | Logistic Regression      | TfidfVectorizer |       0.87 |       0.87 |        0.95 |
# | Random Forest Classifier | CountVectorizer |       0.8  |       0.8  |        0.9  |
# | Random Forest Classifier | TfidfVectorizer |       0.83 |       0.83 |        0.92 |
# | KNeighbors Classifier    | CountVectorizer |       0.7  |       0.64 |        0.79 |
# | KNeighbors Classifier    | TfidfVectorizer |       0.75 |       0.69 |        0.88 |

# %% [markdown]
# Refering to the score table above, the model built using the Logistic Regression algorithm and Tfid Vectorizer is the best performing model, since it has the highest accuracy score of 0.87 and AUC score at 0.95. This indicates that the model has a decently good ability to distinguish between whether an observation is from r/scubadiving or r/surfing, and in general, can classify the observations to the right category 87% of the time.
#
# Meantime, KNeighbors Classifier performed the worst. In general, the KNN algorithm does not seem to perform well compared to the other algorithms for balanced data binary classification problems, which is the exact problem we are dealing with in this project. Problem arises when there is an even (>1) number of, say n nearest neighbors and half of n neighbors belong to label 0 and the other half belong to label 1. Then, (n+1)th nearest neighbors have to be found (according to the algorithm) and if the same case arises again, (n+2)th nearest neighbors are found and so on. If this case continues to arise, and in this case, with our balanced data between scubadiving and surfing, at a particular instant, there will be no more samples remaining in the data set and at each nth nearest neighbors consideration, same number of instances of the both the labels are found. Hence, no decision can be taken about the prediction of a test sample, even though after reaching the maximum value of k as per the data set.
# [(source)](https://towardsdatascience.com/algorithmic-incompleteness-of-k-nearest-neighbour-in-binary-classification-8149bfb97c6c)
#
# We can also see that models built using Tfidf Vectorizer perform better than those using Count Vectorizer. This is understable as count vectorizer gives more importance to the words which occurs more frequently but tfidf vectorizer works in such a way that it will give importance to both sets of words which occur more and less in the dataset.

# %% [markdown]
# # Conclusion
# In order for the water sporting goods company to be able to offer highly personalized product recommendations to forum users, a predictor model that is able to distinguish between the two water sports categories  is essential. Hence, we will select the best model based on the highest AUC score, which is the Logistic Regression algorithm and Tfid Vectorizer model, since this score is a measure of a model's separability between two different categories. The higher the AUC score of a model, the better its perfomance in distinguishing different categories.
#
# We will cover the model with more details below with:
# 1. Confusion Matrix to show a summary of the number / percentage of observation that were rightly / wrongly predicted.
# 2. ROC Curve of the model to show the trade-off between sensitivity (or TPR) and specificity (1 – FPR).
# 3. Observations that were misclassified
# 4. Word Coefficiencies

# %% [markdown]
# ## Final Model: Logistic Regression (Count Vectorizer)

# %%
# Set up pipleline
lr_tfidf_pipe = Pipeline([('tfidf',TfidfVectorizer()),
                          ('lr',LogisticRegression(solver = 'liblinear'))])

# Pipe parameters
lr_tfidf_params = {'tfidf__max_features': [6000, 6500, 7000],
                   'tfidf__ngram_range': [(1,1), (1,2)],
                   'lr__penalty': ['l1', 'l2'],
                   'lr__C': np.linspace(4, 7, 20)}

start_time = time.time()

# tfidf grid search
# Instantiate GridSearchCV.
lr_tfidf_gs = GridSearchCV(lr_tfidf_pipe, 
                           lr_tfidf_params, 
                           cv = 5,
                           verbose = 1,
                           n_jobs = 7) 

# Fit grid search
lr_tfidf_gs.fit(X_train, y_train)

# Show best params, metrics and unpack function return values into variables
print(lr_tfidf_gs.best_params_)
lt_y_pred, lt_y_pred_prob, lt_accuracy, lt_sensitivity, lt_specificity, lt_precision, lt_f1score, lt_auc = class_metrics(
    lr_tfidf_gs, X_test, y_test)

end_time = time.time()
print(f'Elapsed time: {round((end_time - start_time), 2)} seconds')
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# {'lr__C': 5.105263157894736, 'lr__penalty': 'l2', 'tfidf__max_features': 6500, 'tfidf__ngram_range': (1, 2)}
# Accuracy: 0.87
# Sensitivity: 0.84
# Specificity: 0.91
# Precision: 0.9
# F1: 0.87
# AUC: 0.95
# Elapsed time: 47.25 seconds

# %% [markdown]
# ## Confusion Matrix

# %%
confusion_matrix_plot(y_test, lt_y_pred, 'Logistic Regression (TfidfVectorizer)')

# %% [markdown]
# ### ROC Curve and AUC

# %%
plot_roc_auc(lt_y_pred_prob, lt_auc, 'Logistic Regression', 'TfidfVectorizer')

# %% [markdown]
# The Receiver Operator Characteristic (ROC) curve is an evaluation metric for binary classification problems. It is a probability curve that plots the TPR against FPR at various threshold values and essentially separates the 'signal' from the 'noise'. The Area Under the Curve (AUC) is the measure of the ability of a classifier to distinguish between classes and is used as a summary of the ROC curve. Classifiers that give curves closer to the top-left corner indicate a better performance. The closer the curve comes to the 45-degree diagonal of the ROC space, the less accurate the test. [(source)](https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/)
#
# As mentioned during model evaluation, 0.95 is a good AUC score, and hence would be useful in helping the water sporting goods company to identify forum users' preference in water sports.

# %% [markdown]
# ### Misclassified Observations

# %%
display_misclassification(lt_y_pred)
# Out:
#                                                                                                                         text  \
# 0                                                                                                  diy trilobite line cutter
# 1                                                                                                     jacob well texas could
# 2                                                                                                   activity best complement
# 3                                                          mentawaii island 2019 5 u perfect poo stance love go back someday
# 4    shark life australia change dramatically summer winter completely different shark population reside many offshore ro...
# 5                                                                             nitrox incident analysis one seriously injured
# 6    place north shore hi everyone new hop see knew good place north shore massachusetts look place gloucester rockport a...
# 7    impromptu bali trip bring rent wife surprised ticket bali may trip isnt dedicate trip ill try much possible wonder g...
# 8                                                                                                                 day corona
# 9                                                                                     joe rogan experience 1749 shane dorian
# 10            present boyfriend planning go indonesia covid ever end 4 month get divemaster good present trip thanks advance
# 11                                                       nantucket mv live south eastern go mv summer time havent heard much
# 12                                                                                                   learnt deadly art pearl
# 13                                                                                           shark kill dolphin brings shore
# 14                                     52 spending weekend wendover friday saturday interested meeting dinner drink let know
# 15   fin recommendation cold warm water hi recently get back love recommendation fin look last long time get back lot pla...
# 16                                                     human really consume 300 million ton antarctic krill per year extinct
# 17   try hand make weight since two son get multiply expense three look cost weight severe sticker shock decide try make ...
# 18   help nice question hello everyone question isnt simple think someone might able help love dream somewhat person work...
# 19                                                                                                         love around gilis
# 20                                                                                                             shadeonme com
# 21                                                                                                                   ya need
# 22   ireland planning trip ireland scotland january plan first leg trip ireland go around whole country want know good sp...
# 23                                                                                          tell damage look way close thing
# 24                                                                                                                  question
# 25                                                  big challenge interested learn appreciate information someone know learn
# 26   men v woman wetsuits main difference men woman wetsuits guess little space around bust could woman typically use men...
# 27                                                                                                                   brownie
# 28                                                                                                               life change
# 29                                                                                                         high fashion boot
# 30                                                                                               beginner friend keep buying
# 31                                                                                     throwaway extreme first world problem
# 32                                                                                          scoobslens insta like stuff hehe
# 86                                                                                                                   sun sea
# 87                           best knife general use see lot different one titanium h1 steel one coat stop rust everyone take
# 88                                                                                                                 evolution
# 89                                                                                       thought guy might like illustration
# 90                                                                                                                 waco pool
# 91                                                                   co founder ceo truly social game gold mining enthusiast
# 92                                                                                                         thought sharkbanz
# 93                                                                                             best app app store nobodysurf
# 94                                                                                       best skill develop anywhere anytime
# 95                                                                                                remember make u smile back
# 96                                                 gopro hand pole get gopro christmas hand pole attachment recommend thanks
# 97   havent three year today finally first since panicked heavily within meter felt like couldnt breath couldnt finish ev...
# 98   affect contraceptive implant nexplanon hi go first time week realize checked afterwards use nexplanon small contrace...
# 99   please help ive really want get last couple month realy need someone know theyre talk help dont live around body wat...
# 100                                                                                                  patagonia wetsuits good
# 101  gear set id like sell go find worth recommendation sell aside craigslist offerup didnt want post something shouldnt ...
# 102                                                                                   mt rainer chilly day 10 12 21 pre view
# 103                                                                       funny christmas soccer snowman ugly christmas xmas
# 104                                                                                     anything keep harm little wound knee
# 105                                                                                              weather get cold ocean call
# 106                                                                                                  downside carbon compact
# 107                                                                                                                love drop
# 108                                                                          grner see green lake austria good old day allow
# 109  picture dad round valley nj 1989 thanks dad get unfortunately cant anymore due health issue thank almost 100 able go...
# 110  need help find good time year mediterranean hi graduate high school decide take gap year get opportunity volunteer m...
# 111                                                                                                            isla del cano
# 112  clear coat extend life old experiment put clear coat old keep waterproof little longer bunch repair fairly structura...
# 113                             know sunny garcia recently mean disrespect invasion privacy curious hope well happy possible
# 114                                                                                                          thought waxjobs
# 115                                                                                            gopros gotten much well photo
# 116  advice 100th 17 year old male caribbean 2 away hit 100 want know could possibly heard others get naked unwilling wan...
# 117                                                                                    ice training past weekend lake simcoe
# 118                                                                                                              wetsuit buy
# 119                                                                                                                st thomas
# 120                                                                                                   seraya secret concpets
# 121                                                                        tiny cephalopod last time pinky finger size squid
# 122                                                                                                                  morning
# 123                                           happy new year everyone include hater haha let hope year fill truly swell time
# 124                                                                                                       ok one wild enough
# 125                                                                                       look affordable spot work remotely
#
#           actual    predicted
# 0    scubadiving      surfing
# 1    scubadiving      surfing
# 2        surfing  scubadiving
# 3        surfing  scubadiving
# 4    scubadiving      surfing
# 5    scubadiving      surfing
# 6    scubadiving      surfing
# 7        surfing  scubadiving
# 8    scubadiving      surfing
# 9        surfing  scubadiving
# 10   scubadiving      surfing
# 11   scubadiving      surfing
# 12   scubadiving      surfing
# 13       surfing  scubadiving
# 14   scubadiving      surfing
# 15   scubadiving      surfing
# 16   scubadiving      surfing
# 17   scubadiving      surfing
# 18   scubadiving      surfing
# 19   scubadiving      surfing
# 20       surfing  scubadiving
# 21       surfing  scubadiving
# 22       surfing  scubadiving
# 23       surfing  scubadiving
# 24   scubadiving      surfing
# 25   scubadiving      surfing
# 26   scubadiving      surfing
# 27   scubadiving      surfing
# 28   scubadiving      surfing
# 29       surfing  scubadiving
# 30       surfing  scubadiving
# 31       surfing  scubadiving
# 32       surfing  scubadiving
# 33   scubadiving      surfing
# 34       surfing  scubadiving
# 35       surfing  scubadiving
# 36       surfing  scubadiving
# 37   scubadiving      surfing
# 38   scubadiving      surfing
# 39   scubadiving      surfing
# 40   scubadiving      surfing
# 41       surfing  scubadiving
# 42   scubadiving      surfing
# 43   scubadiving      surfing
# 44   scubadiving      surfing
# 45       surfing  scubadiving
# 46   scubadiving      surfing
# 47   scubadiving      surfing
# 48   scubadiving      surfing
# 49       surfing  scubadiving
# 50       surfing  scubadiving
# 51   scubadiving      surfing
# 52       surfing  scubadiving
# 53   scubadiving      surfing
# 54   scubadiving      surfing
# 55       surfing  scubadiving
# 56   scubadiving      surfing
# 57   scubadiving      surfing
# 58       surfing  scubadiving
# 59   scubadiving      surfing
# 60   scubadiving      surfing
# 61   scubadiving      surfing
# 62   scubadiving      surfing
# 63       surfing  scubadiving
# 64       surfing  scubadiving
# 65       surfing  scubadiving
# 66   scubadiving      surfing
# 67   scubadiving      surfing
# 68       surfing  scubadiving
# 69       surfing  scubadiving
# 70   scubadiving      surfing
# 71   scubadiving      surfing
# 72   scubadiving      surfing
# 73   scubadiving      surfing
# 74   scubadiving      surfing
# 75   scubadiving      surfing
# 76   scubadiving      surfing
# 77       surfing  scubadiving
# 78   scubadiving      surfing
# 79   scubadiving      surfing
# 80       surfing  scubadiving
# 81       surfing  scubadiving
# 82   scubadiving      surfing
# 83       surfing  scubadiving
# 84       surfing  scubadiving
# 85   scubadiving      surfing
# 86       surfing  scubadiving
# 87   scubadiving      surfing
# 88   scubadiving      surfing
# 89   scubadiving      surfing
# 90       surfing  scubadiving
# 91   scubadiving      surfing
# 92       surfing  scubadiving
# 93       surfing  scubadiving
# 94       surfing  scubadiving
# 95   scubadiving      surfing
# 96   scubadiving      surfing
# 97   scubadiving      surfing
# 98   scubadiving      surfing
# 99   scubadiving      surfing
# 100  scubadiving      surfing
# 101  scubadiving      surfing
# 102  scubadiving      surfing
# 103  scubadiving      surfing
# 104      surfing  scubadiving
# 105  scubadiving      surfing
# 106      surfing  scubadiving
# 107  scubadiving      surfing
# 108  scubadiving      surfing
# 109  scubadiving      surfing
# 110  scubadiving      surfing
# 111  scubadiving      surfing
# 112      surfing  scubadiving
# 113      surfing  scubadiving
# 114      surfing  scubadiving
# 115  scubadiving      surfing
# 116  scubadiving      surfing
# 117  scubadiving      surfing
# 118  scubadiving      surfing
# 119  scubadiving      surfing
# 120  scubadiving      surfing
# 121  scubadiving      surfing
# 122  scubadiving      surfing
# 123      surfing  scubadiving
# 124      surfing  scubadiving
# 125      surfing  scubadiving

# %% [markdown]
# Most of the text observations that have been 'misclassfied' actually contain texts that are quite random. Also, many of these observations have very few word tokens, eg. less than 5. Hence it would be difficult to classify them correctly as there is a lack to the lack of word tokens for the model to do its prediction.

# %% [markdown]
# ### Word Coefficients

# %%
coef_names = lr_tfidf_gs.best_estimator_.named_steps['tfidf'].get_feature_names()
coef_vals = lr_tfidf_gs.best_estimator_.named_steps['lr'].coef_[0]

coef_df = pd.DataFrame ({
    'word' : coef_names,
    'coef' : coef_vals}).set_index('word')

coef_df.reindex(coef_df['coef'].sort_values(ascending = False).index)[:20]
# Out:
#                    coef
# word
# underwater     6.630013
# bali           4.714728
# sea            4.356657
# open           4.267845
# gear           4.127601
# certify        4.074857
# computer       3.964749
# reef           3.873575
# equipment      3.862796
# course         3.761237
# octopus        3.728063
# certification  3.642339
# padi           3.603478
# mask           3.599225
# snorkel        3.460913
# com            3.425256
# wreck          3.374158
# island         3.325003
# turtle         3.277600
# bonaire        3.177694

# %%
coef_df.reindex(coef_df['coef'].sort_values(ascending = True).index)[:20]
# Out:
#                coef
# word
# surfer    -6.248414
# surfboard -5.216310
# kook      -3.927988
# ride      -3.704780
# repair    -3.679268
# paddle    -3.669844
# session   -3.296608
# winter    -3.269509
# shape     -3.231808
# surfed    -3.086244
# break     -2.996529
# swell     -2.981087
# morning   -2.870150
# use       -2.845665
# custom    -2.678052
# rain      -2.668920
# barrel    -2.580733
# quiver    -2.578556
# rid       -2.554317
# beach     -2.507196

# %% [markdown]
# Above shows the top 20 words with the highest coefficient with category 1, scubadiving. This means that the higher the coefficient of a word, the higher the chance the observation that contains the word, will be placed in category 1. Meantime, the lower the coefficient of a word, the chance of the observation that contain the word will be classified as cateogry 0 will be higher. In this case, observations containing words with higher coefficients will most likely be classified as category 1, which is scubadiving, while observations containing words with low coefficients (in this case, negative coefficients) will most likely be classified as category 0, which is surfing.

# %% [markdown]
# # Future Improvements

# %% [markdown]
# Words like 'surfboard' and 'surfer' should be removed as a good model should be able to classify data even without the use of obvious key words.

# %% [markdown]
# ---

# %% [markdown]
# # Appendix

# %% [markdown]
# ### Score Table

# %%
data = {'Models': ['Logistic Regression', 'Logistic Regression', 'Random Forest Classifier', 'Random Forest Classifier', 
                   'KNeighbors Classifier', 'KNeighbors Classifier'], 
        'Vectorizer': ['CountVectorizer', 'TfidfVectorizer', 'CountVectorizer', 'TfidfVectorizer', 
                           'CountVectorizer', 'TfidfVectorizer'], 
        'Accuracy': [lc_accuracy, lt_accuracy, rc_accuracy, rt_accuracy, kc_accuracy, kt_accuracy],
        'F1-Score': [lc_f1score, lt_f1score, rc_f1score, rt_f1score, kc_f1score, kt_f1score],
        'AUC Score': [lc_auc, lt_auc, rc_auc, rt_auc, kc_auc, kt_auc]}

# %%
# Create DataFrame  
df = pd.DataFrame(data)

# %%
score_table = df.to_markdown(index=False)

# %%
print(score_table)
# Out:
# | Models                   | Vectorizer      |   Accuracy |   F1-Score |   AUC Score |
# |:-------------------------|:----------------|-----------:|-----------:|------------:|
# | Logistic Regression      | CountVectorizer |       0.85 |       0.85 |        0.93 |
# | Logistic Regression      | TfidfVectorizer |       0.87 |       0.87 |        0.95 |
# | Random Forest Classifier | CountVectorizer |       0.8  |       0.8  |        0.9  |
# | Random Forest Classifier | TfidfVectorizer |       0.83 |       0.83 |        0.92 |
# | KNeighbors Classifier    | CountVectorizer |       0.71 |       0.67 |        0.78 |
# | KNeighbors Classifier    | TfidfVectorizer |       0.75 |       0.69 |        0.88 |
