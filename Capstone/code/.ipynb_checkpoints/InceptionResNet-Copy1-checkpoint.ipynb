# %%
import os
import itertools 
import random
random.seed(42)
from random import shuffle
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
import numpy as np
from PIL import Image
from keras import backend as K
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Input, Flatten, Dense, Dropout, Lambda
from keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.applications.inception_resnet_v2 import preprocess_input, InceptionResNetV2

# Modeling and model evaluation
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import f1_score

# connect to gpu
import tensorflow as tf
from tensorflow.python.client import device_lib
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def plot_history(results):
    plt.plot(results.history['loss'])
    plt.plot(results.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train loss', 'val loss'], loc='upper right')
    plt.show()

# %%
path='../signatures_full/train/forged'
list_name =[]
for root, dirs, files in os.walk(path):
    list_name.extend(files)
from collections import defaultdict
#Does not raise KeyError. It provides a default value for the key that does not exists

dic=defaultdict(list)


for i in list_name:
    filename,ext =os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic[group].append(img_index)

# %%
# create a sub_directory called forged_person inside the forged directory if folder does not exist
directory = 'forged_person'
parent_dir = '../datasets/signatures_full/test/forged'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
#group every signature from each individual in one folder
import shutil
new_folder='../signatures_full/train/forged/forged_person'
path='../signatures_full/train/forged'

for i in dic:        
        if not os.path.exists(os.path.join(new_folder,i)):
            os.mkdir(os.path.join(new_folder,i))
            for img in dic[i]:
                old_image = os.path.join(path,'forgeries_{}_{}.png'.format(i,img))
                new_image = r'{}.png'.format(img)
                new_path =os.path.join(new_folder,i)

                shutil.move(old_image,os.path.join(new_path,new_image)) #Recursively moves a file or directory to another location and returns the destination.
                #If the destination directory already exists then src is moved inside that directory.
                
        else:
            for img in dic[i]:
                old_image = os.path.join(path,'forgeries_{}_{}.png'.format(i,img))
                new_image = r'{}.png'.format(img)
                new_path =os.path.join(new_folder,i)
                print(new_path)
                shutil.move(old_image,os.path.join(new_path,new_image))

# %%
path='../signatures_full/train/genuine'
list_name_2 =[]
for root, dirs, files in os.walk(path):
    list_name_2.extend(files)
from collections import defaultdict

dic_2=defaultdict(list)


for i in list_name_2:
    filename,ext =os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic_2[group].append(img_index)

# %%
# create a sub_directory called genuine_person inside the genuine directory
directory = 'genuine_person'
parent_dir = '../datasets/signatures_full/test/genuine'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
#group every signature from each individual in one folder

new_folder='../signatures_full/train/genuine_person'
path='../signatures_full/train/genuine'

for i in dic_2:        
        if not os.path.exists(os.path.join(new_folder,i)):
            os.mkdir(os.path.join(new_folder,i))
            for img in dic_2[i]:
                old_image = os.path.join(path,'original_{}_{}.png'.format(i,img))
                new_image = r'{}.png'.format(img)
                new_path =os.path.join(new_folder,i)

                shutil.move(old_image,os.path.join(new_path,new_image))
        else:
            for img in dic_2[i]:
                old_image = os.path.join(path,'original_{}_{}.png'.format(i,img))
                new_image = r'{}.png'.format(img)
                new_path =os.path.join(new_folder,i)
                print(new_path)
                shutil.move(old_image,os.path.join(new_path,new_image))

# %%
# Create lists of different list of genuine signature images from a single person

path = '../datasets/signatures_full/train/genuine/genuine_person'
# create a list of directories containing signatures of each person
dir_list_gen = next(os.walk(path))[1]  # root, folder, files
# sort the list
dir_list_gen.sort()
# create an empty list
orig_groups=[]
for directory in dir_list_gen:
    images = os.listdir(path+'/'+directory)
    images.sort()
    # list comprehension generating the file path of each img inside the dir
    images = [path+'/'+directory+'/' + x for x in images]
    orig_groups.append(images)  # appending the list inside the genuine list

# %%
orig_groups[2]
# Out:
# ['../datasets/signatures_full/train/genuine/genuine_person/11/1.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/10.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/11.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/12.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/13.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/14.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/15.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/16.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/17.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/18.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/19.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/2.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/20.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/3.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/4.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/5.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/6.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/7.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/8.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/11/9.png']

# %%
# Forged signature lists
path = '../datasets/signatures_full/train/forged/forged_person'

dir_list_forg = sorted(os.listdir(path))
dir_list_forg.sort()

forg_groups = []
for directory in dir_list_forg:
    images = os.listdir(path+'/'+directory)
    images.sort()
    images = [path+'/'+directory+'/'+x for x in images]
    forg_groups.append(images)

# %%
len(orig_groups), len(forg_groups)
# Out:
# (55, 55)

# %%
#check the number of signatures per individual. Both genuine and forged
orig_lengths = [len(x) for x in orig_groups]
forg_lengths = [len(x) for x in forg_groups]
print(orig_lengths)
print(forg_lengths)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %%
#split data into training and validation
#40 individuals for training and 15 for validation
orig_train, orig_val = orig_groups[:40], orig_groups[40:]
forg_train, forg_val = forg_groups[:40], forg_groups[40:]

# %%
# All the images will be converted to the same size before processing
img_h, img_w = 150,150

# %%
def generate_batch(orig_groups, forg_groups, batch_size = 32):
    #Function to generate a batch of data with batch_size number of data points
    #Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs
    while True:
        orig_pairs = []
        forg_pairs = []
        gen_gen_labels = []
        gen_for_labels = []
        all_pairs = []
        all_labels = []
        
        # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
        # For every person we have 20 genuine signatures, hence we have 
        # 20 choose 2 = 190 Genuine-Genuine image pairs for one person.
        # To make Genuine-Forged pairs, we pair every Genuine signature of a person
        # with 12 randomly sampled Forged signatures of the same person.
        # Thus we make 20 * 12 = 240 Genuine-Forged image pairs for one person.
        # In all we have 40 person's data in the training data.
        # Total no. of Genuine-Genuine pairs = 40 * 190= 7600
        # Total number of Genuine-Forged pairs = 40 * 240 = 9600
        # Total no. of data points = 7600 + 9600 = 17200
        for orig, forg in zip(orig_groups, forg_groups):
            orig_pairs.extend(list(itertools.combinations(orig, 2)))
            for i in range(len(forg)):
                forg_pairs.extend(list(itertools.product(orig[i:i+1], random.sample(forg, 12))))
        
        # Label for Genuine-Genuine pairs is 1
        # Label for Genuine-Forged pairs is 0
        gen_gen_labels = [1]*len(orig_pairs)
        gen_for_labels = [0]*len(forg_pairs)
        
        # Concatenate all the pairs together along with their labels and shuffle them
        all_pairs = orig_pairs + forg_pairs
        all_labels = gen_gen_labels + gen_for_labels
        del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
        all_pairs, all_labels = shuffle(all_pairs, all_labels)
        
        # Note the lists above contain only the image names and
        # actual images are loaded and yielded below in batches
        # Below we prepare a batch of data points and yield the batch
        # In each batch we load "batch_size" number of image pairs
        # These images are then removed from the original set so that
        # they are not added again in the next batch.
            
        k = 0
        pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
        targets=np.zeros((batch_size,))
        for ix, pair in enumerate(all_pairs):
            img1 = cv2.imread(pair[0], 0)
            img2 = cv2.imread(pair[1], 0)
            img1 = cv2.resize(img1, (img_w, img_h))
            img2 = cv2.resize(img2, (img_w, img_h))
            img1 = np.array(img1, dtype = np.float64)
            img2 = np.array(img2, dtype = np.float64)
            img1 /= 255
            img2 /= 255
            img1 = img1[..., np.newaxis]
            img2 = img2[..., np.newaxis]
            pairs[0][k, :, :, :] = img1
            pairs[1][k, :, :, :] = img2
            targets[k] = all_labels[ix]
            k += 1
            if k == batch_size:
                yield pairs, targets
                k = 0
                pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
                targets=np.zeros((batch_size,))

# %%
def euclidean_distance(vects):
    #Compute Euclidean Distance between two vectors
    
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def contrastive_loss(y_true, y_pred):          #contrastive_loss - This loss encourages the embedding to be close to each other for
                                               #the samples of the same label and the embedding to be far apart at least
                                               #by the margin constant for the samples of different labels

    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))

# %%
def confusion_matrix_plot(y_test, y_pred, title):
    cf_matrix = confusion_matrix(y_test, y_pred)
    group_names = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    hm = sns.heatmap(cf_matrix, annot = labels, fmt = '', cmap = 'Blues')
    hm.set_title(title)

# %%
def create_pairs(orig_groups, forg_groups):
    orig_pairs = []
    forg_pairs = []
    gen_gen_labels = []
    gen_for_labels = []
    all_pairs = []
    all_labels = []
        
    # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
    # For every person we have 20 genuine signatures, hence we have 
    # 20 choose 2 = 190 Genuine-Genuine image pairs for one person.
    # To make Genuine-Forged pairs, we pair every Genuine signature of a person
    # with 12 randomly sampled Forged signatures of the same person.
    # Thus we make 20 * 12 = 240 Genuine-Forged image pairs for one person.
    # In all we have 40 person's data in the training data.
    # Total no. of Genuine-Genuine pairs = 40 * 190= 7600
    # Total number of Genuine-Forged pairs = 40 * 240 = 9600
    # Total no. of data points = 7600 + 9600 = 17200
    for orig, forg in zip(orig_groups, forg_groups):
        orig_pairs.extend(list(itertools.combinations(orig, 2)))
        for i in range(len(forg)):
            forg_pairs.extend(list(itertools.product(orig[i:i+1], random.sample(forg, 12))))
        
    # Label for Genuine-Genuine pairs is 1
    # Label for Genuine-Forged pairs is 0
    gen_gen_labels = [1]*len(orig_pairs)
    gen_for_labels = [0]*len(forg_pairs)
        
    # Concatenate all the pairs together along with their labels and shuffle them
    all_pairs = orig_pairs + forg_pairs
    all_labels = gen_gen_labels + gen_for_labels
    
    return (all_pairs, all_labels)

# %%
def batch_generator(X_pairs, y_labels, batch_size):
    """"Returns a batch of images for the model to consume
    
    Args:
        X_pairs (tuple[str, str]): List of tuples with two image filepaths
        y_labels (List[int]): List of labels for pairs, 1 for similar and 0 for dissimilar
    
    Yields:
        tuple[(ndarray, ndarray), ndarray]
    """
    total_pairs = len(y_labels)
    while True:
        batch = []
        labels = []
        for i, ((img_filename_1, img_filename_2), label) in enumerate(zip(X_pairs, y_labels)):
            img_1 = cv2.imread(img_filename_1)
            img_2 = cv2.imread(img_filename_2)
            img_1 = preprocess_image_inception_keras(img_1)
            img_2 = preprocess_image_inception_keras(img_2)
            batch.append([img_1, img_2])
            labels.append(label)
            if (i + 1) % batch_size == 0 or (i + 1) == total_pairs:
                result = np.array(batch, dtype=np.float32)
                yield ([result[:, 0], result[:, 1]], np.array(labels, dtype=np.float32))
                result = None
                batch = []
                labels = []

# %%
def preprocess_image_inception_keras(image_matrix):
    X = np.array(image_matrix, dtype=np.float32)
    return preprocess_input(X)

# %%
X_train, y_train = create_pairs(orig_train, forg_train)
X_val, y_val = create_pairs(orig_val, forg_val)

# %%
def euclidean_distance(vects):
    x, y = vects
    return K.sqrt(K.maximum(K.sum(K.square(x - y), axis=1, keepdims=True), K.epsilon()))

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def create_base_network(input_shape, model_name, freeze_layers_until=None):
    """Get the base network to do the feature extract for the latent embedding
    
    Args:
        input_shape (tuple): Shape of image tensor input
        
    Returns:
        keras.models.Model
    """
    input = Input(shape=input_shape)
    model = model_name(weights='imagenet', input_tensor=input)
    model.layers.pop()  # Remove classification layer

    if freeze_layers_until:
        assert freeze_layers_until in [l.name for l in model.layers]
        for layer in model.layers:
            layer.trainable = False
            if type(layer) == 'BatchNormalization':
                layer.momentum = 1.0
            if layer.name == freeze_layers_until:
                break

    model = Model(inputs=[input], outputs=[model.layers[-1].output], name='embedding_model')
    return model

# %%
def compute_accuracy(y_true, y_pred):
    """Compute classification accuracy with a fixed threshold on distances."""
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %%
def accuracy(y_true, y_pred):
    """Compute classification accuracy with a fixed threshold on distances."""
    return K.mean(K.equal(y_true, K.cast(y_pred < 0.5, y_true.dtype)))

# %%
def compute_accuracy_roc(predictions, labels):
    '''Compute ROC accuracy with a range of thresholds on distances.
    '''
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)

    step = 0.01
    max_acc = 0
    best_thresh = -1

    for d in np.arange(dmin, dmax+step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d

        tpr = float(np.sum(labels[idx1] == 1)) / nsame
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff
        acc = 0.5 * (tpr + tnr)
#       print ('ROC', acc, tpr, tnr)

        if (acc > max_acc):
            max_acc, best_thresh = acc, d

    return max_acc, best_thresh,

# %%
# Don't change these unless you know what you are doing
IMAGE_SHAPE = (150, 150, 3)
IMAGE_SIZE = IMAGE_SHAPE[:2]
EVAL_PERCENT = 0.3

# %%
# Grab the Inception ResNet V2 model pretrained on image net
# Freeze layers up to mixed_6a for faster training and less overfitting
base_network = create_base_network(IMAGE_SHAPE, InceptionResNetV2, 'mixed_6a')

# Create two inputs for both images from pairs
input_a = Input(shape=IMAGE_SHAPE)
input_b = Input(shape=IMAGE_SHAPE)

# %%
# Connect the same base_network created above to the two image inputs
processed_a = base_network(input_a)
processed_b = base_network(input_b)

# Get the distance between the two input images
distance = Lambda(euclidean_distance,
                  output_shape=eucl_dist_output_shape)([processed_a, processed_b])

# Create a model which takes in a pair of images and returns the distance
model = Model([input_a, input_b], distance)

# %%
# Create callback functions to call after every epoch
ckpt_dir = 'checkpoints'
if not os.path.exists(ckpt_dir):
    os.mkdir(ckpt_dir)
ckpt_pattern = os.path.join(ckpt_dir, 'weights.{epoch:02d}-{val_loss:.5f}.hdf5')

callbacks = [
    ModelCheckpoint(ckpt_pattern,
                    monitor='val_loss',
                    save_best_only=True),
    ReduceLROnPlateau('loss', factor=0.5, patience=3, verbose=1, min_lr=1e-7)
]

# %%
init_learning_rate = 0.0005
rms = RMSprop(learning_rate=init_learning_rate)
model.compile(loss=contrastive_loss, optimizer=rms, metrics=[accuracy])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  input_3 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  embedding_model (Functional)   (None, 1000)         55873736    ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['embedding_model[0][0]',
#                                                                   'embedding_model[1][0]']
#
# ==================================================================================================
# Total params: 55,873,736
# Trainable params: 51,480,168
# Non-trainable params: 4,393,568
# __________________________________________________________________________________________________

# %%
history = model.fit(batch_generator(X_train, y_train, 32),
          steps_per_epoch=len(X_train) // 32,
          epochs=20,
          callbacks=callbacks,
          validation_data=batch_generator(X_val, y_val, 32),
          validation_steps=len(y_val) // 32)
# Out:
# Epoch 1/20
# 537/537 [==============================] - 253s 423ms/step - loss: 0.0882 - accuracy: 0.8897 - val_loss: 0.5134 - val_accuracy: 0.4646 - lr: 5.0000e-04
# Epoch 2/20
# 537/537 [==============================] - 224s 415ms/step - loss: 0.0584 - accuracy: 0.9208 - val_loss: 0.5544 - val_accuracy: 0.4453 - lr: 5.0000e-04
# Epoch 3/20
# 537/537 [==============================] - 226s 422ms/step - loss: 0.0430 - accuracy: 0.9374 - val_loss: 0.5218 - val_accuracy: 0.5292 - lr: 5.0000e-04
# Epoch 4/20
# 537/537 [==============================] - 226s 422ms/step - loss: 0.0669 - accuracy: 0.9175 - val_loss: 0.5293 - val_accuracy: 0.4557 - lr: 5.0000e-04
# Epoch 5/20
# 537/537 [==============================] - 224s 416ms/step - loss: 0.0507 - accuracy: 0.9398 - val_loss: 0.5492 - val_accuracy: 0.5622 - lr: 5.0000e-04
# Epoch 6/20
# 537/537 [==============================] - 223s 416ms/step - loss: 0.0298 - accuracy: 0.9614 - val_loss: 0.5452 - val_accuracy: 0.4579 - lr: 5.0000e-04
# Epoch 7/20
# 537/537 [==============================] - 224s 416ms/step - loss: 0.0480 - accuracy: 0.9395 - val_loss: 0.5274 - val_accuracy: 0.5045 - lr: 5.0000e-04
# Epoch 8/20
# 537/537 [==============================] - 225s 419ms/step - loss: 0.1406 - accuracy: 0.8482 - val_loss: 0.5409 - val_accuracy: 0.5131 - lr: 5.0000e-04
# Epoch 9/20
# 537/537 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.8951
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 537/537 [==============================] - 222s 414ms/step - loss: 0.0879 - accuracy: 0.8951 - val_loss: 0.5534 - val_accuracy: 0.4507 - lr: 5.0000e-04
# Epoch 10/20
# 537/537 [==============================] - 224s 417ms/step - loss: 0.1037 - accuracy: 0.8803 - val_loss: 0.5307 - val_accuracy: 0.5168 - lr: 2.5000e-04
# Epoch 11/20
# 537/537 [==============================] - 226s 420ms/step - loss: 0.0787 - accuracy: 0.9161 - val_loss: 0.5301 - val_accuracy: 0.5107 - lr: 2.5000e-04
# Epoch 12/20
# 537/537 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9627
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 537/537 [==============================] - 225s 419ms/step - loss: 0.0330 - accuracy: 0.9627 - val_loss: 0.5521 - val_accuracy: 0.4841 - lr: 2.5000e-04
# Epoch 13/20
# 537/537 [==============================] - 222s 414ms/step - loss: 0.0959 - accuracy: 0.9001 - val_loss: 0.5442 - val_accuracy: 0.4913 - lr: 1.2500e-04
# Epoch 14/20
# 537/537 [==============================] - 223s 415ms/step - loss: 0.0604 - accuracy: 0.9361 - val_loss: 0.5419 - val_accuracy: 0.5006 - lr: 1.2500e-04
# Epoch 15/20
# 537/537 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9003
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 537/537 [==============================] - 224s 417ms/step - loss: 0.0931 - accuracy: 0.9003 - val_loss: 0.5553 - val_accuracy: 0.4420 - lr: 1.2500e-04
# Epoch 16/20
# 537/537 [==============================] - 222s 414ms/step - loss: 0.0637 - accuracy: 0.9287 - val_loss: 0.5521 - val_accuracy: 0.4431 - lr: 6.2500e-05
# Epoch 17/20
# 537/537 [==============================] - 224s 416ms/step - loss: 0.0759 - accuracy: 0.9168 - val_loss: 0.5539 - val_accuracy: 0.4431 - lr: 6.2500e-05
# Epoch 18/20
# 537/537 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.8478
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 537/537 [==============================] - 222s 414ms/step - loss: 0.1427 - accuracy: 0.8478 - val_loss: 0.5539 - val_accuracy: 0.4431 - lr: 6.2500e-05
# Epoch 19/20
# 537/537 [==============================] - 224s 417ms/step - loss: 0.2766 - accuracy: 0.6968 - val_loss: 0.5542 - val_accuracy: 0.4431 - lr: 3.1250e-05
# Epoch 20/20
# 537/537 [==============================] - 222s 413ms/step - loss: 0.1712 - accuracy: 0.8024 - val_loss: 0.5551 - val_accuracy: 0.4431 - lr: 3.1250e-05

# %%
plot_history(history)

# %%
# Save the final model
model.save(os.path.join(ckpt_dir, 'final_model.hdf5'))

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/inception_resnetv2-model-{epoch:02d}.h5', verbose=1, save_weights_only=True)
]

# %%
init_learning_rate = 1e-3
rms = RMSprop(learning_rate=init_learning_rate)
model.compile(loss=contrastive_loss, optimizer=rms, metrics=[accuracy])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  input_3 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  embedding_model (Functional)   (None, 1000)         55873736    ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['embedding_model[0][0]',
#                                                                   'embedding_model[1][0]']
#
# ==================================================================================================
# Total params: 55,873,736
# Trainable params: 51,480,168
# Non-trainable params: 4,393,568
# __________________________________________________________________________________________________

# %%
history = model.fit(batch_generator(X_train, y_train, 32),
                    steps_per_epoch=len(X_train) // 32,
                    epochs=30,
                    callbacks=callbacks,
                    validation_data=batch_generator(X_val, y_val, 32),
                    validation_steps=len(y_val) // 32)
# Out:
# Epoch 1/30
# 537/537 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9096
# Epoch 1: saving model to ../weights\inception_resnetv2-model-01.h5
# 537/537 [==============================] - 250s 426ms/step - loss: 0.0668 - accuracy: 0.9096 - val_loss: 0.5146 - val_accuracy: 0.4913
# Epoch 2/30
# 537/537 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.8733
# Epoch 2: saving model to ../weights\inception_resnetv2-model-02.h5
# 537/537 [==============================] - 227s 422ms/step - loss: 0.1166 - accuracy: 0.8733 - val_loss: 0.5395 - val_accuracy: 0.4787
# Epoch 3/30
# 537/537 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.8982
# Epoch 3: saving model to ../weights\inception_resnetv2-model-03.h5
# 537/537 [==============================] - 227s 422ms/step - loss: 0.0765 - accuracy: 0.8982 - val_loss: 0.5309 - val_accuracy: 0.4433
# Epoch 4/30
# 537/537 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.8994Restoring model weights from the end of the best epoch: 1.
#
# Epoch 4: saving model to ../weights\inception_resnetv2-model-04.h5
# 537/537 [==============================] - 230s 428ms/step - loss: 0.0950 - accuracy: 0.8994 - val_loss: 0.5634 - val_accuracy: 0.4695
# Epoch 4: early stopping

# %%
plot_history(history)

# %%
y_pred = model.predict(batch_generator(X_val, y_val, 50),
                                 steps=len(y_val) // 50,
                                 verbose=1)
cm = confusion_matrix(y_val, y_pred)
#print('* Accuracy on test set: %0.2f%%' % (100 * te_acc))
# Out:
# 129/129 [==============================] - 27s 207ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19936/3676169316.py in <module>
#       2                                  steps=len(y_val) // 50,
#       3                                  verbose=1)
# ----> 4 cm = confusion_matrix(y_val, y_pred)
#       5 #print('* Accuracy on test set: %0.2f%%' % (100 * te_acc))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     297
#     298     """
# --> 299     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     300     if y_type not in ("binary", "multiclass"):
#     301         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
def evaluate(embedding_model, epochs = 0):
    probs,yprob = compute_probs(embedding_model, X_val, y_val)
    fpr, tpr, thresholds, auc = compute_metrics(probs,yprob)
    draw_roc(fpr, tpr, thresholds, auc)
    draw_interdist(embedding_model, epochs)

# %%
def draw_roc(fpr, tpr,thresholds, auc):
    #find threshold
    targetfpr=1e-3
    _, idx = find_nearest(fpr,targetfpr)
    threshold = thresholds[idx]
    recall = tpr[idx]

# %%
def draw_interdist(network, epochs):
    interdist = compute_interdist(network)
    
    data = []
    for i in range(num_classes):
        data.append(np.delete(interdist[i,:],[i]))

    fig, ax = plt.subplots()
    ax.set_title('Evaluating embeddings distance from each other after {0} epochs'.format(epochs))
    ax.set_ylim([0,3])
    plt.xlabel('Classes')
    plt.ylabel('Distance')
    ax.boxplot(data,showfliers=False,showbox=True)
    locs, labels = plt.xticks()
    plt.xticks(locs,np.arange(num_classes))

    plt.show()

# %%
def compute_metrics(probs,yprobs):
    '''
    Returns
        fpr : Increasing false positive rates such that element i is the false positive rate of predictions with score >= thresholds[i]
        tpr : Increasing true positive rates such that element i is the true positive rate of predictions with score >= thresholds[i].
        thresholds : Decreasing thresholds on the decision function used to compute fpr and tpr. thresholds[0] represents no instances being predicted and is arbitrarily set to max(y_score) + 1
        auc : Area Under the ROC Curve metric
    '''
    # calculate AUC
    auc = roc_auc_score(yprobs, probs)
    # calculate roc curve
    fpr, tpr, thresholds = roc_curve(yprobs, probs)
    
    return fpr, tpr, thresholds,auc

# %%
def compute_probs(network,X,Y):
    '''
    Input
        network : current NN to compute embeddings
        X : tensor of shape (m,w,h,1) containing pics to evaluate
        Y : tensor of shape (m,) containing true class
        
    Returns
        probs : array of shape (m,m) containing distances
    
    '''
    m = X.shape[0]
    nbevaluation = int(m*(m-1)/2)
    probs = np.zeros((nbevaluation))
    y = np.zeros((nbevaluation))
    
    #Compute all embeddings for all imgs with current embedding network
    embeddings = embedding_model.predict(X)
    
    k = 0
    
    # For each img in the evaluation set
    for i in range(m):
            # Against all other images
            for j in range(i+1,m):
                # compute the probability of being the right decision : it should be 1 for right class, 0 for all other classes
                probs[k] = -compute_dist(embeddings[i,:],embeddings[j,:])
                if (Y[i]==Y[j]):
                    y[k] = 1
                    #print("{3}:{0} vs {1} : \t\t\t{2}\tSAME".format(i,j,probs[k],k, Y[i], Y[j]))
                else:
                    y[k] = 0
                    #print("{3}:{0} vs {1} : {2}\tDIFF".format(i,j,probs[k],k, Y[i], Y[j]))
                k += 1
    return probs, y

# %%
evaluate(model, epochs = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19936/1005635204.py in <module>
# ----> 1 evaluate(model, epochs = 0)
#
# ~\AppData\Local\Temp/ipykernel_19936/3719634980.py in evaluate(embedding_model, epochs)
#       1 def evaluate(embedding_model, epochs = 0):
# ----> 2     probs,yprob = compute_probs(embedding_model, X_val, y_val)
#       3     fpr, tpr, thresholds, auc = compute_metrics(probs,yprob)
#       4     draw_roc(fpr, tpr, thresholds, auc)
#       5     draw_interdist(embedding_model, epochs)
#
# ~\AppData\Local\Temp/ipykernel_19936/3917420089.py in compute_probs(network, X, Y)
#      10
#      11     '''
# ---> 12     m = X.shape[0]
#      13     nbevaluation = int(m*(m-1)/2)
#      14     probs = np.zeros((nbevaluation))
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
X_val
# Out:
# [('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/10.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/7.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/7.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/46/8.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/46/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/10.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/12.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/13.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/14.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/15.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/16.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/47/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/47/18.png',
# ...
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/17.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/18.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/19.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/2.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/20.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/3.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/4.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/5.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/6.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/7.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/7.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/5/8.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/5/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/10.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/1.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/11.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/5.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/6.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/7.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/8.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/10.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/9.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/12.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/13.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/14.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/15.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/16.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/17.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/18.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/19.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/2.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/20.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/3.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/4.png'),
#  ('../datasets/signatures_full/train/genuine/genuine_person/50/11.png',
#   '../datasets/signatures_full/train/genuine/genuine_person/50/5.png'),
#  ...]
