# %% [markdown]
# # Capstone: Signature Forgery Detection

# %% [markdown]
# ## Folder Organization
# ```
# |__ code
# |   |__ 01_preprocessing_eda.ipynb
# |   |__ 02_modeling.ipynb
# |__ datasets
# |   |__ train.csv
# |   |__ test.csv
# |__ visualizations
# |   |__ gif_frames
# |   |__ gif_frames2
# |__ slides
# |   |__ signature_authentication.pdf
# |__ README.md
# ```

# %% [markdown]
# # Table of Contents
# * [Background](#Background)
# * [Problem Statement](#Problem-Statement)
# * [Data](#Data)
# * [Methodology](#Methodology)
# * [Function](#Function)
# * [Import Libraries](#Import-Libraries)
# * [Preview Sample Images](#Preview-Sample-Images)
# * [Preprocessing Images](#Preprocessing-Images)
# * [Group Images into Categories](#Group-Images-into-Categories)

# %% [markdown]
# ## Background
# Handwritten signatures have long been used as a form of biometric technique frequently used for personal identification.
#
# ### Use Cases
# Signature verification is useful across many domains. Let’s explore a set of common use cases.
#
# #### Banking Check Signature Verification
#
# Banking institutions typically have to verify that a submitted check was authorized by the associated account owner. To achieve this, they rely on matching the signature in the check to a signature they have on file for the account owner.
#
# #### Administrative Documents
#
# Formal administrative documents such as memos, letters, memorandas, etc. frequently bear the signature of their authors as a proof of authorship. In some cases, it is useful to automatically verify these signatures.
#
# #### Legal Contracts
#
# Legal contracts (e.g., the sale or lease of property) typically become binding with the provision of signatures from each participating entity. Across the lifetime of these contracts (extensions, renewals, suspensions events, etc.), it may be useful to ensure that the expected parties are privy to each of these events and their identities verified.
#
# Beyond security applications, ASV opens up new opportunities for organisations seeking to automatically group, catalog, and search their documents based on signatures or identities (e.g., “show me all documents signed by a given entity”).

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# --type here--

# %% [markdown]
# ## Data
# Handwritten Signatures: [(source)](https://www.kaggle.com/divyanshrai/handwritten-signatures)<br>
# Dataset contains signatures of 50 people, 20 genuine signatures and forged signatures per person. In total, there are 1,100 genuine signatures and 1,100 forged signatures.

# %% [markdown]
# ## Methodology
#
# --type here--

# %% [markdown]
# ## Functions

# %%
def normalize_image(img, size=(900, 1800)):
    """ Centers an image in a pre-defined canvas size, and remove
    noise using OTSU's method.
    :param img: The image to be processed
    :param size: The desired canvas size
    :return: The normalized image
    """

    max_r, max_c = size

    # 1) Crop the image before getting the center of mass

    # Apply a gaussian filter on the image to remove small components
    # Note: this is only used to define the limits to crop the image
    blur_radius = 2
    blurred_image = ndimage.gaussian_filter(img, blur_radius)


    # Binarize the image using OTSU's algorithm. This is used to find the center
    # of mass of the image, and find the threshold to remove background noise
    threshold, binarized_image = cv2.threshold(blurred_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    

    # Find the center of mass
    r, c = np.where(binarized_image == 0)
    r_center = int(r.mean() - r.min())
    c_center = int(c.mean() - c.min())

    # Crop the image with a tight box
    cropped = img[r.min(): r.max(), c.min(): c.max()]

    # 2) Center the image
    img_r, img_c = cropped.shape

    r_start = max_r // 2 - r_center
    c_start = max_c // 2 - c_center

    # Make sure the new image does not go off bounds
    # Case 1: image larger than required (height):  Crop.
    # Emit a warning since we don't want this for the signatures in the WD dataset (OK for feature wi)
    if img_r > max_r:
        print ('Warning: cropping image. The signature should be smaller than the canvas size')
        r_start = 0
        difference = img_r - max_r
        crop_start = difference // 2
        cropped = cropped[crop_start:crop_start + max_r, :]
        img_r = max_r
    else:
        extra_r = (r_start + img_r) - max_r
        # Case 2: centering exactly would require a larger image. relax the centering of the image
        if extra_r > 0:
            r_start -= extra_r
        if r_start < 0:
            r_start = 0

    # Case 2: image larger than required (width). Crop.
    if img_c > max_c:
        print ('Warning: cropping image. The signature should be smaller than the canvas size')
        c_start = 0
        difference = img_c - max_c
        crop_start = difference // 2
        cropped = cropped[:, crop_start:crop_start + max_c]
        img_c = max_c
    else:
        extra_c = (c_start + img_c) - max_c
        if extra_c > 0:
            c_start -= extra_c
        if c_start < 0:
            c_start = 0

    normalized_image = np.ones((max_r, max_c), dtype=np.uint8) * 255
    # Add the image to the blank canvas
    normalized_image[r_start:r_start + img_r, c_start:c_start + img_c] = cropped

    # Remove noise - anything higher than the threshold. Note that the image is still grayscale
    normalized_image[normalized_image > threshold] = 255

    return normalized_image

# %%
def remove_background(img):
        """ Remove noise using OTSU's method.
        :param img: The image to be processed
        :return: The normalized image
        """

        img = img.astype(np.uint8)
        # Binarize the image using OTSU's algorithm. This is used to find the center
        # of mass of the image, and find the threshold to remove background noise
        threshold, _ = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

        # Remove noise - anything higher than the threshold. Note that the image is still grayscale
        img[img > threshold] = 255

        return img

# %%
def resize_image(image, new_size, interpolation='bilinear'):
    """ Crops an image to the desired size without stretching it.
    :param image: The image to be cropped
    :param new_size: The desired size
    :param interpolation: The interpolation method ('nearest', 'bilinear', 'bicubic')
    :return: The cropped image
    """
    height, width = new_size

    # Check which dimension needs to be cropped
    # (assuming the new height-width ratio may not match the original size)
    width_ratio = float(image.shape[1]) / width
    height_ratio = float(image.shape[0]) / height
    if width_ratio > height_ratio:
        resize_height = height
        resize_width = int(round(image.shape[1] / height_ratio))
    else:
        resize_width = width
        resize_height = int(round(image.shape[0] / width_ratio))

    # Resize the image (will still be larger than new_size in one dimension)
    image = resize(image.astype(np.float32), (resize_height, resize_width), 1)
    
    #image = image.astype(np.float32)

    #size = (np.dot(resize_height, resize_width) * 0.99999).astype(float)
    #image  = resize(image, size, 3)
    
    #image= np.resize(image,(IMG_HEIGHT,IMG_WIDTH,3))
    
    #im = Image.fromarray(image)
    #size = tuple(np.array([resize_height, resize_width]) * 0.99999)
    #image = np.array(Image.fromarray(im).resize(size=size))

    # Crop to exactly the desired new_size, using the middle of the image:
    if width_ratio > height_ratio:
        start = int(round((resize_width-width)/2.0))
        return image[:, start:start + width]
    else:
        start = int(round((resize_height-height)/2.0))
        return image[start:start+height, :]

# %%
def crop_center(img, input_shape):
    img_shape = img.shape
    start_y = (img_shape[0] - input_shape[0]) // 2
    start_x = (img_shape[1] - input_shape[1]) // 2
    cropped = img[start_y: start_y + input_shape[0], start_x:start_x + input_shape[1]]
    return cropped

# %%
def process_and_save(read_folder, read_folder2):
    inPath ="../datasets/Dataset/" + read_folder + '/' + read_folder2
    
    # path of the folder that will contain the modified image
    outPath ="../datasets/Dataset/" + read_folder + '/' + read_folder2 
    
    for imagePath in os.listdir(inPath):
        # imagePath contains name of the image 
        inputPath = os.path.join(inPath, imagePath)
        # inputPath contains the full directory name
        img = cv2.imread(inputPath)
        fullOutPath = os.path.join(outPath, imagePath)
        # fullOutPath contains the path of the output
        # image that needs to be generated
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # grayscale
        normalized = 255 - normalize_image(img, size=(350, 350))
        resized = resize_image(normalized, (155, 220))
        cropped = crop_center(resized, (155, 220))
        img = 255 - cropped
        cv2.imwrite(fullOutPath, img)
        print(fullOutPath)

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import os
np.random.seed(42)

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Preview Sample Images

# %% [markdown]
# ### Genuine Signatures

# %%
# Preview sample images - genuine
plt.figure(figsize=(20,20))

# Defining the image directory
image_dir='../datasets/dataset1/real'

# Extracting 5 random images
for x in range(5):
    file = random.choice(os.listdir(image_dir))
    image_path= os.path.join(image_dir, file)
    image=mpimg.imread(image_path)
    ax=plt.subplot(1,5,x+1)
    ax.title.set_text(file)
    plt.imshow(image, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13564/829298464.py in <module>
#       7 # Extracting 5 random images
#       8 for x in range(5):
# ----> 9     file = random.choice(os.listdir(image_dir))
#      10     image_path= os.path.join(image_dir, file)
#      11     image=mpimg.imread(image_path)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../datasets/dataset1/real'

# %% [markdown]
# ### Forged Signatures

# %%
# Preview sample images - forged
# Image size
plt.figure(figsize=(20,20))

# Defining the image directory
image_dir='../datasets/Dataset/dataset1/forge'

# Extracting 5 random images
for x in range(5):
    file = random.choice(os.listdir(image_dir))
    image_path= os.path.join(image_dir, file)
    image=mpimg.imread(image_path)
    ax=plt.subplot(1,5,x+1)
    ax.title.set_text(file)
    plt.imshow(image, cmap='gray')

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Preprocessing Images

# %% [markdown]
# ### Preprocess One Image

# %%
img = cv2.imread('../datasets/Dataset/dataset1/real/00100001.png')
plt.imshow(img, cmap='gray');

# %% [markdown]
# Image shape is 3 Dimensional

# %%
img.shape
# Out:
# (155, 220, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # grayscale
normalized = 255 - normalize_image(img, size=(350, 350))
resized = resize_image(normalized, (155, 220))
cropped = crop_center(resized, (155, 220))
img = 255 - cropped

# %% [markdown]
# Shape is now 2 dimenional as image is converted to grayscale.

# %%
img.shape
# Out:
# (155, 220)

# %%
# show preprocessed image
plt.imshow(img, cmap='gray');

# %% [markdown]
# ### Preprocess Multiple Images

# %% [markdown]
# #### Train Images

# %%
process_and_save('dataset1', 'real')
# Out:
# ../datasets/Dataset_Signature_Final/dataset1/real\00100001.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00101001.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00102001.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00103001.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00104001.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00200002.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00201002.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00202002.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00203002.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00204002.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00300003.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00301003.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00302003.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00303003.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00304003.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00400004.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00401004.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00402004.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00403004.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00404004.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00500005.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00501005.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00502005.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00503005.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00504005.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00600006.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00601006.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00602006.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00603006.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00604006.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00700007.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00701007.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00702007.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00703007.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00704007.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00800008.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00801008.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00802008.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00803008.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00804008.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00900009.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00901009.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00902009.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00903009.png
# ../datasets/Dataset_Signature_Final/dataset1/real\00904009.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01000010.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01001010.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01002010.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01003010.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01004010.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01100011.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01101011.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01102011.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01103011.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01104011.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01200012.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01201012.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01202012.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01203012.png
# ../datasets/Dataset_Signature_Final/dataset1/real\01204012.png

# %%
process_and_save('dataset1', 'forge')
# Out:
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100001.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100002.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100003.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100004.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100005.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100006.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100007.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100008.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100009.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100010.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100011.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02100012.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101001.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101002.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101003.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101004.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101005.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101006.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101007.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101008.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101009.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101010.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101011.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02101012.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102001.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102002.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102003.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102004.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102005.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102006.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102007.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102008.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102009.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102010.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102011.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02102012.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103001.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103002.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103003.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103004.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103005.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103006.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103007.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103008.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103009.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103010.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103011.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02103012.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104001.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104002.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104003.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104004.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104005.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104006.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104007.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104008.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104009.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104010.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104011.png
# ../datasets/Dataset_Signature_Final/dataset1/forge\02104012.png

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)
