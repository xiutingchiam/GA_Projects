# %% [markdown]
# # Capstone: Signature Verification

# %% [markdown]
# # Notebook 1: Pre-processing

# %% [markdown]
# ## Folder Organization
# ```
# Capstone/
# |__ README.md
# |__ code/
# |   |__ 01_preprocessing.ipynb
# |   |__ 02_modeling.ipynb
# |__ datasets/
# |   |__ train/
# |   |  |__forged/
# |   |  |   |__forged_person/
# |   |  |__genuine/
# |   |      |__genuine_person/
# |   |__ test/
# |__ images/
# |   |__ forged_signature.png
# |   |__ genuine_signature.png
# |__ weights/
# |   |
# |__ slides/
#     |__ signature_authentication.pdf
# ```

# %% [markdown]
# # Table of Contents
# * [Background](#Background)
# * [Problem Statement](#Problem-Statement)
# * [Data](#Data)
# * [Methodology](#Methodology)
# * [Import Libraries](#Import-Libraries)
# * [Function](#Function)
# * [Preview Sample Images](#Preview-Sample-Images)
# * [Preprocessing Images](#Preprocessing-Images)
# * [Group Images into Categories](#Group-Images-into-Categories)

# %% [markdown]
# ## Background
# Handwritten signatures have long been used as a form of biometric technique frequently used for personal identification and verification. Many documents like bank checks and legal transactions require signature verification and traditional ways of going through signature-based documents and verifying signatures at a large scale is a very difficult and time consuming task.
#
# ### Use Cases
# Signature verification is useful across many domains. Let’s explore a set of common use cases.
#
# <b>Banking Check:</b> Banking institutions typically have to verify that a submitted check was authorized by the associated account owner, by matching the signature in the check to a signature they have on file for the account owner.
#
# <b>Administrative Documents:</b> Formal administrative documents such as memos, letters, memorandas, etc. frequently bear the signature of their authors as a proof of authorship.
#
# <b>Legal Contracts:</b> Legal contracts (e.g. lease of property, business contracts) typically become binding with the provision of signatures from each participating entity.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Handwritten signatures are very important in our social and legal life for verification and authentication. However, detecting a signature forgery (especially skilled forgeries) is a challenging task as no two signatures made by the same person are exactly the same.
#
# To resolve this problem, we want to build a model that can detect forgery that might be very similar in case of skilled forgeries, while accounting for the below variations in genuine signatures and establish the authenticity of a signature.
# - Variability due to different pens used
# - Variability arising out of the fact that “No two signatures of the same person are exactly- same” , and
# - Noisy background of signatures, eg. stamp, signature positioning, size difference
#
# We will use accuracy and as a metric to select the best model for this problem statement.

# %% [markdown]
# ## Dataset
# <b>Handwritten Signatures: </b> [(source)](https://www.kaggle.com/divyanshrai/handwritten-signatures)<br>
# Dataset contains signatures of 55 people, 20 genuine signatures and forged signatures per person. In total, there are 1,100 genuine signatures and 1,100 forged signatures.

# %% [markdown]
# ## Methodology
# 1. Preview and examine image data.
# 2. Pre-process images.
# 3. Prepare data by creating lists of genuine and forged signatures and binary classification labels.
# 4. Explore and visualize data for data distribution, shape and labels.
# 5. Create pairs of genuine-genuine and genuine-forged signatures.
# 6. Create batches of pair signatures for modeling
# 7. Use deep learning to train data
# 8. Predict test data using the best epoch model and predict class labels using threshold of euclidean distance.
# 9. Evaluate models.

# %% [markdown]
# ## Import Libraries

# %%
# Basics
import itertools
from scipy import ndimage
import matplotlib.image as mpimg
import cv2
from skimage.transform import resize
import random
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(42)

# Image processing

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Functions

# %%
def normalize_image(img, size=(900, 1800)):
    """ Centers an image in a pre-defined canvas size, and remove
    noise using OTSU's method.
    :param img: The image to be processed
    :param size: The desired canvas size
    :return: The normalized image
    """

    max_r, max_c = size

    # 1) Crop the image before getting the center of mass

    # Apply a gaussian filter on the image to remove small components
    # Note: this is only used to define the limits to crop the image
    blur_radius = 2
    blurred_image = ndimage.gaussian_filter(img, blur_radius)

    # Binarize the image using OTSU's algorithm. This is used to find the center
    # of mass of the image, and find the threshold to remove background noise
    threshold, binarized_image = cv2.threshold(
        blurred_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Find the center of mass
    r, c = np.where(binarized_image == 0)
    r_center = int(r.mean() - r.min())
    c_center = int(c.mean() - c.min())

    # Crop the image with a tight box
    cropped = img[r.min(): r.max(), c.min(): c.max()]

    # 2) Center the image
    img_r, img_c = cropped.shape

    r_start = max_r // 2 - r_center
    c_start = max_c // 2 - c_center

    # Make sure the new image does not go off bounds
    # Case 1: image larger than required (height):  Crop.
    # Emit a warning since we don't want this for the signatures in the WD dataset (OK for feature wi)
    if img_r > max_r:
        print('Cropping image. The signature should be smaller than the canvas size.')
        r_start = 0
        difference = img_r - max_r
        crop_start = difference // 2
        cropped = cropped[crop_start:crop_start + max_r, :]
        img_r = max_r
    else:
        extra_r = (r_start + img_r) - max_r
        # Case 2: centering exactly would require a larger image. relax the centering of the image
        if extra_r > 0:
            r_start -= extra_r
        if r_start < 0:
            r_start = 0

    # Case 2: image larger than required (width). Crop.
    if img_c > max_c:
        print('Cropping image. The signature should be smaller than the canvas size.')
        c_start = 0
        difference = img_c - max_c
        crop_start = difference // 2
        cropped = cropped[:, crop_start:crop_start + max_c]
        img_c = max_c
    else:
        extra_c = (c_start + img_c) - max_c
        if extra_c > 0:
            c_start -= extra_c
        if c_start < 0:
            c_start = 0

    normalized_image = np.ones((max_r, max_c), dtype=np.uint8) * 255
    # Add the image to the blank canvas
    normalized_image[r_start:r_start + img_r,
                     c_start:c_start + img_c] = cropped

    # Remove noise - anything higher than the threshold. Note that the image is still grayscale
    normalized_image[normalized_image > threshold] = 255

    return normalized_image

# %%
def remove_background(img):

    img = img.astype(np.uint8)
    # Binarize the image using OTSU's algorithm. This is used to find the center
    # of mass of the image, and find the threshold to remove background noise
    threshold, _ = cv2.threshold(
        img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Remove noise - anything higher than the threshold. Note that the image is still grayscale
    img[img > threshold] = 255

    return img

# %%
def resize_image(image, new_size, interpolation='bilinear'):
    """ Crops an image to the desired size without stretching it.
    :param image: The image to be cropped
    :param new_size: The desired size
    :param interpolation: The interpolation method ('nearest', 'bilinear', 'bicubic')
    :return: The cropped image
    """
    height, width = new_size

    # Check which dimension needs to be cropped
    # (assuming the new height-width ratio may not match the original size)
    width_ratio = float(image.shape[1]) / width
    height_ratio = float(image.shape[0]) / height
    if width_ratio > height_ratio:
        resize_height = height
        resize_width = int(round(image.shape[1] / height_ratio))
    else:
        resize_width = width
        resize_height = int(round(image.shape[0] / width_ratio))

    # Resize the image (will still be larger than new_size in one dimension)
    image = resize(image.astype(np.float32), (resize_height, resize_width), 1)

    # Crop to exactly the desired new_size, using the middle of the image:
    if width_ratio > height_ratio:
        start = int(round((resize_width-width)/2.0))
        return image[:, start:start + width]
    else:
        start = int(round((resize_height-height)/2.0))
        return image[start:start+height, :]

# %%
def crop_center(img, input_shape):
    img_shape = img.shape
    start_y = (img_shape[0] - input_shape[0]) // 2
    start_x = (img_shape[1] - input_shape[1]) // 2
    cropped = img[start_y: start_y + input_shape[0],
                  start_x:start_x + input_shape[1]]
    return cropped

# %%
def process_and_save(read_folder, read_folder2):
    inPath = "../datasets/" + read_folder + '/' + read_folder2

    # path of the folder that will contain the modified image
    outPath = "../datasets/" + read_folder + '/' + read_folder2

    for imagePath in os.listdir(inPath):
        # imagePath contains name of the image
        inputPath = os.path.join(inPath, imagePath)
        # inputPath contains the full directory name
        img = cv2.imread(inputPath)
        fullOutPath = os.path.join(outPath, imagePath)
        # fullOutPath contains the path of the output
        # image that needs to be generated
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # grayscale
        normalized = 255 - normalize_image(img, size=(900, 900))
        resized = resize_image(normalized, (150, 150))
        cropped = crop_center(resized, (150, 150))
        img = 255 - cropped
        cv2.imwrite(fullOutPath, img)
        print(fullOutPath)

# %%
def process_and_save_test(read_folder, read_folder2):
    inPath = "../datasets/" + read_folder + '/' + read_folder2

    # path of the folder that will contain the modified image
    outPath = "../datasets/" + read_folder + '/' + read_folder2

    for imagePath in os.listdir(inPath):
        # imagePath contains name of the image
        inputPath = os.path.join(inPath, imagePath)
        # inputPath contains the full directory name
        img = cv2.imread(inputPath)
        fullOutPath = os.path.join(outPath, imagePath)
        # fullOutPath contains the path of the output
        # image that needs to be generated
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # grayscale
        normalized = 255 - normalize_image(img, size=(1500, 1500))
        resized = resize_image(normalized, (150, 150))
        cropped = crop_center(resized, (150, 150))
        img = 255 - cropped
        cv2.imwrite(fullOutPath, img)
        print(fullOutPath)

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Preview Sample Images
# A few things can be noted below:
# - The background of genuine signature images is darker than that of the forged signatures images.
# - Image sizes varies alot.
# - Some signatures are not centralized.
#
# Hence, we have to preprocess the images to standardize them.

# %% [markdown]
# ### Genuine Signatures

# %%
# Preview sample images - genuine
plt.figure(figsize=(20, 20))

# Defining the image directory
image_dir = '../datasets/train/genuine'

# Extracting 5 random images
for x in range(5):
    file = random.choice(os.listdir(image_dir))
    image_path = os.path.join(image_dir, file)
    image = mpimg.imread(image_path)
    ax = plt.subplot(1, 5, x+1)
    ax.title.set_text(file)
    plt.imshow(image, cmap='gray')

# %% [markdown]
# ### Forged Signatures

# %%
# Preview sample images - forged
# Image size
plt.figure(figsize=(20, 20))

# Defining the image directory
image_dir = '../datasets/train/forged'

# Extracting 5 random images
for x in range(5):
    file = random.choice(os.listdir(image_dir))
    image_path = os.path.join(image_dir, file)
    image = mpimg.imread(image_path)
    ax = plt.subplot(1, 5, x+1)
    ax.title.set_text(file)
    plt.imshow(image, cmap='gray')

# %% [markdown]
# Below is an example where background of images were not removed (same dataset that we are using) before models were trained on it. Model accuracy can easily be more than 99%, as it would be easy to get an accurate prediction based on the background. e.g. darker background for genuine signatures and lighter background for forged signatures. p(https://github.com/Aftaab99/OfflineSignatureVerification)

# %% [markdown]
# <table>
#   <tr>
#     <td><img src="../images/genuine_signature.png" width=450 height=480></td>
#     <td><img src="../images/forged_signature.png" width=450 height=480></td>
#   </tr>
#  </table>

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Preprocessing Images

# %% [markdown]
# Signature images are standardized through preprocessing steps as below
# Each signature image is preprocessed as per below steps:
# 1. Shape is changed from 3 channels (RGB) to single channel (grayscale)
# 2. Gaussian filter is applied on the image to remove noise / small components
# 3. Centers an image on a pre-defined canvas size
# 4. Image is cropped to a pre-defined size without stretching it. eg. (150, 150)

# %% [markdown]
# ### Preprocess One Image
# Displays how a single signature image is is pre-processed.

# %%
img = cv2.imread('../datasets/train/genuine/Original_8_19.png')
plt.imshow(img, cmap='gray')

# %% [markdown]
# Image shape is 3 Dimensional

# %%
img.shape
# Out:
# (427, 528, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # grayscale
normalized = 255 - normalize_image(img, size=(900, 900))
resized = resize_image(normalized, (150, 150))
cropped = crop_center(resized, (150, 150))
img = 255 - cropped

# %% [markdown]
# Shape is now 2 dimenional as image is converted to grayscale.

# %%
img.shape
# Out:
# (150, 150)

# %%
# show preprocessed image
plt.imshow(img, cmap='gray')

# %% [markdown]
# ### Preprocess Multiple Images

# %% [markdown]
# #### Train Images

# %% [markdown]
# `process_and_save` function is executed on all train genuine and forged signature images, and these preprocessed images will replace the old images in the same directory.

# %%
process_and_save('train', 'genuine')
# Out:
# ../datasets/signatures_full/train/genuine\original_10_1.png
# ../datasets/signatures_full/train/genuine\original_10_10.png
# ../datasets/signatures_full/train/genuine\original_10_11.png
# ../datasets/signatures_full/train/genuine\original_10_12.png
# ../datasets/signatures_full/train/genuine\original_10_13.png
# ../datasets/signatures_full/train/genuine\original_10_14.png
# ../datasets/signatures_full/train/genuine\original_10_15.png
# ../datasets/signatures_full/train/genuine\original_10_16.png
# ../datasets/signatures_full/train/genuine\original_10_17.png
# ../datasets/signatures_full/train/genuine\original_10_18.png
# ../datasets/signatures_full/train/genuine\original_10_19.png
# ../datasets/signatures_full/train/genuine\original_10_2.png
# ../datasets/signatures_full/train/genuine\original_10_20.png
# ../datasets/signatures_full/train/genuine\original_10_3.png
# ../datasets/signatures_full/train/genuine\original_10_4.png
# ...

# %%
process_and_save('train', 'forged')
# Out:
# ../datasets/signatures_full/train/forged\forgeries_10_1.png
# ../datasets/signatures_full/train/forged\forgeries_10_10.png
# ../datasets/signatures_full/train/forged\forgeries_10_11.png
# ../datasets/signatures_full/train/forged\forgeries_10_12.png
# ../datasets/signatures_full/train/forged\forgeries_10_13.png
# ../datasets/signatures_full/train/forged\forgeries_10_14.png
# ../datasets/signatures_full/train/forged\forgeries_10_15.png
# ../datasets/signatures_full/train/forged\forgeries_10_16.png
# ../datasets/signatures_full/train/forged\forgeries_10_17.png
# ../datasets/signatures_full/train/forged\forgeries_10_18.png
# ../datasets/signatures_full/train/forged\forgeries_10_19.png
# ../datasets/signatures_full/train/forged\forgeries_10_2.png
# ../datasets/signatures_full/train/forged\forgeries_10_20.png
# ../datasets/signatures_full/train/forged\forgeries_10_3.png
# ../datasets/signatures_full/train/forged\forgeries_10_4.png
# ...

# %% [markdown]
# #### Test Images
# `process_and_save_test` function is executed on all test genuine and forged signature images, and these preprocessed images will replace the old images in the same directory.

# %%
process_and_save_test('test', 'genuine')
# Out:
# ../datasets/signatures_full/test/genuine\original_1_1.png
# ../datasets/signatures_full/test/genuine\original_1_2.png
# ../datasets/signatures_full/test/genuine\original_1_3.png
# ../datasets/signatures_full/test/genuine\original_1_4.png
# ../datasets/signatures_full/test/genuine\original_1_5.png
# ../datasets/signatures_full/test/genuine\original_2_1.png
# ../datasets/signatures_full/test/genuine\original_2_2.png
# ../datasets/signatures_full/test/genuine\original_2_3.png
# ../datasets/signatures_full/test/genuine\original_2_4.png
# ../datasets/signatures_full/test/genuine\original_2_5.png
# ../datasets/signatures_full/test/genuine\original_3_1.png
# ../datasets/signatures_full/test/genuine\original_3_2.png
# ../datasets/signatures_full/test/genuine\original_3_3.png
# ../datasets/signatures_full/test/genuine\original_3_4.png
# ../datasets/signatures_full/test/genuine\original_3_5.png
# ../datasets/signatures_full/test/genuine\original_4_1.png
# ...

# %%
process_and_save_test('test', 'forged')
# Out:
# ../datasets/signatures_full/test/forged\forgeries_1_1.png
# ../datasets/signatures_full/test/forged\forgeries_1_2.png
# ../datasets/signatures_full/test/forged\forgeries_1_3.png
# ../datasets/signatures_full/test/forged\forgeries_1_4.png
# ../datasets/signatures_full/test/forged\forgeries_1_5.png
# ../datasets/signatures_full/test/forged\forgeries_2_1.png
# ../datasets/signatures_full/test/forged\forgeries_2_2.png
# ../datasets/signatures_full/test/forged\forgeries_2_3.png
# ../datasets/signatures_full/test/forged\forgeries_2_4.png
# ../datasets/signatures_full/test/forged\forgeries_2_5.png
# ../datasets/signatures_full/test/forged\forgeries_3_1.png
# ../datasets/signatures_full/test/forged\forgeries_3_2.png
# ../datasets/signatures_full/test/forged\forgeries_3_3.png
# ../datasets/signatures_full/test/forged\forgeries_3_4.png
# ../datasets/signatures_full/test/forged\forgeries_3_5.png
# ../datasets/signatures_full/test/forged\forgeries_4_1.png
# ...

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)

# %% [markdown]
# ## Group Images into Categories
# Signature image files are renamed and grouped into subfolders in genuine_person or forged_person folders, according to the index number of a single person. E.g. Genuine signature images of person number 1 will be moved to `'../datasets/signature_full/train/genuine/genuine_person/1/'`, while forged signature images of person number 1 will be moved to `'../datasets/signature_full/train/forged/forged_person/1/'`.

# %% [markdown]
# ### Group Train Signatures

# %% [markdown]
# #### Genuine Signatures

# %%
from collections import defaultdict
path = '../datasets/train/genuine'
list_name = []
for root, dirs, files in os.walk(path):
    list_name.extend(files)

dic = defaultdict(list)

for i in list_name:
    filename, ext = os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic[group].append(img_index)

# %%
# create a sub_directory called genuine_person inside the genuine directory
directory = 'genuine_person'
parent_dir = '../datasets/train/genuine'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
# group every signature from each individual in one folder
import shutil
new_folder = '../datasets/train/genuine/genuine_person'
path = '../datasets/signatures_full/train/genuine'

for i in dic:
    if not os.path.exists(os.path.join(new_folder, i)):
        os.mkdir(os.path.join(new_folder, i))
        for img in dic[i]:
            old_image = os.path.join(path, 'original_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)

            # Recursively moves a file or directory to another location and returns the destination.
            shutil.move(old_image, os.path.join(new_path, new_image))
            # If the destination directory already exists then src is moved inside that directory.

    else:
        for img in dic[i]:
            old_image = os.path.join(path, 'original_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)
            print(new_path)
            shutil.move(old_image, os.path.join(new_path, new_image))

# %% [markdown]
# #### Forged Signatures

# %%
from collections import defaultdict
path = '../datasets/train/forged'
list_name = []
for root, dirs, files in os.walk(path):
    list_name.extend(files)
# Does not raise KeyError. It provides a default value for the key that does not exists

dic = defaultdict(list)


for i in list_name:
    filename, ext = os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic[group].append(img_index)

# %%
# create a sub_directory called forged_person inside the forged directory if folder does not exist
directory = 'forged_person'
parent_dir = '../datasets/train/forged'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
# group every signature from each individual in one folder
import shutil
new_folder = '../datasets/train/forged/forged_person'
path = '../datasets/train/forged'

for i in dic:
    if not os.path.exists(os.path.join(new_folder, i)):
        os.mkdir(os.path.join(new_folder, i))
        for img in dic[i]:
            old_image = os.path.join(
                path, 'forgeries_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)

            # Recursively moves a file or directory to another location and returns the destination.
            shutil.move(old_image, os.path.join(new_path, new_image))
            # If the destination directory already exists then src is moved inside that directory.

    else:
        for img in dic[i]:
            old_image = os.path.join(
                path, 'forgeries_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)
            print(new_path)
            shutil.move(old_image, os.path.join(new_path, new_image))

# %% [markdown]
# ### Group Test Signatures

# %% [markdown]
# #### Genuine Signatures

# %%
from collections import defaultdict
path = '../datasets/test/genuine'
list_name = []
for root, dirs, files in os.walk(path):
    list_name.extend(files)

dic = defaultdict(list)

for i in list_name:
    filename, ext = os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic[group].append(img_index)

# %%
# create a sub_directory called genuine_person inside the genuine directory
directory = 'genuine_person'
parent_dir = '../datasets/test/genuine'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
# group every signature from each individual in one folder
import shutil
new_folder = '../datasets/test/genuine/genuine_person'
path = '../datasets/test/genuine'

for i in dic:
    if not os.path.exists(os.path.join(new_folder, i)):
        os.mkdir(os.path.join(new_folder, i))
        for img in dic[i]:
            old_image = os.path.join(path, 'original_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)

            # Recursively moves a file or directory to another location and returns the destination.
            shutil.move(old_image, os.path.join(new_path, new_image))
            # If the destination directory already exists then src is moved inside that directory.

    else:
        for img in dic[i]:
            old_image = os.path.join(path, 'original_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)
            print(new_path)
            shutil.move(old_image, os.path.join(new_path, new_image))

# %% [markdown]
# #### Forged Signatures

# %%
from collections import defaultdict
path = '../datasets/test/forged'
list_name = []
for root, dirs, files in os.walk(path):
    list_name.extend(files)
# Does not raise KeyError. It provides a default value for the key that does not exists

dic = defaultdict(list)

for i in list_name:
    filename, ext = os.path.splitext(i)
    cat, group, img_index = filename.split('_')
    dic[group].append(img_index)

# %%
# create a sub_directory called forged_person inside the forged directory if folder does not exist
directory = 'forged_person'
parent_dir = '../datasets/test/forged'
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.makedirs(path)

# %%
# group every signature from each individual in one folder
import shutil
new_folder = '../datasets/test/forged/forged_person'
path = '../datasets/test/forged'

for i in dic:
    if not os.path.exists(os.path.join(new_folder, i)):
        os.mkdir(os.path.join(new_folder, i))
        for img in dic[i]:
            old_image = os.path.join(
                path, 'forgeries_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)

            # Recursively moves a file or directory to another location and returns the destination.
            shutil.move(old_image, os.path.join(new_path, new_image))
            # If the destination directory already exists then src is moved inside that directory.

    else:
        for img in dic[i]:
            old_image = os.path.join(
                path, 'forgeries_{}_{}.png'.format(i, img))
            new_image = r'{}.png'.format(img)
            new_path = os.path.join(new_folder, i)
            print(new_path)
            shutil.move(old_image, os.path.join(new_path, new_image))

# %% [markdown]
# [[Back to Table of Contents]](#Table-of-Contents)
