# %% [markdown]
# # Modeling

# %% [markdown]
# ## Import Libraries

# %%
# Basics
import re
import os
import numpy as np
import itertools  
import random
import argparse
np.random.seed(42)
from pysb import *
from pysb.integrate import odesolve

# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.image as mpimg
# %matplotlib inline

# Image processing
import cv2
from scipy import ndimage
from skimage.transform import resize
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Tensorflow keras
from tensorflow import keras
from keras import backend as K
from keras.models import Model
from keras import layers, models
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, RMSprop, Adagrad, Adadelta, SGD
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate, Dropout
from tensorflow.keras.layers import (BatchNormalization, SeparableConv2D, MaxPooling2D, GlobalAveragePooling2D,
                                     Activation, Flatten, Dropout, Dense, Lambda)

# Sklearn metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from skimage.metrics import structural_similarity
from sklearn.metrics import plot_confusion_matrix
from sklearn.utils import shuffle

# Connect to gpu
import tensorflow as tf
from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
from tensorflow.python.client import device_lib
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8130681399412766681
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3667263488
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15732677985009347048
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ## Functions

# %%
def mse(A, B):
    """
        Computes Mean Squared Error between two images. (A and B)      
        Arguments:
            A: numpy array
            B: numpy array
        Returns:
            err: float
    """
    # sigma(1, n-1)(a-b)^2)
    err = np.sum((A - B) ** 2)

    # mean of the sum (r,c) => total elements: r*c
    err /= float(A.shape[0] * B.shape[1])

    return err


def ssim(A, B):
    """
        Computes SSIM between two images.

        Arguments:
            A: numpy array
            B: numpy array

        Returns:
            score: float
    """
    return structural_similarity(A, B)

# %%
def visualize_signatures():

    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 10))

    k = np.random.randint(len(genuine_train))

    genuine_img_names = random.sample(genuine_train[k], 2)
    forged_img_name = random.sample(forged_train[k], 1)

    # read images using open cv module
    genuine_img1 = cv2.imread(genuine_img_names[0], 0)
    genuine_img2 = cv2.imread(genuine_img_names[1], 0)
    forged_img1 = plt.imread(forged_img_name[0], 0)

    # show images
    ax1.imshow(genuine_img1, cmap='gray')
    ax2.imshow(genuine_img2, cmap='gray')
    ax3.imshow(forged_img1, cmap='gray')

    # set title
    ax1.set_title('Genuine')
    ax2.set_title('Genuine')
    ax3.set_title('Forged')

# %% [markdown]
# <b>Generate batches for training</b>

# %%
def generate_batch(orig_groups, forg_groups, batch_size=50):
    '''Function to generate a batch of data with batch_size number of data points
    Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs'''
    while True:
        orig_pairs = []
        forg_pairs = []
        gen_gen_labels = []
        gen_for_labels = []
        all_pairs = []
        all_labels = []

        # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
        # For every person we have 24 genuine signatures, hence we have
        # 20 choose 2 = 190 Genuine-Genuine image pairs for one person.
        # To make Genuine-Forged pairs, we pair every Genuine signature of a person
        # with 20 randomly sampled Forged signatures of the same person.
        # Thus we make 20 * 20 = 400 Genuine-Forged image pairs for one person.
        # In all we have 55 person's data in the training data.
        # Total no. of Genuine-Genuine pairs = 55 * 190 = 10450
        # Total number of Genuine-Forged pairs = 55 * 400 = 22000
        # Total no. of data points = 10450 + 22000 = 32450
        for orig, forg in zip(orig_groups, forg_groups):
            orig_pairs.extend(list(itertools.combinations(orig, 2)))
            for i in range(len(forg)):
                forg_pairs.extend(list(itertools.product(
                    orig[i:i+1], random.sample(forg, 10))))

        # Label for Genuine-Genuine pairs is 1
        # Label for Genuine-Forged pairs is 0
        gen_gen_labels = [1]*len(orig_pairs)
        gen_for_labels = [0]*len(forg_pairs)
        # Concatenate all the pairs together along with their labels and shuffle them
        all_pairs = orig_pairs + forg_pairs
        all_labels = gen_gen_labels + gen_for_labels
        del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
        all_pairs, all_labels = shuffle(all_pairs, all_labels)

        # Note the lists above contain only the image names and
        # actual images are loaded and yielded below in batches
        # Below we prepare a batch of data points and yield the batch
        # In each batch we load "batch_size" number of image pairs
        # These images are then removed from the original set so that
        # they are not added again in the next batch.

        k = 0
        pairs = [np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
        targets = np.zeros((batch_size,))
        for ix, pair in enumerate(all_pairs):
            img1 = cv2.imread(pair[0], 0)
            img2 = cv2.imread(pair[1], 0)
            img1 = cv2.resize(img1, (img_w, img_h))
            img2 = cv2.resize(img2, (img_w, img_h))
            img1 = np.array(img1, dtype=np.float64)
            img2 = np.array(img2, dtype=np.float64)
            img1 /= 255
            img2 /= 255
            img1 = img1[..., np.newaxis]
            img2 = img2[..., np.newaxis]
            pairs[0][k, :, :, :] = img1
            pairs[1][k, :, :, :] = img2
            targets[k] = all_labels[ix]
            k += 1
            if k == batch_size:
                yield pairs, targets
                k = 0
                pairs = [np.zeros((batch_size, img_h, img_w, 1))
                         for i in range(2)]
                targets = np.zeros((batch_size,))

# %%
def generate_test_batch(test_orig_groups, test_forg_groups, batch_size=1):
    '''Function to generate a batch of data with batch_size number of data points
    Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs'''
    while True:
        orig_pairs = []
        forg_pairs = []
        gen_gen_labels = []
        gen_for_labels = []
        all_pairs = []
        all_labels = []

        # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
        # For every person we have 24 genuine signatures, hence we have
        # 20 choose 2 = 190 Genuine-Genuine image pairs for one person.
        # To make Genuine-Forged pairs, we pair every Genuine signature of a person
        # with 20 randomly sampled Forged signatures of the same person.
        # Thus we make 20 * 20 = 400 Genuine-Forged image pairs for one person.
        # In all we have 55 person's data in the training data.
        # Total no. of Genuine-Genuine pairs = 55 * 190 = 10450
        # Total number of Genuine-Forged pairs = 55 * 400 = 22000
        # Total no. of data points = 10450 + 22000 = 32450
        for orig, forg in zip(test_orig_groups, test_forg_groups):
            orig_pairs.extend(list(itertools.combinations(orig, 2)))
            for i in range(len(forg)):
                forg_pairs.extend(list(itertools.product(
                    orig[i:i+1], random.sample(forg, 10))))

        # Label for Genuine-Genuine pairs is 1
        # Label for Genuine-Forged pairs is 0
        gen_gen_labels = [1]*len(orig_pairs)
        gen_for_labels = [0]*len(forg_pairs)
        # Concatenate all the pairs together along with their labels and shuffle them
        all_pairs = orig_pairs + forg_pairs
        all_labels = gen_gen_labels + gen_for_labels
        del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
        all_pairs, all_labels = shuffle(all_pairs, all_labels)

        # Note the lists above contain only the image names and
        # actual images are loaded and yielded below in batches
        # Below we prepare a batch of data points and yield the batch
        # In each batch we load "batch_size" number of image pairs
        # These images are then removed from the original set so that
        # they are not added again in the next batch.

        k = 0
        pairs = [np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
        targets = np.zeros((batch_size,))
        for ix, pair in enumerate(all_pairs):
            img1 = cv2.imread(pair[0], 0)
            img2 = cv2.imread(pair[1], 0)
            img1 = cv2.resize(img1, (img_w, img_h))
            img2 = cv2.resize(img2, (img_w, img_h))
            img1 = np.array(img1, dtype=np.float64)
            img2 = np.array(img2, dtype=np.float64)
            img1 /= 255
            img2 /= 255
            img1 = img1[..., np.newaxis]
            img2 = img2[..., np.newaxis]
            pairs[0][k, :, :, :] = img1
            pairs[1][k, :, :, :] = img2
            targets[k] = all_labels[ix]
            k += 1
            if k == batch_size:
                yield pairs, targets
                k = 0
                pairs = [np.zeros((batch_size, img_h, img_w, 1))
                         for i in range(2)]
                targets = np.zeros((batch_size,))

# %% [markdown]
# <b>Assets for training</b>

# %%
def euclidean_distance(vects):
    '''Compute Euclidean Distance between two vectors'''
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))

# %% [markdown]
# <b>Network Architecture</b>

# %%
def create_base_network_signet(input_shape):
    '''Base Siamese Network'''

    seq = Sequential()
    seq.add(Conv2D(96, kernel_size=(11, 11), activation='relu', name='conv1_1', strides=4, input_shape=input_shape
                   ))
    seq.add(BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3, 3), strides=(2, 2)))
    seq.add(ZeroPadding2D((2, 2)))

    seq.add(Conv2D(256, kernel_size=(5, 5),
            activation='relu', name='conv2_1', strides=1))
    seq.add(BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3, 3), strides=(2, 2)))
    seq.add(Dropout(0.3))  # added extra
    seq.add(ZeroPadding2D((1, 1)))

    seq.add(Conv2D(384, kernel_size=(3, 3),
            activation='relu', name='conv3_1', strides=1))
    seq.add(ZeroPadding2D((1, 1)))

    seq.add(Conv2D(256, kernel_size=(3, 3),
            activation='relu', name='conv3_2', strides=1))
    seq.add(MaxPooling2D((3, 3), strides=(2, 2)))
    seq.add(Dropout(0.3))  # added extra
    seq.add(Flatten(name='flatten'))
    seq.add(Dense(1024, kernel_regularizer=l2(0.0005), activation='relu'))
    seq.add(Dropout(0.5))

    # softmax changed to relu
    seq.add(Dense(128, kernel_regularizer=l2(0.0005), activation='relu'))

    return seq

# %% [markdown]
# <b>Load data in grayscale or rgb<b>

# %%
def load_data(verbose=True, load_grayscale=True):

    features = []
    features_forged = []
    features_real = []
    features_anchor = []
    features_dict = {}
    labels = []  # forged: 0 and real: 1
    mode = 'rgb'
    if load_grayscale:
        mode = 'grayscale'

    for folder in os.listdir('../datasets/signatures_full/train/forged/forged_person'):
        print('Searching folder {}'.format(folder))
        # forged images
        for sub in os.listdir('../datasets/signatures_full/train/forged/forged_person/'+folder):
            f = '../datasets/signatures_full/train/forged/forged_person/' + folder + '/' + sub
            img = load_img(f, color_mode=mode, target_size=(150, 150))
            features.append(img_to_array(img))
            sub = 'forged_'+folder+'_'+sub
            features_dict[sub] = (img, 0)
            features_forged.append(img)
            labels.append(0)  # forged
            print('Adding {} with label 0'.format(f))
    for folder in os.listdir('../datasets/signatures_full/train/genuine/genuine_person'):
        # real images
        for sub in os.listdir('../datasets/signatures_full/train/genuine/genuine_person/'+folder):
            f = '../datasets/signatures_full/train/genuine/genuine_person/' + folder + '/' + sub
            img = load_img(f, color_mode=mode, target_size=(150, 150))
            features.append(img_to_array(img))
            sub = 'genuine_'+folder+'_'+sub
            features_dict[sub] = (img, 1)
            features_real.append(img)
            labels.append(1)  # genuine

    features = np.array(features)
    labels = np.array(labels)
    
    # X = features, y = labels
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.25, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.25, random_state=42)

    return sub, features, labels, features_forged, features_real, features_dict, X_train, X_test, y_train, y_test, X_val, y_val

# %%
def load_test_data(verbose=True, load_grayscale=True):

    features = []
    features_forged = []
    features_real = []
    features_anchor = []
    features_dict = {}
    labels = []  # forged: 0 and real: 1
    mode = 'rgb'
    if load_grayscale:
        mode = 'grayscale'

    for folder in os.listdir('../datasets/signatures_full/test/forged/forged_person'):
        print('Searching folder {}'.format(folder))
        # forged images
        for sub in os.listdir('../datasets/signatures_full/test/forged/forged_person/'+folder):
            f = '../datasets/signatures_full/test/forged/forged_person/' + folder + '/' + sub
            img = load_img(f, color_mode=mode, target_size=(150, 150))
            features.append(img_to_array(img))
            sub = 'forged_'+folder+'_'+sub
            features_dict[sub] = (img, 0)
            features_forged.append(img)
            labels.append(0)  # forged
            print('Adding {} with label 0'.format(f))
    for folder in os.listdir('../datasets/signatures_full/test/genuine/genuine_person'):
        # real images
        for sub in os.listdir('../datasets/signatures_full/test/genuine/genuine_person/'+folder):
            f = '../datasets/signatures_full/test/genuine/genuine_person/' + folder + '/' + sub
            img = load_img(f, color_mode=mode, target_size=(150, 150))
            features.append(img_to_array(img))
            sub = 'genuine_'+folder+'_'+sub
            features_dict[sub] = (img, 1)
            features_real.append(img)
            labels.append(1)  # genuine

    features = np.array(features)
    labels = np.array(labels)
    
    X = features 
    y = labels
    
    return X, y

# %% [markdown]
# <b>Convert labels 0 to 'Forged' and 1 to 'Genuine'</b>

# %%
def convert_label_to_text(label=0):
    return 'Forged' if label == 0 else 'Genuine'

# %%
def compute_accuracy_roc(predictions, labels, plot_far_frr =False):
    '''
    Compute ROC accuracy with a range of thresholds on distances.
    Plot FAR-FRR curves and P-R curves for input data
    '''
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1) #similar
    ndiff = np.sum(labels == 0) #different
    step = 0.01
    max_acc = 0
    best_thresh = -1
    frr_plot = []
    far_plot = []
    pr_plot = []
    re_plot = []
    ds = []
    for d in np.arange(dmin, dmax+step, step):
        idx1 = predictions.ravel() <= d #guessed genuine
        idx2 = predictions.ravel() > d #guessed forged
        tp = float(np.sum(labels[idx1] == 1))
        tn = float(np.sum(labels[idx2] == 0))
        fp = float(np.sum(labels[idx1] == 0))
        fn = float(np.sum(labels[idx2] == 1))
#         print(tp, tn, fp, fn)
        tpr = float(np.sum(labels[idx1] == 1)) / nsame       
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff
        
        
        acc = 0.5 * (tpr + tnr)
        pr = tp / (tp + fp)
        re = tp / (tp + fn)
#       print ('ROC', acc, tpr, tnr)
       
        if (acc > max_acc):
            max_acc, best_thresh = acc, d
        
        #if (fp+tn) != 0.0 and (fn+tp) != 0.0:
        far = fp / (fp + tn)
        frr = fn / (fn + tp)
        frr_plot.append(frr)
        pr_plot.append(pr)
        re_plot.append(re)
        far_plot.append(far)
        ds.append(d)
            
    
    if plot_far_frr:
        fig = plt.figure(figsize = (10,10))
        ax = fig.add_subplot(121)
        ax.plot(ds, far_plot, color = 'red')
        ax.plot(ds, frr_plot, color = 'blue')
        ax.set_title('Error rate')
        ax.legend(['FAR', 'FRR'])
        ax.set(xlabel = 'Thresholds', ylabel = 'Error rate')
        
        ax1 = fig.add_subplot(122)
        ax1.plot(ds, pr_plot, color = 'green')
        ax1.plot(ds, re_plot, color = 'magenta')
        ax1.set_title('P-R curve')
        ax1.legend(['Precision', 'Recall'])
        ax.set(xlabel = 'Thresholds', ylabel = 'Error rate')
        
        plt.show()
    return max_acc, best_thresh

# %%
def plot_history(results):
    acc = results.history["acc"]
    val_acc = results.history["val_acc"]
    loss = results.history["loss"]
    val_loss = results.history["val_loss"]
    
    plt.plot(results.history['loss'])
    plt.plot(results.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train loss', 'val loss'], loc='upper right')
    plt.show()
    print('Train Loss: ', loss[-1])
    print('Validation Loss: ', val_loss[-1])
    
    plt.plot(results.history['acc'])
    plt.plot(results.history['val_acc'])
    plt.title('Model Accuracy')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train acc', 'val acc'], loc='upper right')
    plt.show()
    print('Train Accuracy: ', acc[-1])
    print('Validation Accuracy: ', val_acc[-1])

# %%
def plot_history2(results):
    loss = results.history["loss"]
    val_loss = results.history["val_loss"]
    
    plt.plot(results.history['loss'])
    plt.plot(results.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train loss', 'val loss'], loc='upper right')
    plt.show()
    print('Train Loss: ', loss[-1])
    print('Validation Loss: ', val_loss[-1])

# %%
def generate_data(features, labels, test_size=0.25):
    """
        Generate data in pairs according to labels.
        Arguments:
            features: numpy
            labels: numpy
    """
    im_a = []  # images a
    im_b = []  # images b
    pair_labels = []
    for i in range(0, len(features)-1):
        j = i + 1
        if labels[i] == labels[j]:
            im_a.append(features[i])
            im_b.append(features[j])
            pair_labels.append(1)  # similar
        else:
            im_a.append(features[i])
            im_b.append(features[j])
            pair_labels.append(0)  # not similar

    pairs = np.stack([im_a, im_b], axis=1)
    pair_labels = np.array(pair_labels)
    x_train, x_test, y_train, y_test = train_test_split(
        pairs, pair_labels, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = train_test_split(
        x_train, y_train, test_size=0.25, random_state=42)
    return x_train, y_train, x_test, y_test, x_val, y_val, pairs, pair_labels

# %%
def test_model(weight):
    model.load_weights(weight)

    test_gen = generate_batch(genuine_test, forged_test, 1)
    pred, tr_y = [], []
    for i in range(num_test_samples):
        (img1, img2), label = next(test_gen)
        tr_y.append(label)
        pred.append(model.predict([img1, img2])[0][0])

    tr_acc, threshold = compute_accuracy_roc(np.array(pred), np.array(tr_y), plot_far_frr = True)
    return tr_acc, threshold

# %%
def verify_signature():
    '''Predict distance score and classify test images as Genuine or Forged'''
    test_point, test_label = next(test_genuine)
    img1, img2 = test_point[0], test_point[1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))
    ax1.imshow(np.squeeze(img1), cmap='gray')
    ax2.imshow(np.squeeze(img2), cmap='gray')
    ax1.set_title('Genuine')
    if test_label == 1:
        ax2.set_title('Genuine')
    else:
        ax2.set_title('Forged')
    plt.show()
    result = model.predict([img1, img2])
    diff = result[0][0]
    print('Difference Score = ', diff)
    if diff > threshold:
        print('The signature is forged')
    else:
        print('The signature is genuine')

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    return unique_list

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Create Signature Lists

# %% [markdown]
# #### Train Genuine Signatures

# %%
# Create lists of different list of genuine signature images from a single person

path = '../datasets/signatures_full/train/genuine/genuine_person'
# create a list of directories containing signatures of each person
dir_list_genuine = next(os.walk(path))[1]  # root, folder, files
# sort the list
dir_list_genuine.sort()
# create an empty list
genuine_lists = []
for directory in dir_list_genuine:
    images = os.listdir(path+'/'+directory)
    images.sort()
    # list comprehension generating the file path of each img inside the dir
    images = [path+'/'+directory+'/' + x for x in images]
    genuine_lists.append(images)  # appending the list inside the genuine list

# %%
len(genuine_lists)
# Out:
# 55

# %%
genuine_lists[0]
# Out:
# ['../datasets/signatures_full/train/genuine/genuine_person/1/1.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/10.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/11.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/12.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/13.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/14.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/15.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/16.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/17.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/18.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/19.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/2.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/20.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/3.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/4.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/5.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/6.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/7.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/8.png',
#  '../datasets/signatures_full/train/genuine/genuine_person/1/9.png']

# %% [markdown]
# #### Train Forged Signatures

# %%
# Forged signature lists
path = '../datasets/signatures_full/train/forged/forged_person'

dir_list_forged = sorted(os.listdir(path))
dir_list_forged.sort()

forged_lists = []
for directory in dir_list_forged:
    images = os.listdir(path+'/'+directory)
    images.sort()
    images = [path+'/'+directory+'/'+x for x in images]
    forged_lists.append(images)

# %%
len(forged_lists)
# Out:
# 55

# %%
forged_lists[0]
# Out:
# ['../datasets/signatures_full/train/forged/forged_person/1/1.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/10.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/11.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/12.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/13.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/14.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/15.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/16.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/17.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/18.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/19.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/2.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/20.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/3.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/4.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/5.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/6.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/7.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/8.png',
#  '../datasets/signatures_full/train/forged/forged_person/1/9.png']

# %%
# check the number of signatures per individual. Both genuine and forged
genuine_len = [len(x) for x in genuine_lists]
forged_len = [len(x) for x in forged_lists]
print(genuine_len)
print(forged_len)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %% [markdown]
# #### Test Genuine Signatures

# %%
# Create lists of different list of genuine signature images from a single person

test_path = '../datasets/signatures_full/test/genuine/genuine_person'
# create a list of directories containing signatures of each person
dir_list_test_genuine = next(os.walk(test_path))[1]  # root, folder, files
# sort the list
dir_list_test_genuine.sort()
# create an empty list
test_genuine_lists = []
for directory in dir_list_test_genuine:
    test_images = os.listdir(test_path+'/'+directory)
    test_images.sort()
    # list comprehension generating the file path of each img inside the dir
    test_images = [test_path+'/'+directory+'/'+x for x in test_images]
    # appending the list inside the genuine list
    test_genuine_lists.append(test_images)

# %%
len(test_genuine_lists)
# Out:
# 8

# %%
test_genuine_lists[0]
# Out:
# ['../datasets/signatures_full/test/genuine/genuine_person/1/1.png',
#  '../datasets/signatures_full/test/genuine/genuine_person/1/2.png',
#  '../datasets/signatures_full/test/genuine/genuine_person/1/3.png',
#  '../datasets/signatures_full/test/genuine/genuine_person/1/4.png',
#  '../datasets/signatures_full/test/genuine/genuine_person/1/5.png']

# %% [markdown]
# #### Test Forged Signatures

# %%
# Create lists of different list of forged signature images from a single person

test_path = '../datasets/signatures_full/test/forged/forged_person'
# create a list of directories containing signatures of each person
dir_list_test_forged = next(os.walk(test_path))[1]  # root, folder, files
# sort the list
dir_list_test_forged.sort()
# create an empty list
test_forged_lists = []
for directory in dir_list_test_forged:
    test_images = os.listdir(test_path+'/'+directory)
    test_images.sort()
    # list comprehension generating the file path of each img inside the dir
    test_images = [test_path+'/'+directory+'/'+x for x in test_images]
    # appending the list inside the genuine list
    test_forged_lists.append(test_images)

# %% [markdown]
# ### Split Data

# %%
file, features, labels, features_forged, features_real, features_dict, X_train, X_test, y_train, y_test, X_val, y_val = load_data()
# Out:
# Searching folder 1
# Adding ../datasets/signatures_full/train/forged/forged_person/1/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/9.png with label 0
# Searching folder 10
# Adding ../datasets/signatures_full/train/forged/forged_person/10/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/9.png with label 0
# Searching folder 11
# Adding ../datasets/signatures_full/train/forged/forged_person/11/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/9.png with label 0
# Searching folder 12
# Adding ../datasets/signatures_full/train/forged/forged_person/12/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/9.png with label 0
# Searching folder 13
# Adding ../datasets/signatures_full/train/forged/forged_person/13/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/9.png with label 0
# Searching folder 14
# Adding ../datasets/signatures_full/train/forged/forged_person/14/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/9.png with label 0
# Searching folder 15
# Adding ../datasets/signatures_full/train/forged/forged_person/15/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/9.png with label 0
# Searching folder 16
# Adding ../datasets/signatures_full/train/forged/forged_person/16/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/9.png with label 0
# Searching folder 17
# Adding ../datasets/signatures_full/train/forged/forged_person/17/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/9.png with label 0
# Searching folder 18
# Adding ../datasets/signatures_full/train/forged/forged_person/18/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/9.png with label 0
# Searching folder 19
# Adding ../datasets/signatures_full/train/forged/forged_person/19/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/9.png with label 0
# Searching folder 2
# Adding ../datasets/signatures_full/train/forged/forged_person/2/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/9.png with label 0
# Searching folder 20
# Adding ../datasets/signatures_full/train/forged/forged_person/20/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/9.png with label 0
# Searching folder 21
# Adding ../datasets/signatures_full/train/forged/forged_person/21/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/9.png with label 0
# Searching folder 22
# Adding ../datasets/signatures_full/train/forged/forged_person/22/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/9.png with label 0
# Searching folder 23
# Adding ../datasets/signatures_full/train/forged/forged_person/23/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/9.png with label 0
# Searching folder 24
# Adding ../datasets/signatures_full/train/forged/forged_person/24/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/9.png with label 0
# Searching folder 25
# Adding ../datasets/signatures_full/train/forged/forged_person/25/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/9.png with label 0
# Searching folder 26
# Adding ../datasets/signatures_full/train/forged/forged_person/26/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/9.png with label 0
# Searching folder 27
# Adding ../datasets/signatures_full/train/forged/forged_person/27/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/9.png with label 0
# Searching folder 28
# Adding ../datasets/signatures_full/train/forged/forged_person/28/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/9.png with label 0
# Searching folder 29
# Adding ../datasets/signatures_full/train/forged/forged_person/29/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/9.png with label 0
# Searching folder 3
# Adding ../datasets/signatures_full/train/forged/forged_person/3/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/9.png with label 0
# Searching folder 30
# Adding ../datasets/signatures_full/train/forged/forged_person/30/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/9.png with label 0
# Searching folder 31
# Adding ../datasets/signatures_full/train/forged/forged_person/31/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/9.png with label 0
# Searching folder 32
# Adding ../datasets/signatures_full/train/forged/forged_person/32/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/9.png with label 0
# Searching folder 33
# Adding ../datasets/signatures_full/train/forged/forged_person/33/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/9.png with label 0
# Searching folder 34
# Adding ../datasets/signatures_full/train/forged/forged_person/34/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/9.png with label 0
# Searching folder 35
# Adding ../datasets/signatures_full/train/forged/forged_person/35/1.png with label 0
# ...
# Adding ../datasets/signatures_full/train/forged/forged_person/50/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/9.png with label 0
# Searching folder 51
# Adding ../datasets/signatures_full/train/forged/forged_person/51/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/9.png with label 0
# Searching folder 52
# Adding ../datasets/signatures_full/train/forged/forged_person/52/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/9.png with label 0
# Searching folder 53
# Adding ../datasets/signatures_full/train/forged/forged_person/53/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/9.png with label 0
# Searching folder 54
# Adding ../datasets/signatures_full/train/forged/forged_person/54/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/9.png with label 0
# Searching folder 55
# Adding ../datasets/signatures_full/train/forged/forged_person/55/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/9.png with label 0
# Searching folder 6
# Adding ../datasets/signatures_full/train/forged/forged_person/6/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/9.png with label 0
# Searching folder 7
# Adding ../datasets/signatures_full/train/forged/forged_person/7/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/9.png with label 0
# Searching folder 8
# Adding ../datasets/signatures_full/train/forged/forged_person/8/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/9.png with label 0
# Searching folder 9
# Adding ../datasets/signatures_full/train/forged/forged_person/9/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/9.png with label 0

# %%
genuine_train, genuine_val, genuine_test = genuine_lists[0:
                                                         41], genuine_lists[41:48], genuine_lists[48:55]
forged_train, forged_val, forged_test = forged_lists[0:
                                                     41], forged_lists[41:48], forged_lists[48:55]

# %%
genuine_test_data = test_genuine_lists
forged_test_data = test_forged_lists

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Distribution of Genuine and Forged Signatures

# %% [markdown]
# Displays the distribution of labels that has label 1 (1100 samples of genuine signatures) and label 0 (1100 samples of forged signatures).

# %%
print("Distribution: {}".format(np.bincount(labels)))
# Out:
# Distribution: [1100 1100]

# %%
#### input code to plot bar charts
y = []
unique_labels = unique(labels)
for x in unique_labels: 
    y.append(np.count_nonzero(labels == x))

x_labels=[]
for i in unique_labels:
    if i == 0:
        x_labels.append('Forged (0)')
    else:
        x_labels.append('Genuine (1)')

plt.rcParams["figure.figsize"] = (5,4)
plt.title('Distribution of Genuine and Forged Signatures', fontsize=12)
sns.barplot(x=x_labels, y=y, color='turquoise')
plt.xlabel('Signature Classes', fontsize=12)
plt.ylabel('Number of Signatures', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# %% [markdown]
# ### Image Shape and Labels
# Displays the label and shape of each sample image, which is (150, 150).

# %%
f, axarr = plt.subplots(2, 2, figsize=(10, 10))
axarr[0, 0].imshow(features[1101]/255., cmap='gray')
axarr[0, 0].text(2, 2, labels[1101], bbox={'facecolor': 'white', 'pad': 3})
axarr[0, 1].imshow(features[0]/255., cmap='gray')
axarr[0, 1].text(2, 2, labels[0], bbox={'facecolor': 'white', 'pad': 3})
axarr[1, 0].imshow(features[1301]/255., cmap='gray')
axarr[1, 0].text(2, 2, labels[1301], bbox={'facecolor': 'white', 'pad': 3})
axarr[1, 1].imshow(features[201]/255., cmap='gray')
axarr[1, 1].text(2, 2, labels[201], bbox={'facecolor': 'white', 'pad': 3})
# Out:
# Text(2, 2, '0')

# %% [markdown]
# ### Genuine and Forged Signatures of each Person
# Function randomly selects a genuine signature of a person from train dataset and selects one genuine copy and one forged copy of signatures of the same person, and displays them accordingly.

# %%
visualize_signatures()

# %%
visualize_signatures()

# %% [markdown]
# ## Models

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# Our problem statement is a binary classification problem, where label 1 represents a genuine signature and label 0 represents a forged signature. For a two outcome/binary model, it will be right more often than not by just going with the odds. Selecting the majority group (ZeroR classifier) is insightful as a baseline. In this case, we have a balanced classification problem, hence we will just use 0.50 as the baseline accuracy score.

# %% [markdown]
# ### Similarity in Images using MSE and SSIM
#
# Mean Squared Error (MSE) and Structural Similarity Index (SSIM) are used to compute similarities between two images. These functions can be found in the sklearn library.
#
# MSE does not have a fixed bound, and a higher number means a higher dissimilarity, whereas SSIM has a fixed bound between -1 and 1, where 1 means a perfect match between two images.
#
# We will look at the MSE and SSIM for two examples below:
# 1. Genuine-Forged pairs of images
#     - <i>MSE Error: 42.80746666666667</i>
#     - <i>SSIM: 0.9384314910047251</i>
# 2. Genuine-Genuine pairs of images
#     - <i>MSE Error: 65.84168888888888</i>
#     - <i>SSIM: 0.8892803875742811</i>
#
# Even though these functions can help detect unskilled forgeries, in cases like the below skilled forgery for the genuine-forged pair of signatures, the MSE error is smaller than that of the genuine-genuine pair, when the opposite should be true. Similarly, the SSIM for the genuine-forged pair is higher than that of the genuine-genuine pairs (which will almost never be identical).
#
# Hence, we cannot use MSE and SSIM for verifying signatures.

# %% [markdown]
# #### Genuine-Forged Pairs

# %%
A = features_dict["forged_1_1.png"]  # forged
B = features_dict["genuine_1_1.png"]  # genuine

# %%
print("Signature: {}".format(convert_label_to_text(A[1])))
plt.imshow(A[0], cmap='gray')
plt.show()

print("Signature: {}".format(convert_label_to_text(B[1])))
plt.imshow(B[0], cmap='gray')
plt.show()
# Out:
# Signature: Forged
# Signature: Genuine

# %%
A_array = img_to_array(A[0])
B_array = img_to_array(B[0])
print('MSE Error: {}'.format(mse(A_array, B_array)))
print('SSIM: {}'.format(ssim(A_array.flatten(), B_array.flatten())))
# Out:
# MSE Error: 42.80746666666667
# SSIM: 0.9384314910047251

# %% [markdown]
# #### Genuine-Genuine Pairs

# %%
C = features_dict['genuine_8_2.png']  # genuine
D = features_dict['genuine_8_3.png']  # genuine

# %%
print('Signature: {}'.format(convert_label_to_text(C[0])))
plt.imshow(C[0], cmap='gray')
plt.show()

print('Signature: {}'.format(convert_label_to_text(D[0])))
plt.imshow(D[0], cmap='gray')
plt.show()
# Out:
# Signature: Genuine
# Signature: Genuine

# %%
C_array = img_to_array(C[0])
D_array = img_to_array(D[0])
print('MSE Error: {}'.format(mse(C_array, D_array)))
print('SSIM: {}'.format(ssim(C_array.flatten(), D_array.flatten())))
# Out:
# MSE Error: 65.84168888888888
# SSIM: 0.8892803875742811

# %% [markdown]
# ### CNN Classifier

# %%
cnn = tf.keras.Sequential()
cnn.add(tf.keras.layers.Conv2D(
    64, (3, 3), input_shape=(150, 150, 1), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(512, activation='relu'))
cnn.add(tf.keras.layers.Dense(1, activation='sigmoid'))
cnn.compile(optimizer='adam',
            loss=tf.keras.losses.binary_crossentropy, metrics=['acc'])

# %%
cnn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 148, 148, 64)      640
#
#  max_pooling2d_21 (MaxPoolin  (None, 74, 74, 64)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 72, 72, 32)        18464
#
#  max_pooling2d_22 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 34, 34, 16)        4624
#
#  max_pooling2d_23 (MaxPoolin  (None, 17, 17, 16)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 15, 15, 16)        2320
#
#  flatten_7 (Flatten)         (None, 3600)              0
#
#  dense_14 (Dense)            (None, 512)               1843712
#
#  dense_15 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 1,870,273
# Trainable params: 1,870,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
# normalize inputs
X_train /= 255.
X_val /= 255.
X_test /= 255.

# %%
callbacks = [
    EarlyStopping(patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/cnn-model-{epoch:02d}.h5', verbose=1, save_weights_only=True)
]

# %%
cnn_history = cnn.fit(X_train, y_train, epochs=50,
                      validation_data=(X_val, y_val), callbacks=callbacks)
# Out:
# Epoch 1/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.5020
# Epoch 1: saving model to ../weights\cnn-model-01.h5
# 39/39 [==============================] - 2s 33ms/step - loss: 0.6932 - acc: 0.5020 - val_loss: 0.6989 - val_acc: 0.4552
# Epoch 2/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5107
# Epoch 2: saving model to ../weights\cnn-model-02.h5
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6939 - val_acc: 0.4552
# Epoch 3/50
# 37/39 [===========================>..] - ETA: 0s - loss: 0.6931 - acc: 0.5101
# Epoch 3: saving model to ../weights\cnn-model-03.h5
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6936 - val_acc: 0.4552
# Epoch 4/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.5101
# Epoch 4: saving model to ../weights\cnn-model-04.h5
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6942 - val_acc: 0.4552
# Epoch 5/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5090
# Epoch 5: saving model to ../weights\cnn-model-05.h5
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6941 - val_acc: 0.4552
# Epoch 6/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5090
# Epoch 6: saving model to ../weights\cnn-model-06.h5
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6947 - val_acc: 0.4552
# Epoch 6: early stopping

# %%
plot_history(cnn_history)
# Out:
# Train Loss:  0.6930504441261292
# Validation Loss:  0.6946852803230286
# Train Accuracy:  0.5101050734519958
# Validation Accuracy:  0.4552057981491089

# %%
preds = cnn.predict(X_test)
pred_labels = []

# %%
# threshold is 0.5
for p in preds:
    if p >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
pred_labels = np.array(pred_labels)

# %%
print('Accuracy on test dataset: {}'.format(
    accuracy_score(y_test, pred_labels)))
# Out:
# Accuracy on test dataset: 0.5109090909090909

# %%
cnn = tf.keras.Sequential()
cnn.add(tf.keras.layers.Conv2D(
    64, (3, 3), input_shape=(150, 150, 1), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(2))
cnn.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(512, activation='relu'))
cnn.add(tf.keras.layers.Dense(1, activation='sigmoid'))
cnn.compile(optimizer='RMSProp',
            loss=tf.keras.losses.binary_crossentropy, metrics=['acc'])

# %%
cnn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 148, 148, 64)      640
#
#  max_pooling2d_27 (MaxPoolin  (None, 74, 74, 64)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 72, 72, 32)        18464
#
#  max_pooling2d_28 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 34, 34, 16)        4624
#
#  max_pooling2d_29 (MaxPoolin  (None, 17, 17, 16)       0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 15, 15, 16)        2320
#
#  flatten_9 (Flatten)         (None, 3600)              0
#
#  dense_18 (Dense)            (None, 512)               1843712
#
#  dense_19 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 1,870,273
# Trainable params: 1,870,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/cnn-rms-model-{epoch:02d}.h5', verbose=1, save_weights_only=True)
]

# %%
cnn_history = cnn.fit(X_train, y_train, epochs=50,
                      validation_data=(X_val, y_val), callbacks=callbacks)
# Out:
# Epoch 1/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6975 - acc: 0.5085
# Epoch 1: saving model to ../weights\cnn-rms-model-01.h5
# 39/39 [==============================] - 2s 39ms/step - loss: 0.6975 - acc: 0.5085 - val_loss: 0.6935 - val_acc: 0.4552
# Epoch 2/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6933 - acc: 0.5101
# Epoch 2: saving model to ../weights\cnn-rms-model-02.h5
# 39/39 [==============================] - 1s 35ms/step - loss: 0.6933 - acc: 0.5101 - val_loss: 0.6937 - val_acc: 0.4552
# Epoch 3/50
# 37/39 [===========================>..] - ETA: 0s - loss: 0.6935 - acc: 0.4890
# Epoch 3: saving model to ../weights\cnn-rms-model-03.h5
# 39/39 [==============================] - 1s 35ms/step - loss: 0.6934 - acc: 0.4907 - val_loss: 0.6939 - val_acc: 0.4552
# Epoch 4/50
# 37/39 [===========================>..] - ETA: 0s - loss: 0.6932 - acc: 0.5068
# Epoch 4: saving model to ../weights\cnn-rms-model-04.h5
# 39/39 [==============================] - 1s 32ms/step - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6945 - val_acc: 0.4552
# Epoch 4: early stopping

# %%
plot_history(cnn_history)
# Out:
# Train Loss:  0.6931211352348328
# Validation Loss:  0.6944618225097656
# Train Accuracy:  0.5101050734519958
# Validation Accuracy:  0.4552057981491089

# %% [markdown]
# ### Siamese Neural Networks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Fine-tuning was done to optimizers adam and RMSProp

# %%
# To ensure that all images will be the same size 
img_h, img_w = 150, 150

# %%
input_shape = (img_h, img_w, 1)

# %%
# network definition
base_network = create_base_network_signet(input_shape)

input_a = Input(shape=(input_shape))
input_b = Input(shape=(input_shape))

# because we re-use the same instance `base_network`,
# the weights of the network
# will be shared across the two branches
processed_a = base_network(input_a)
processed_b = base_network(input_b)

# Compute the Euclidean distance between the two vectors in the latent space
distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)(
    [processed_a, processed_b])

model = Model([input_a, input_b], distance)

# %%
batch_size = 200
num_train_samples = 190*41 + 400*41
num_val_samples = num_test_samples = 190*7 + 400*7
num_train_samples, num_val_samples, num_test_samples
# Out:
# (24190, 4130, 4130)

# %% [markdown]
# #### RMSProp

# %% [markdown]
# ##### Learning rate: 1e-5

# %%
# compile model using  RMSProp Optimizer and Contrastive loss function defined above
rms = RMSprop(learning_rate=1e-5, rho=0.9, epsilon=1e-08)
model.compile(loss=contrastive_loss, optimizer=rms, metrics='acc')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-rms-le5-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
results = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 9.9733 - acc: 0.4859
# Epoch 1: saving model to ../weights\snn-rms-le5-model-01.h5
# 120/120 [==============================] - 21s 138ms/step - loss: 9.9733 - acc: 0.4859 - val_loss: 1.3219 - val_acc: 0.5130
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0712 - acc: 0.4929
# Epoch 2: saving model to ../weights\snn-rms-le5-model-02.h5
# 120/120 [==============================] - 16s 131ms/step - loss: 1.0712 - acc: 0.4929 - val_loss: 1.3057 - val_acc: 0.5157
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0334 - acc: 0.4922
# Epoch 3: saving model to ../weights\snn-rms-le5-model-03.h5
# 120/120 [==============================] - 16s 130ms/step - loss: 1.0334 - acc: 0.4922 - val_loss: 1.2679 - val_acc: 0.5110
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0001 - acc: 0.4983
# Epoch 4: saving model to ../weights\snn-rms-le5-model-04.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0001 - acc: 0.4983 - val_loss: 1.2390 - val_acc: 0.5160
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9667 - acc: 0.4936
# Epoch 5: saving model to ../weights\snn-rms-le5-model-05.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.9667 - acc: 0.4936 - val_loss: 1.2059 - val_acc: 0.5145
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9342 - acc: 0.4958
# Epoch 6: saving model to ../weights\snn-rms-le5-model-06.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.9342 - acc: 0.4958 - val_loss: 1.1724 - val_acc: 0.5140
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9024 - acc: 0.4996
# Epoch 7: saving model to ../weights\snn-rms-le5-model-07.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.9024 - acc: 0.4996 - val_loss: 1.1347 - val_acc: 0.5090
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8700 - acc: 0.4971
# Epoch 8: saving model to ../weights\snn-rms-le5-model-08.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.8700 - acc: 0.4971 - val_loss: 1.1122 - val_acc: 0.5192
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8390 - acc: 0.4973
# Epoch 9: saving model to ../weights\snn-rms-le5-model-09.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.8390 - acc: 0.4973 - val_loss: 1.0698 - val_acc: 0.5067
# Epoch 10/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8097 - acc: 0.5012
# Epoch 10: saving model to ../weights\snn-rms-le5-model-10.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8097 - acc: 0.5012 - val_loss: 1.0518 - val_acc: 0.5163
# Epoch 11/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7820 - acc: 0.5006
# Epoch 11: saving model to ../weights\snn-rms-le5-model-11.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.7820 - acc: 0.5006 - val_loss: 1.0215 - val_acc: 0.5135
# Epoch 12/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7539 - acc: 0.4974
# Epoch 12: saving model to ../weights\snn-rms-le5-model-12.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.7539 - acc: 0.4974 - val_loss: 0.9985 - val_acc: 0.5170
# Epoch 13/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7278 - acc: 0.4962
# Epoch 13: saving model to ../weights\snn-rms-le5-model-13.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.7278 - acc: 0.4962 - val_loss: 0.9725 - val_acc: 0.5175
# Epoch 14/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7025 - acc: 0.4986
# Epoch 14: saving model to ../weights\snn-rms-le5-model-14.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.7025 - acc: 0.4986 - val_loss: 0.9367 - val_acc: 0.5065
# Epoch 15/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6783 - acc: 0.5014
# Epoch 15: saving model to ../weights\snn-rms-le5-model-15.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.6783 - acc: 0.5014 - val_loss: 0.9249 - val_acc: 0.5182
# Epoch 16/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6540 - acc: 0.5005
# Epoch 16: saving model to ../weights\snn-rms-le5-model-16.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6540 - acc: 0.5005 - val_loss: 0.8913 - val_acc: 0.5085
# Epoch 17/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6314 - acc: 0.4962
# Epoch 17: saving model to ../weights\snn-rms-le5-model-17.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6314 - acc: 0.4962 - val_loss: 0.8787 - val_acc: 0.5173
# Epoch 18/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6108 - acc: 0.4977
# Epoch 18: saving model to ../weights\snn-rms-le5-model-18.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.6108 - acc: 0.4977 - val_loss: 0.8553 - val_acc: 0.5128
# Epoch 19/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5919 - acc: 0.4995
# Epoch 19: saving model to ../weights\snn-rms-le5-model-19.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.5919 - acc: 0.4995 - val_loss: 0.8343 - val_acc: 0.5102
# Epoch 20/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5741 - acc: 0.4964
# Epoch 20: saving model to ../weights\snn-rms-le5-model-20.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.5741 - acc: 0.4964 - val_loss: 0.8205 - val_acc: 0.5140
# Epoch 21/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5571 - acc: 0.4956
# Epoch 21: saving model to ../weights\snn-rms-le5-model-21.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.5571 - acc: 0.4956 - val_loss: 0.8022 - val_acc: 0.5120
# Epoch 22/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5415 - acc: 0.4998
# Epoch 22: saving model to ../weights\snn-rms-le5-model-22.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.5415 - acc: 0.4998 - val_loss: 0.7863 - val_acc: 0.5117
# Epoch 23/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5263 - acc: 0.4988
# Epoch 23: saving model to ../weights\snn-rms-le5-model-23.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5263 - acc: 0.4988 - val_loss: 0.7741 - val_acc: 0.5130
# Epoch 24/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5127 - acc: 0.4950
# Epoch 24: saving model to ../weights\snn-rms-le5-model-24.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.5127 - acc: 0.4950 - val_loss: 0.7498 - val_acc: 0.5027
# Epoch 25/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4985 - acc: 0.4919
# Epoch 25: saving model to ../weights\snn-rms-le5-model-25.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4985 - acc: 0.4919 - val_loss: 0.7480 - val_acc: 0.5130
# Epoch 26/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4863 - acc: 0.5008
# Epoch 26: saving model to ../weights\snn-rms-le5-model-26.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4863 - acc: 0.5008 - val_loss: 0.7382 - val_acc: 0.5157
# Epoch 27/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4757 - acc: 0.4996
# Epoch 27: saving model to ../weights\snn-rms-le5-model-27.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.4757 - acc: 0.4996 - val_loss: 0.7236 - val_acc: 0.5115
# Epoch 28/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4657 - acc: 0.5066
# Epoch 28: saving model to ../weights\snn-rms-le5-model-28.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4657 - acc: 0.5066 - val_loss: 0.7100 - val_acc: 0.5073
# Epoch 29/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4554 - acc: 0.4921
# Epoch 29: saving model to ../weights\snn-rms-le5-model-29.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4554 - acc: 0.4921 - val_loss: 0.7044 - val_acc: 0.5107
# Epoch 30/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4463 - acc: 0.4958
# Epoch 30: saving model to ../weights\snn-rms-le5-model-30.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4463 - acc: 0.4958 - val_loss: 0.7013 - val_acc: 0.5167
# Epoch 31/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4389 - acc: 0.4998
# Epoch 31: saving model to ../weights\snn-rms-le5-model-31.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4389 - acc: 0.4998 - val_loss: 0.6901 - val_acc: 0.5130
# Epoch 32/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4313 - acc: 0.4965
# Epoch 32: saving model to ../weights\snn-rms-le5-model-32.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4313 - acc: 0.4965 - val_loss: 0.6795 - val_acc: 0.5085
# Epoch 33/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4240 - acc: 0.4966
# Epoch 33: saving model to ../weights\snn-rms-le5-model-33.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4240 - acc: 0.4966 - val_loss: 0.6800 - val_acc: 0.5157
# Epoch 34/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4185 - acc: 0.4965
# Epoch 34: saving model to ../weights\snn-rms-le5-model-34.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4185 - acc: 0.4965 - val_loss: 0.6758 - val_acc: 0.5182
# Epoch 35/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4130 - acc: 0.4983
# Epoch 35: saving model to ../weights\snn-rms-le5-model-35.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.4130 - acc: 0.4983 - val_loss: 0.6657 - val_acc: 0.5128
# Epoch 36/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4075 - acc: 0.4965
# Epoch 36: saving model to ../weights\snn-rms-le5-model-36.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4075 - acc: 0.4965 - val_loss: 0.6575 - val_acc: 0.5098
# Epoch 37/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4035 - acc: 0.5011
# Epoch 37: saving model to ../weights\snn-rms-le5-model-37.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4035 - acc: 0.5011 - val_loss: 0.6621 - val_acc: 0.5190
# Epoch 38/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3978 - acc: 0.4971
# Epoch 38: saving model to ../weights\snn-rms-le5-model-38.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3978 - acc: 0.4971 - val_loss: 0.6490 - val_acc: 0.5110
# Epoch 39/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3937 - acc: 0.4979
# Epoch 39: saving model to ../weights\snn-rms-le5-model-39.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3937 - acc: 0.4979 - val_loss: 0.6412 - val_acc: 0.5075
# Epoch 40/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3883 - acc: 0.4955
# Epoch 40: saving model to ../weights\snn-rms-le5-model-40.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3883 - acc: 0.4955 - val_loss: 0.6443 - val_acc: 0.5155
# Epoch 41/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3842 - acc: 0.4939
# Epoch 41: saving model to ../weights\snn-rms-le5-model-41.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3842 - acc: 0.4939 - val_loss: 0.6350 - val_acc: 0.5105
# Epoch 42/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3808 - acc: 0.5044
# Epoch 42: saving model to ../weights\snn-rms-le5-model-42.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3808 - acc: 0.5044 - val_loss: 0.6357 - val_acc: 0.5145
# Epoch 43/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3768 - acc: 0.4973
# Epoch 43: saving model to ../weights\snn-rms-le5-model-43.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3768 - acc: 0.4973 - val_loss: 0.6310 - val_acc: 0.5132
# Epoch 44/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3737 - acc: 0.5002
# Epoch 44: saving model to ../weights\snn-rms-le5-model-44.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3737 - acc: 0.5002 - val_loss: 0.6306 - val_acc: 0.5157
# Epoch 45/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3707 - acc: 0.4989
# Epoch 45: saving model to ../weights\snn-rms-le5-model-45.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3707 - acc: 0.4989 - val_loss: 0.6216 - val_acc: 0.5095
# Epoch 46/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3670 - acc: 0.4942
# Epoch 46: saving model to ../weights\snn-rms-le5-model-46.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3670 - acc: 0.4942 - val_loss: 0.6195 - val_acc: 0.5102
# Epoch 47/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3646 - acc: 0.5007
# Epoch 47: saving model to ../weights\snn-rms-le5-model-47.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3646 - acc: 0.5007 - val_loss: 0.6212 - val_acc: 0.5145
# Epoch 48/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3614 - acc: 0.4957
# Epoch 48: saving model to ../weights\snn-rms-le5-model-48.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3614 - acc: 0.4957 - val_loss: 0.6189 - val_acc: 0.5153
# Epoch 49/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3585 - acc: 0.4925
# Epoch 49: saving model to ../weights\snn-rms-le5-model-49.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3585 - acc: 0.4925 - val_loss: 0.6168 - val_acc: 0.5157
# Epoch 50/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3565 - acc: 0.4983
# Epoch 50: saving model to ../weights\snn-rms-le5-model-50.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.3565 - acc: 0.4983 - val_loss: 0.6140 - val_acc: 0.5155
# Epoch 51/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3531 - acc: 0.4928
# Epoch 51: saving model to ../weights\snn-rms-le5-model-51.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3531 - acc: 0.4928 - val_loss: 0.6114 - val_acc: 0.5153
# Epoch 52/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3515 - acc: 0.4963
# Epoch 52: saving model to ../weights\snn-rms-le5-model-52.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3515 - acc: 0.4963 - val_loss: 0.6100 - val_acc: 0.5160
# Epoch 53/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3490 - acc: 0.4980
# Epoch 53: saving model to ../weights\snn-rms-le5-model-53.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3490 - acc: 0.4980 - val_loss: 0.6048 - val_acc: 0.5132
# Epoch 54/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3467 - acc: 0.4989
# Epoch 54: saving model to ../weights\snn-rms-le5-model-54.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3467 - acc: 0.4989 - val_loss: 0.6049 - val_acc: 0.5153
# Epoch 55/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3459 - acc: 0.4992
# Epoch 55: saving model to ../weights\snn-rms-le5-model-55.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.3459 - acc: 0.4992 - val_loss: 0.6034 - val_acc: 0.5170
# Epoch 56/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3428 - acc: 0.4943
# Epoch 56: saving model to ../weights\snn-rms-le5-model-56.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.3428 - acc: 0.4943 - val_loss: 0.5992 - val_acc: 0.5140
# Epoch 57/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3415 - acc: 0.5010
# Epoch 57: saving model to ../weights\snn-rms-le5-model-57.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.3415 - acc: 0.5010 - val_loss: 0.5973 - val_acc: 0.5135
# Epoch 58/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3394 - acc: 0.4961
# Epoch 58: saving model to ../weights\snn-rms-le5-model-58.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3394 - acc: 0.4961 - val_loss: 0.5912 - val_acc: 0.5085
# Epoch 59/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3372 - acc: 0.4882
# Epoch 59: saving model to ../weights\snn-rms-le5-model-59.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3372 - acc: 0.4882 - val_loss: 0.5990 - val_acc: 0.5180
# Epoch 60/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3359 - acc: 0.4913
# Epoch 60: saving model to ../weights\snn-rms-le5-model-60.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3359 - acc: 0.4913 - val_loss: 0.5888 - val_acc: 0.5100
# Epoch 61/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3344 - acc: 0.4980
# Epoch 61: saving model to ../weights\snn-rms-le5-model-61.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3344 - acc: 0.4980 - val_loss: 0.5922 - val_acc: 0.5150
# Epoch 62/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3327 - acc: 0.4975
# Epoch 62: saving model to ../weights\snn-rms-le5-model-62.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3327 - acc: 0.4975 - val_loss: 0.5845 - val_acc: 0.5088
# Epoch 63/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3305 - acc: 0.4905
# Epoch 63: saving model to ../weights\snn-rms-le5-model-63.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3305 - acc: 0.4905 - val_loss: 0.5918 - val_acc: 0.5173
# Epoch 64/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3291 - acc: 0.4980
# Epoch 64: saving model to ../weights\snn-rms-le5-model-64.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3291 - acc: 0.4980 - val_loss: 0.5888 - val_acc: 0.5167
# Epoch 65/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3284 - acc: 0.5034
# Epoch 65: saving model to ../weights\snn-rms-le5-model-65.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3284 - acc: 0.5034 - val_loss: 0.5822 - val_acc: 0.5115
# Epoch 66/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3264 - acc: 0.4981
# Epoch 66: saving model to ../weights\snn-rms-le5-model-66.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3264 - acc: 0.4981 - val_loss: 0.5861 - val_acc: 0.5170
# Epoch 67/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3246 - acc: 0.4999
# Epoch 67: saving model to ../weights\snn-rms-le5-model-67.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3246 - acc: 0.4999 - val_loss: 0.5799 - val_acc: 0.5125
# Epoch 68/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3234 - acc: 0.4991
# Epoch 68: saving model to ../weights\snn-rms-le5-model-68.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3234 - acc: 0.4991 - val_loss: 0.5845 - val_acc: 0.5185
# Epoch 69/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3219 - acc: 0.4960
# Epoch 69: saving model to ../weights\snn-rms-le5-model-69.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3219 - acc: 0.4960 - val_loss: 0.5767 - val_acc: 0.5125
# Epoch 70/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3206 - acc: 0.4978
# Epoch 70: saving model to ../weights\snn-rms-le5-model-70.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3206 - acc: 0.4978 - val_loss: 0.5752 - val_acc: 0.5120
# Epoch 71/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3186 - acc: 0.4967
# Epoch 71: saving model to ../weights\snn-rms-le5-model-71.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.3186 - acc: 0.4967 - val_loss: 0.5780 - val_acc: 0.5167
# Epoch 72/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3172 - acc: 0.4956
# Epoch 72: saving model to ../weights\snn-rms-le5-model-72.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.3172 - acc: 0.4956 - val_loss: 0.5689 - val_acc: 0.5095
# Epoch 73/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3159 - acc: 0.4935
# Epoch 73: saving model to ../weights\snn-rms-le5-model-73.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3159 - acc: 0.4935 - val_loss: 0.5703 - val_acc: 0.5132
# Epoch 74/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3150 - acc: 0.4945
# Epoch 74: saving model to ../weights\snn-rms-le5-model-74.h5
# 120/120 [==============================] - 16s 138ms/step - loss: 0.3150 - acc: 0.4945 - val_loss: 0.5639 - val_acc: 0.5085
# Epoch 75/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3134 - acc: 0.4913
# Epoch 75: saving model to ../weights\snn-rms-le5-model-75.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3134 - acc: 0.4913 - val_loss: 0.5714 - val_acc: 0.5173
# Epoch 76/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3126 - acc: 0.4932
# Epoch 76: saving model to ../weights\snn-rms-le5-model-76.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.3126 - acc: 0.4932 - val_loss: 0.5627 - val_acc: 0.5100
# Epoch 77/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3110 - acc: 0.4860
# Epoch 77: saving model to ../weights\snn-rms-le5-model-77.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3110 - acc: 0.4860 - val_loss: 0.5624 - val_acc: 0.5110
# Epoch 78/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3105 - acc: 0.4933
# Epoch 78: saving model to ../weights\snn-rms-le5-model-78.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3105 - acc: 0.4933 - val_loss: 0.5597 - val_acc: 0.5110
# Epoch 79/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3090 - acc: 0.4939
# Epoch 79: saving model to ../weights\snn-rms-le5-model-79.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3090 - acc: 0.4939 - val_loss: 0.5541 - val_acc: 0.5082
# Epoch 80/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3069 - acc: 0.4826
# Epoch 80: saving model to ../weights\snn-rms-le5-model-80.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3069 - acc: 0.4826 - val_loss: 0.5518 - val_acc: 0.5100
# Epoch 81/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3062 - acc: 0.4843
# Epoch 81: saving model to ../weights\snn-rms-le5-model-81.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3062 - acc: 0.4843 - val_loss: 0.5584 - val_acc: 0.5203
# Epoch 82/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3045 - acc: 0.4785
# Epoch 82: saving model to ../weights\snn-rms-le5-model-82.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3045 - acc: 0.4785 - val_loss: 0.5429 - val_acc: 0.5128
# Epoch 83/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3023 - acc: 0.4650
# Epoch 83: saving model to ../weights\snn-rms-le5-model-83.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.3023 - acc: 0.4650 - val_loss: 0.5317 - val_acc: 0.5123
# Epoch 84/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2982 - acc: 0.4409
# Epoch 84: saving model to ../weights\snn-rms-le5-model-84.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.2982 - acc: 0.4409 - val_loss: 0.4843 - val_acc: 0.5132
# Epoch 85/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2733 - acc: 0.3628
# Epoch 85: saving model to ../weights\snn-rms-le5-model-85.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.2733 - acc: 0.3628 - val_loss: 0.3515 - val_acc: 0.4215
# Epoch 86/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2357 - acc: 0.2820
# Epoch 86: saving model to ../weights\snn-rms-le5-model-86.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.2357 - acc: 0.2820 - val_loss: 0.2843 - val_acc: 0.3313
# Epoch 87/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2127 - acc: 0.2346
# Epoch 87: saving model to ../weights\snn-rms-le5-model-87.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.2127 - acc: 0.2346 - val_loss: 0.2924 - val_acc: 0.3352
# Epoch 88/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1968 - acc: 0.2075
# Epoch 88: saving model to ../weights\snn-rms-le5-model-88.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.1968 - acc: 0.2075 - val_loss: 0.2819 - val_acc: 0.3237
# Epoch 89/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1841 - acc: 0.1898
# Epoch 89: saving model to ../weights\snn-rms-le5-model-89.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.1841 - acc: 0.1898 - val_loss: 0.2835 - val_acc: 0.3397
# Epoch 90/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1725 - acc: 0.1712
# Epoch 90: saving model to ../weights\snn-rms-le5-model-90.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.1725 - acc: 0.1712 - val_loss: 0.2870 - val_acc: 0.3500
# Epoch 91/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1653 - acc: 0.1650
# Epoch 91: saving model to ../weights\snn-rms-le5-model-91.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.1653 - acc: 0.1650 - val_loss: 0.2698 - val_acc: 0.3327
# Epoch 92/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1538 - acc: 0.1504
# Epoch 92: saving model to ../weights\snn-rms-le5-model-92.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.1538 - acc: 0.1504 - val_loss: 0.2716 - val_acc: 0.3430
# Epoch 93/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1464 - acc: 0.1390
# Epoch 93: saving model to ../weights\snn-rms-le5-model-93.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.1464 - acc: 0.1390 - val_loss: 0.2759 - val_acc: 0.3450
# Epoch 94/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1377 - acc: 0.1293
# Epoch 94: saving model to ../weights\snn-rms-le5-model-94.h5
# 120/120 [==============================] - 17s 146ms/step - loss: 0.1377 - acc: 0.1293 - val_loss: 0.2674 - val_acc: 0.3372
# Epoch 95/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1278 - acc: 0.1142
# Epoch 95: saving model to ../weights\snn-rms-le5-model-95.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.1278 - acc: 0.1142 - val_loss: 0.2655 - val_acc: 0.3160
# Epoch 96/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1221 - acc: 0.1082
# Epoch 96: saving model to ../weights\snn-rms-le5-model-96.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.1221 - acc: 0.1082 - val_loss: 0.2690 - val_acc: 0.3360
# Epoch 97/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1105 - acc: 0.0890
# Epoch 97: saving model to ../weights\snn-rms-le5-model-97.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 0.1105 - acc: 0.0890 - val_loss: 0.2609 - val_acc: 0.3288
# Epoch 98/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1036 - acc: 0.0823
# Epoch 98: saving model to ../weights\snn-rms-le5-model-98.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.1036 - acc: 0.0823 - val_loss: 0.2565 - val_acc: 0.3340
# Epoch 99/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0959 - acc: 0.0726
# Epoch 99: saving model to ../weights\snn-rms-le5-model-99.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.0959 - acc: 0.0726 - val_loss: 0.2788 - val_acc: 0.3338
# Epoch 100/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0891 - acc: 0.0645
# Epoch 100: saving model to ../weights\snn-rms-le5-model-100.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.0891 - acc: 0.0645 - val_loss: 0.2891 - val_acc: 0.3243

# %%
plot_history(results)
# Out:
# Train Loss:  0.08912274241447449
# Validation Loss:  0.2890637218952179
# Train Accuracy:  0.06449999660253525
# Validation Accuracy:  0.3242500126361847

# %%
acc, threshold = test_model('../weights\snn-rms-le5-model-86.h5')
acc, threshold
# Out:
# (0.6492842391814513, 0.28812231935560706)

# %% [markdown]
# ##### Learning rate: 1e-4

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-rms-le4-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
# compile model using RMSProp Optimizer and Contrastive loss function defined above
rms = RMSprop(learning_rate=1e-4, rho=0.9, epsilon=1e-08)
model.compile(loss=contrastive_loss, optimizer=rms, metrics='acc')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
results = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 2.1108 - acc: 0.4935
# Epoch 1: saving model to ../weights\snn-rms-le4-model-01.h5
# 120/120 [==============================] - 25s 161ms/step - loss: 2.1108 - acc: 0.4935 - val_loss: 1.2498 - val_acc: 0.5130
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8736 - acc: 0.4956
# Epoch 2: saving model to ../weights\snn-rms-le4-model-02.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 0.8736 - acc: 0.4956 - val_loss: 0.9817 - val_acc: 0.5157
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6318 - acc: 0.4967
# Epoch 3: saving model to ../weights\snn-rms-le4-model-03.h5
# 120/120 [==============================] - 18s 152ms/step - loss: 0.6318 - acc: 0.4967 - val_loss: 0.7949 - val_acc: 0.5110
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4947 - acc: 0.4995
# Epoch 4: saving model to ../weights\snn-rms-le4-model-04.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.4947 - acc: 0.4995 - val_loss: 0.7039 - val_acc: 0.5160
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4170 - acc: 0.4993
# Epoch 5: saving model to ../weights\snn-rms-le4-model-05.h5
# 120/120 [==============================] - 18s 149ms/step - loss: 0.4170 - acc: 0.4993 - val_loss: 0.6456 - val_acc: 0.5145
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3712 - acc: 0.4999
# Epoch 6: saving model to ../weights\snn-rms-le4-model-06.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 0.3712 - acc: 0.4999 - val_loss: 0.6111 - val_acc: 0.5140
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3411 - acc: 0.4928
# Epoch 7: saving model to ../weights\snn-rms-le4-model-07.h5
# 120/120 [==============================] - 18s 151ms/step - loss: 0.3411 - acc: 0.4928 - val_loss: 0.5830 - val_acc: 0.5090
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3216 - acc: 0.4990
# Epoch 8: saving model to ../weights\snn-rms-le4-model-08.h5
# 120/120 [==============================] - 17s 144ms/step - loss: 0.3216 - acc: 0.4990 - val_loss: 0.5776 - val_acc: 0.5192
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3081 - acc: 0.4980
# Epoch 9: saving model to ../weights\snn-rms-le4-model-09.h5
# 120/120 [==============================] - 17s 144ms/step - loss: 0.3081 - acc: 0.4980 - val_loss: 0.5533 - val_acc: 0.5067
# Epoch 10/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2977 - acc: 0.5001
# Epoch 10: saving model to ../weights\snn-rms-le4-model-10.h5
# 120/120 [==============================] - 18s 153ms/step - loss: 0.2977 - acc: 0.5001 - val_loss: 0.5545 - val_acc: 0.5163
# Epoch 11/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2898 - acc: 0.5004
# Epoch 11: saving model to ../weights\snn-rms-le4-model-11.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.2898 - acc: 0.5004 - val_loss: 0.5453 - val_acc: 0.5135
# Epoch 12/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2834 - acc: 0.4951
# Epoch 12: saving model to ../weights\snn-rms-le4-model-12.h5
# 120/120 [==============================] - 18s 153ms/step - loss: 0.2834 - acc: 0.4951 - val_loss: 0.5438 - val_acc: 0.5170
# Epoch 13/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2795 - acc: 0.5015
# Epoch 13: saving model to ../weights\snn-rms-le4-model-13.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.2795 - acc: 0.5015 - val_loss: 0.5403 - val_acc: 0.5175
# Epoch 14/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2754 - acc: 0.4987
# Epoch 14: saving model to ../weights\snn-rms-le4-model-14.h5
# 120/120 [==============================] - 18s 154ms/step - loss: 0.2754 - acc: 0.4987 - val_loss: 0.5261 - val_acc: 0.5065
# Epoch 15/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2729 - acc: 0.5007
# Epoch 15: saving model to ../weights\snn-rms-le4-model-15.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 0.2729 - acc: 0.5007 - val_loss: 0.5354 - val_acc: 0.5182
# Epoch 16/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2706 - acc: 0.5010
# Epoch 16: saving model to ../weights\snn-rms-le4-model-16.h5
# 120/120 [==============================] - 17s 146ms/step - loss: 0.2706 - acc: 0.5010 - val_loss: 0.5237 - val_acc: 0.5085
# Epoch 17/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2682 - acc: 0.5028
# Epoch 17: saving model to ../weights\snn-rms-le4-model-17.h5
# 120/120 [==============================] - 17s 144ms/step - loss: 0.2682 - acc: 0.5028 - val_loss: 0.5307 - val_acc: 0.5173
# Epoch 18/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2668 - acc: 0.4945
# Epoch 18: saving model to ../weights\snn-rms-le4-model-18.h5
# 120/120 [==============================] - 18s 149ms/step - loss: 0.2668 - acc: 0.4945 - val_loss: 0.5248 - val_acc: 0.5128
# Epoch 19/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2650 - acc: 0.4981
# Epoch 19: saving model to ../weights\snn-rms-le4-model-19.h5
# 120/120 [==============================] - 17s 146ms/step - loss: 0.2650 - acc: 0.4981 - val_loss: 0.5210 - val_acc: 0.5102
# Epoch 20/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2637 - acc: 0.4944
# Epoch 20: saving model to ../weights\snn-rms-le4-model-20.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 0.2637 - acc: 0.4944 - val_loss: 0.5231 - val_acc: 0.5140
# Epoch 21/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2629 - acc: 0.4923
# Epoch 21: saving model to ../weights\snn-rms-le4-model-21.h5
# 120/120 [==============================] - 18s 153ms/step - loss: 0.2629 - acc: 0.4923 - val_loss: 0.5147 - val_acc: 0.5120
# Epoch 22/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2615 - acc: 0.4870
# Epoch 22: saving model to ../weights\snn-rms-le4-model-22.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.2615 - acc: 0.4870 - val_loss: 0.5082 - val_acc: 0.5117
# Epoch 23/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2607 - acc: 0.4844
# Epoch 23: saving model to ../weights\snn-rms-le4-model-23.h5
# 120/120 [==============================] - 18s 153ms/step - loss: 0.2607 - acc: 0.4844 - val_loss: 0.4975 - val_acc: 0.5130
# Epoch 24/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2574 - acc: 0.4640
# Epoch 24: saving model to ../weights\snn-rms-le4-model-24.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.2574 - acc: 0.4640 - val_loss: 0.3821 - val_acc: 0.4890
# Epoch 25/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2193 - acc: 0.3398
# Epoch 25: saving model to ../weights\snn-rms-le4-model-25.h5
# 120/120 [==============================] - 18s 151ms/step - loss: 0.2193 - acc: 0.3398 - val_loss: 0.3709 - val_acc: 0.4720
# Epoch 26/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1912 - acc: 0.2782
# Epoch 26: saving model to ../weights\snn-rms-le4-model-26.h5
# 120/120 [==============================] - 17s 145ms/step - loss: 0.1912 - acc: 0.2782 - val_loss: 0.2522 - val_acc: 0.3338
# Epoch 27/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1778 - acc: 0.2560
# Epoch 27: saving model to ../weights\snn-rms-le4-model-27.h5
# 120/120 [==============================] - 17s 145ms/step - loss: 0.1778 - acc: 0.2560 - val_loss: 0.2423 - val_acc: 0.3365
# Epoch 28/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1630 - acc: 0.2247
# Epoch 28: saving model to ../weights\snn-rms-le4-model-28.h5
# 120/120 [==============================] - 18s 148ms/step - loss: 0.1630 - acc: 0.2247 - val_loss: 0.2374 - val_acc: 0.3225
# Epoch 29/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1447 - acc: 0.1910
# Epoch 29: saving model to ../weights\snn-rms-le4-model-29.h5
# 120/120 [==============================] - 18s 149ms/step - loss: 0.1447 - acc: 0.1910 - val_loss: 0.2217 - val_acc: 0.3153
# Epoch 30/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1313 - acc: 0.1712
# Epoch 30: saving model to ../weights\snn-rms-le4-model-30.h5
# 120/120 [==============================] - 18s 151ms/step - loss: 0.1313 - acc: 0.1712 - val_loss: 0.2199 - val_acc: 0.3162
# Epoch 31/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1133 - acc: 0.1396
# Epoch 31: saving model to ../weights\snn-rms-le4-model-31.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 0.1133 - acc: 0.1396 - val_loss: 0.2151 - val_acc: 0.2960
# Epoch 32/100
# 120/120 [==============================] - ETA: 0s - loss: 0.1007 - acc: 0.1188
# Epoch 32: saving model to ../weights\snn-rms-le4-model-32.h5
# 120/120 [==============================] - 18s 152ms/step - loss: 0.1007 - acc: 0.1188 - val_loss: 0.2172 - val_acc: 0.2998
# Epoch 33/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0901 - acc: 0.1007
# Epoch 33: saving model to ../weights\snn-rms-le4-model-33.h5
# 120/120 [==============================] - 17s 140ms/step - loss: 0.0901 - acc: 0.1007 - val_loss: 0.2007 - val_acc: 0.2998
# Epoch 34/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0769 - acc: 0.0812
# Epoch 34: saving model to ../weights\snn-rms-le4-model-34.h5
# 120/120 [==============================] - 18s 154ms/step - loss: 0.0769 - acc: 0.0812 - val_loss: 0.2102 - val_acc: 0.3010
# Epoch 35/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0649 - acc: 0.0608
# Epoch 35: saving model to ../weights\snn-rms-le4-model-35.h5
# 120/120 [==============================] - 17s 143ms/step - loss: 0.0649 - acc: 0.0608 - val_loss: 0.3386 - val_acc: 0.4008
# Epoch 36/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0581 - acc: 0.0534
# Epoch 36: saving model to ../weights\snn-rms-le4-model-36.h5
# 120/120 [==============================] - 18s 148ms/step - loss: 0.0581 - acc: 0.0534 - val_loss: 0.2931 - val_acc: 0.3460
# Epoch 37/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0504 - acc: 0.0410
# Epoch 37: saving model to ../weights\snn-rms-le4-model-37.h5
# 120/120 [==============================] - 18s 153ms/step - loss: 0.0504 - acc: 0.0410 - val_loss: 0.2421 - val_acc: 0.3318
# Epoch 38/100
# 120/120 [==============================] - ETA: 0s - loss: 0.0443 - acc: 0.0350
# Epoch 38: saving model to ../weights\snn-rms-le4-model-38.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.0443 - acc: 0.0350 - val_loss: 0.2764 - val_acc: 0.3450
# Epoch 38: early stopping

# %%
plot_history(results)
# Out:
# Train Loss:  0.04428759589791298
# Validation Loss:  0.2763756513595581
# Train Accuracy:  0.03500000014901161
# Validation Accuracy:  0.3449999988079071

# %%
acc, threshold = test_model('../weights\snn-rms-le4-model-25.h5')
acc, threshold
# Out:
# (0.702718841343063, 0.10173288071528078)

# %% [markdown]
# #### Adagrad

# %% [markdown]
# ##### Learning Rate: 1e-4

# %%
# compile model using Adagrad Optimizer and Contrastive loss function defined above
adagrad = Adagrad(learning_rate=1e-4, initial_accumulator_value=0.1, epsilon=1e-08)
model.compile(loss=contrastive_loss, optimizer=adagrad, metrics='acc')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-adagrad-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
results = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0756 - acc: 0.5002
# Epoch 1: saving model to ../weights\snn-adagrad-model-01.h5
# 120/120 [==============================] - 17s 136ms/step - loss: 1.0756 - acc: 0.5002 - val_loss: 1.3334 - val_acc: 0.5138
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0757 - acc: 0.4939
# Epoch 2: saving model to ../weights\snn-adagrad-model-02.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 1.0757 - acc: 0.4939 - val_loss: 1.3314 - val_acc: 0.5117
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0758 - acc: 0.4963
# Epoch 3: saving model to ../weights\snn-adagrad-model-03.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 1.0758 - acc: 0.4963 - val_loss: 1.3309 - val_acc: 0.5117
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0755 - acc: 0.4985
# Epoch 4: saving model to ../weights\snn-adagrad-model-04.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 1.0755 - acc: 0.4985 - val_loss: 1.3339 - val_acc: 0.5150
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0764 - acc: 0.4981
# Epoch 5: saving model to ../weights\snn-adagrad-model-05.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 1.0764 - acc: 0.4981 - val_loss: 1.3377 - val_acc: 0.5180
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0761 - acc: 0.5016
# Epoch 6: saving model to ../weights\snn-adagrad-model-06.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 1.0761 - acc: 0.5016 - val_loss: 1.3299 - val_acc: 0.5100
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0751 - acc: 0.4978
# Epoch 7: saving model to ../weights\snn-adagrad-model-07.h5
# 120/120 [==============================] - 17s 141ms/step - loss: 1.0751 - acc: 0.4978 - val_loss: 1.3354 - val_acc: 0.5160
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0764 - acc: 0.5027
# Epoch 8: saving model to ../weights\snn-adagrad-model-08.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 1.0764 - acc: 0.5027 - val_loss: 1.3327 - val_acc: 0.5130
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0751 - acc: 0.4930
# Epoch 9: saving model to ../weights\snn-adagrad-model-09.h5
# 120/120 [==============================] - 17s 142ms/step - loss: 1.0751 - acc: 0.4930 - val_loss: 1.3301 - val_acc: 0.5107
# Epoch 9: early stopping

# %%
plot_history(results)
# Out:
# Train Loss:  1.0750980377197266
# Validation Loss:  1.3300987482070923
# Train Accuracy:  0.49295833706855774
# Validation Accuracy:  0.5107499957084656

# %%
acc, threshold = test_model('../weights\snn-adagrad-model-05.h5')
acc, threshold
# Out:
# (0.5002496255616575, 0.00015001703286543489)

# %% [markdown]
# #### Adam

# %% [markdown]
# ##### learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False, decay=1e-6

# %%
# compile model using adam Optimizer and Contrastive loss function defined above
adam = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False, decay=1e-6)
model.compile(optimizer=adam, loss=contrastive_loss)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-adam-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
results = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 2.4655
# Epoch 1: saving model to ../weights\snn-adam-model-01.h5
# 120/120 [==============================] - 21s 141ms/step - loss: 2.4655 - val_loss: 1.3130
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0489
# Epoch 2: saving model to ../weights\snn-adam-model-02.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 1.0489 - val_loss: 1.2949
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0299
# Epoch 3: saving model to ../weights\snn-adam-model-03.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 1.0299 - val_loss: 1.2732
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0105
# Epoch 4: saving model to ../weights\snn-adam-model-04.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 1.0105 - val_loss: 1.2605
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9939
# Epoch 5: saving model to ../weights\snn-adam-model-05.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9939 - val_loss: 1.2403
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9756
# Epoch 6: saving model to ../weights\snn-adam-model-06.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9756 - val_loss: 1.2228
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9575
# Epoch 7: saving model to ../weights\snn-adam-model-07.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.9575 - val_loss: 1.2008
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9401
# Epoch 8: saving model to ../weights\snn-adam-model-08.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.9401 - val_loss: 1.1939
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9238
# Epoch 9: saving model to ../weights\snn-adam-model-09.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9238 - val_loss: 1.1642
# Epoch 10/100
# 120/120 [==============================] - ETA: 0s - loss: 0.9059
# Epoch 10: saving model to ../weights\snn-adam-model-10.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.9059 - val_loss: 1.1561
# Epoch 11/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8902
# Epoch 11: saving model to ../weights\snn-adam-model-11.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8902 - val_loss: 1.1366
# Epoch 12/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8725
# Epoch 12: saving model to ../weights\snn-adam-model-12.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.8725 - val_loss: 1.1240
# Epoch 13/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8558
# Epoch 13: saving model to ../weights\snn-adam-model-13.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.8558 - val_loss: 1.1085
# Epoch 14/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8397
# Epoch 14: saving model to ../weights\snn-adam-model-14.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.8397 - val_loss: 1.0816
# Epoch 15/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8234
# Epoch 15: saving model to ../weights\snn-adam-model-15.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8234 - val_loss: 1.0766
# Epoch 16/100
# 120/120 [==============================] - ETA: 0s - loss: 0.8077
# Epoch 16: saving model to ../weights\snn-adam-model-16.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8077 - val_loss: 1.0517
# Epoch 17/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7929
# Epoch 17: saving model to ../weights\snn-adam-model-17.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.7929 - val_loss: 1.0449
# Epoch 18/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7776
# Epoch 18: saving model to ../weights\snn-adam-model-18.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.7776 - val_loss: 1.0255
# Epoch 19/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7613
# Epoch 19: saving model to ../weights\snn-adam-model-19.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.7613 - val_loss: 1.0070
# Epoch 20/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7465
# Epoch 20: saving model to ../weights\snn-adam-model-20.h5
# 120/120 [==============================] - 17s 139ms/step - loss: 0.7465 - val_loss: 0.9968
# Epoch 21/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7315
# Epoch 21: saving model to ../weights\snn-adam-model-21.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.7315 - val_loss: 0.9798
# Epoch 22/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7163
# Epoch 22: saving model to ../weights\snn-adam-model-22.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.7163 - val_loss: 0.9655
# Epoch 23/100
# 120/120 [==============================] - ETA: 0s - loss: 0.7038
# Epoch 23: saving model to ../weights\snn-adam-model-23.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.7038 - val_loss: 0.9526
# Epoch 24/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6872
# Epoch 24: saving model to ../weights\snn-adam-model-24.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.6872 - val_loss: 0.9282
# Epoch 25/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6741
# Epoch 25: saving model to ../weights\snn-adam-model-25.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.6741 - val_loss: 0.9248
# Epoch 26/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6601
# Epoch 26: saving model to ../weights\snn-adam-model-26.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.6601 - val_loss: 0.9136
# Epoch 27/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6465
# Epoch 27: saving model to ../weights\snn-adam-model-27.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.6465 - val_loss: 0.8959
# Epoch 28/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6334
# Epoch 28: saving model to ../weights\snn-adam-model-28.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.6334 - val_loss: 0.8786
# Epoch 29/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6195
# Epoch 29: saving model to ../weights\snn-adam-model-29.h5
# 120/120 [==============================] - 16s 138ms/step - loss: 0.6195 - val_loss: 0.8691
# Epoch 30/100
# 120/120 [==============================] - ETA: 0s - loss: 0.6061
# Epoch 30: saving model to ../weights\snn-adam-model-30.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.6061 - val_loss: 0.8620
# Epoch 31/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5943
# Epoch 31: saving model to ../weights\snn-adam-model-31.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.5943 - val_loss: 0.8459
# Epoch 32/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5804
# Epoch 32: saving model to ../weights\snn-adam-model-32.h5
# 120/120 [==============================] - 16s 137ms/step - loss: 0.5804 - val_loss: 0.8289
# Epoch 33/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5688
# Epoch 33: saving model to ../weights\snn-adam-model-33.h5
# 120/120 [==============================] - 16s 138ms/step - loss: 0.5688 - val_loss: 0.8239
# Epoch 34/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5555
# Epoch 34: saving model to ../weights\snn-adam-model-34.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5555 - val_loss: 0.8143
# Epoch 35/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5445
# Epoch 35: saving model to ../weights\snn-adam-model-35.h5
# 120/120 [==============================] - 17s 138ms/step - loss: 0.5445 - val_loss: 0.7968
# Epoch 36/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5334
# Epoch 36: saving model to ../weights\snn-adam-model-36.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5334 - val_loss: 0.7828
# Epoch 37/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5215
# Epoch 37: saving model to ../weights\snn-adam-model-37.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5215 - val_loss: 0.7806
# Epoch 38/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5109
# Epoch 38: saving model to ../weights\snn-adam-model-38.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5109 - val_loss: 0.7621
# Epoch 39/100
# 120/120 [==============================] - ETA: 0s - loss: 0.5001
# Epoch 39: saving model to ../weights\snn-adam-model-39.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 0.5001 - val_loss: 0.7480
# Epoch 40/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4893
# Epoch 40: saving model to ../weights\snn-adam-model-40.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4893 - val_loss: 0.7455
# Epoch 41/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4784
# Epoch 41: saving model to ../weights\snn-adam-model-41.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4784 - val_loss: 0.7304
# Epoch 42/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4684
# Epoch 42: saving model to ../weights\snn-adam-model-42.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4684 - val_loss: 0.7239
# Epoch 43/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4592
# Epoch 43: saving model to ../weights\snn-adam-model-43.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.4592 - val_loss: 0.7131
# Epoch 44/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4501
# Epoch 44: saving model to ../weights\snn-adam-model-44.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4501 - val_loss: 0.7063
# Epoch 45/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4402
# Epoch 45: saving model to ../weights\snn-adam-model-45.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4402 - val_loss: 0.6912
# Epoch 46/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4311
# Epoch 46: saving model to ../weights\snn-adam-model-46.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4311 - val_loss: 0.6827
# Epoch 47/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4222
# Epoch 47: saving model to ../weights\snn-adam-model-47.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4222 - val_loss: 0.6783
# Epoch 48/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4137
# Epoch 48: saving model to ../weights\snn-adam-model-48.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4137 - val_loss: 0.6708
# Epoch 49/100
# 120/120 [==============================] - ETA: 0s - loss: 0.4056
# Epoch 49: saving model to ../weights\snn-adam-model-49.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4056 - val_loss: 0.6632
# Epoch 50/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3980
# Epoch 50: saving model to ../weights\snn-adam-model-50.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3980 - val_loss: 0.6548
# Epoch 51/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3903
# Epoch 51: saving model to ../weights\snn-adam-model-51.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3903 - val_loss: 0.6472
# Epoch 52/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3826
# Epoch 52: saving model to ../weights\snn-adam-model-52.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3826 - val_loss: 0.6409
# Epoch 53/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3763
# Epoch 53: saving model to ../weights\snn-adam-model-53.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3763 - val_loss: 0.6314
# Epoch 54/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3679
# Epoch 54: saving model to ../weights\snn-adam-model-54.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3679 - val_loss: 0.6265
# Epoch 55/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3632
# Epoch 55: saving model to ../weights\snn-adam-model-55.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.3632 - val_loss: 0.6220
# Epoch 56/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3556
# Epoch 56: saving model to ../weights\snn-adam-model-56.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3556 - val_loss: 0.6127
# Epoch 57/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3498
# Epoch 57: saving model to ../weights\snn-adam-model-57.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3498 - val_loss: 0.6063
# Epoch 58/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3435
# Epoch 58: saving model to ../weights\snn-adam-model-58.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3435 - val_loss: 0.5957
# Epoch 59/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3388
# Epoch 59: saving model to ../weights\snn-adam-model-59.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3388 - val_loss: 0.5994
# Epoch 60/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3329
# Epoch 60: saving model to ../weights\snn-adam-model-60.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3329 - val_loss: 0.5860
# Epoch 61/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3280
# Epoch 61: saving model to ../weights\snn-adam-model-61.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3280 - val_loss: 0.5860
# Epoch 62/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3227
# Epoch 62: saving model to ../weights\snn-adam-model-62.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3227 - val_loss: 0.5745
# Epoch 63/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3179
# Epoch 63: saving model to ../weights\snn-adam-model-63.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 0.3179 - val_loss: 0.5772
# Epoch 64/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3135
# Epoch 64: saving model to ../weights\snn-adam-model-64.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3135 - val_loss: 0.5697
# Epoch 65/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3095
# Epoch 65: saving model to ../weights\snn-adam-model-65.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3095 - val_loss: 0.5555
# Epoch 66/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3028
# Epoch 66: saving model to ../weights\snn-adam-model-66.h5
# 120/120 [==============================] - 16s 135ms/step - loss: 0.3028 - val_loss: 0.5174
# Epoch 67/100
# 120/120 [==============================] - ETA: 0s - loss: 0.3039
# Epoch 67: saving model to ../weights\snn-adam-model-67.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3039 - val_loss: 0.5587
# Epoch 68/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2992
# Epoch 68: saving model to ../weights\snn-adam-model-68.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2992 - val_loss: 0.5611
# Epoch 69/100
# 120/120 [==============================] - ETA: 0s - loss: 0.2964
# Epoch 69: saving model to ../weights\snn-adam-model-69.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2964 - val_loss: 0.5488
# Epoch 69: early stopping

# %%
plot_history2(results)
# Out:
# Train Loss:  0.2964404225349426
# Validation Loss:  0.548768937587738

# %%
acc, threshold = test_model('../weights\snn-adam-model-66.h5')
acc, threshold
# Out:
# (0.6649619976576744, 0.038765036240220076)

# %%
# compile model using adam Optimizer and Contrastive loss function defined above
adam = Adam(learning_rate=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False, decay=1e-6)
model.compile(optimizer=adam, loss=contrastive_loss)
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_9 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential_10 (Sequential)     (None, 128)          4888208     ['input_8[0][0]',
#                                                                   'input_9[0][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['sequential_10[0][0]',
#                                                                   'sequential_10[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-adam-model-{epoch:03d}.h5', verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0758
# Epoch 1: saving model to ../weights\snn-adam-model-001.h5
# 120/120 [==============================] - 32s 262ms/step - loss: 1.0758 - val_loss: 1.3346
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0721
# Epoch 2: saving model to ../weights\snn-adam-model-002.h5
# 120/120 [==============================] - 32s 267ms/step - loss: 1.0721 - val_loss: 1.3255
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0681
# Epoch 3: saving model to ../weights\snn-adam-model-003.h5
# 120/120 [==============================] - 31s 261ms/step - loss: 1.0681 - val_loss: 1.3192
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0656
# Epoch 4: saving model to ../weights\snn-adam-model-004.h5
# 120/120 [==============================] - 32s 269ms/step - loss: 1.0656 - val_loss: 1.3256
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0629
# Epoch 5: saving model to ../weights\snn-adam-model-005.h5
# 120/120 [==============================] - 32s 267ms/step - loss: 1.0629 - val_loss: 1.3185
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0596
# Epoch 6: saving model to ../weights\snn-adam-model-006.h5
# 120/120 [==============================] - 34s 285ms/step - loss: 1.0596 - val_loss: 1.3151
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0561
# Epoch 7: saving model to ../weights\snn-adam-model-007.h5
# 120/120 [==============================] - 32s 266ms/step - loss: 1.0561 - val_loss: 1.3129
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0540
# Epoch 8: saving model to ../weights\snn-adam-model-008.h5
# 120/120 [==============================] - 34s 281ms/step - loss: 1.0540 - val_loss: 1.3124
# Epoch 9/100
#  19/120 [===>..........................] - ETA: 21s - loss: 1.0520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16468/2589941652.py in <module>
# ----> 1 history = model.fit(generate_batch(genuine_train, forged_train, batch_size),
#       2                     steps_per_epoch=num_train_samples//batch_size,
#       3                     epochs=100,
#       4                     validation_data=generate_batch(
#       5                         genuine_val, forged_val, batch_size),
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### SGD
# Parameters: learning_rate, momentum, nesterov

# %% [markdown]
# ##### Learning rate: 1e-3

# %%
# compile model using adam Optimizer and Contrastive loss function defined above
sgd = SGD(learning_rate=1e-3, momentum=0.1)
model.compile(optimizer=sgd, loss=contrastive_loss, metrics='acc')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor ="val_loss", patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-sgd-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0748 - acc: 0.4972
# Epoch 1: saving model to ../weights\snn-sgd-model-01.h5
# 120/120 [==============================] - 17s 131ms/step - loss: 1.0748 - acc: 0.4972 - val_loss: 1.3350 - val_acc: 0.5145
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0741 - acc: 0.4935
# Epoch 2: saving model to ../weights\snn-sgd-model-02.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 1.0741 - acc: 0.4935 - val_loss: 1.3345 - val_acc: 0.5142
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0744 - acc: 0.4978
# Epoch 3: saving model to ../weights\snn-sgd-model-03.h5
# 120/120 [==============================] - 16s 130ms/step - loss: 1.0744 - acc: 0.4978 - val_loss: 1.3318 - val_acc: 0.5117
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0745 - acc: 0.4970
# Epoch 4: saving model to ../weights\snn-sgd-model-04.h5
# 120/120 [==============================] - 16s 134ms/step - loss: 1.0745 - acc: 0.4970 - val_loss: 1.3358 - val_acc: 0.5160
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0741 - acc: 0.5007
# Epoch 5: saving model to ../weights\snn-sgd-model-05.h5
# 120/120 [==============================] - 16s 136ms/step - loss: 1.0741 - acc: 0.5007 - val_loss: 1.3299 - val_acc: 0.5105
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0734 - acc: 0.4986
# Epoch 6: saving model to ../weights\snn-sgd-model-06.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0734 - acc: 0.4986 - val_loss: 1.3236 - val_acc: 0.5042
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0741 - acc: 0.5030
# Epoch 7: saving model to ../weights\snn-sgd-model-07.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0741 - acc: 0.5030 - val_loss: 1.3342 - val_acc: 0.5150
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0731 - acc: 0.4983
# Epoch 8: saving model to ../weights\snn-sgd-model-08.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0731 - acc: 0.4983 - val_loss: 1.3259 - val_acc: 0.5070
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0731 - acc: 0.4991
# Epoch 9: saving model to ../weights\snn-sgd-model-09.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0731 - acc: 0.4991 - val_loss: 1.3254 - val_acc: 0.5067
# Epoch 9: early stopping

# %%
plot_history(history)
# Out:
# Train Loss:  1.0731148719787598
# Validation Loss:  1.3253602981567383
# Train Accuracy:  0.49912500381469727
# Validation Accuracy:  0.5067499876022339

# %%
acc, threshold = test_model('../weights/snn-sgd-model-05.h5')
acc, threshold
# Out:
# (0.5005, 0.00010569789446890354)

# %% [markdown]
# ##### Learning Rate: 1e4

# %%
# compile model using adam Optimizer and Contrastive loss function defined above
sgd = SGD(learning_rate=1e-4, momentum=0.1)
model.compile(optimizer=sgd, loss=contrastive_loss, metrics='acc')
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_9 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential_10 (Sequential)     (None, 128)          4888208     ['input_8[0][0]',
#                                                                   'input_9[0][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['sequential_10[0][0]',
#                                                                   'sequential_10[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor ="val_loss", patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-sgd-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 2.4295 - acc: 0.4865
# Epoch 1: saving model to ../weights\snn-sgd-model-01.h5
# 120/120 [==============================] - 33s 266ms/step - loss: 2.4295 - acc: 0.4865 - val_loss: 1.3333 - val_acc: 0.5132
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0933 - acc: 0.4901
# Epoch 2: saving model to ../weights\snn-sgd-model-02.h5
# 120/120 [==============================] - 32s 268ms/step - loss: 1.0933 - acc: 0.4901 - val_loss: 1.3334 - val_acc: 0.5120
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0777 - acc: 0.4919
# Epoch 3: saving model to ../weights\snn-sgd-model-03.h5
# 120/120 [==============================] - 32s 269ms/step - loss: 1.0777 - acc: 0.4919 - val_loss: 1.3384 - val_acc: 0.5170
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0772 - acc: 0.4980
# Epoch 4: saving model to ../weights\snn-sgd-model-04.h5
# 120/120 [==============================] - 33s 275ms/step - loss: 1.0772 - acc: 0.4980 - val_loss: 1.3314 - val_acc: 0.5100
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0778 - acc: 0.5024
# Epoch 5: saving model to ../weights\snn-sgd-model-05.h5
# 120/120 [==============================] - 32s 271ms/step - loss: 1.0778 - acc: 0.5024 - val_loss: 1.3414 - val_acc: 0.5200
# Epoch 6/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0768 - acc: 0.4970
# Epoch 6: saving model to ../weights\snn-sgd-model-06.h5
# 120/120 [==============================] - 32s 271ms/step - loss: 1.0768 - acc: 0.4970 - val_loss: 1.3423 - val_acc: 0.5210
# Epoch 7/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0764 - acc: 0.4948
# Epoch 7: saving model to ../weights\snn-sgd-model-07.h5
# 120/120 [==============================] - 32s 264ms/step - loss: 1.0764 - acc: 0.4948 - val_loss: 1.3271 - val_acc: 0.5058
# Epoch 8/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0770 - acc: 0.4963
# Epoch 8: saving model to ../weights\snn-sgd-model-08.h5
# 120/120 [==============================] - 32s 267ms/step - loss: 1.0770 - acc: 0.4963 - val_loss: 1.3323 - val_acc: 0.5110
# Epoch 9/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0768 - acc: 0.4987
# Epoch 9: saving model to ../weights\snn-sgd-model-09.h5
# 120/120 [==============================] - 32s 268ms/step - loss: 1.0768 - acc: 0.4987 - val_loss: 1.3356 - val_acc: 0.5142
# Epoch 10/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0771 - acc: 0.4975
# Epoch 10: saving model to ../weights\snn-sgd-model-10.h5
# 120/120 [==============================] - 33s 272ms/step - loss: 1.0771 - acc: 0.4975 - val_loss: 1.3305 - val_acc: 0.5092
# Epoch 10: early stopping

# %% [markdown]
# ##### Learning rate: 1e-5

# %%
# compile model using adam Optimizer and Contrastive loss function defined above
sgd = SGD(learning_rate=1e-5)
model.compile(optimizer=sgd, loss=contrastive_loss, metrics='acc')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 128)          4888208     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 4,888,208
# Trainable params: 4,888,104
# Non-trainable params: 104
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor ="val_loss", patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/snn-sgd-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(generate_batch(genuine_train, forged_train, batch_size),
                    steps_per_epoch=num_train_samples//batch_size,
                    epochs=100,
                    validation_data=generate_batch(
                        genuine_val, forged_val, batch_size),
                    validation_steps=num_val_samples//batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0768 - acc: 0.4997
# Epoch 1: saving model to ../weights\snn-sgd-model-01.h5
# 120/120 [==============================] - 17s 131ms/step - loss: 1.0768 - acc: 0.4997 - val_loss: 1.3347 - val_acc: 0.5132
# Epoch 2/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0767 - acc: 0.5038
# Epoch 2: saving model to ../weights\snn-sgd-model-02.h5
# 120/120 [==============================] - 16s 132ms/step - loss: 1.0767 - acc: 0.5038 - val_loss: 1.3284 - val_acc: 0.5070
# Epoch 3/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0759 - acc: 0.4959
# Epoch 3: saving model to ../weights\snn-sgd-model-03.h5
# 120/120 [==============================] - 16s 131ms/step - loss: 1.0759 - acc: 0.4959 - val_loss: 1.3399 - val_acc: 0.5185
# Epoch 4/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0771 - acc: 0.4997
# Epoch 4: saving model to ../weights\snn-sgd-model-04.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0771 - acc: 0.4997 - val_loss: 1.3347 - val_acc: 0.5132
# Epoch 5/100
# 120/120 [==============================] - ETA: 0s - loss: 1.0767 - acc: 0.4967
# Epoch 5: saving model to ../weights\snn-sgd-model-05.h5
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0767 - acc: 0.4967 - val_loss: 1.3317 - val_acc: 0.5102
# Epoch 5: early stopping

# %%
plot_history(history)
# Out:
# Train Loss:  1.0766985416412354
# Validation Loss:  1.331686019897461
# Train Accuracy:  0.49674999713897705
# Validation Accuracy:  0.5102499723434448

# %%
acc, threshold = test_model('../weights/snn-sgd-model-01.h5')
acc, threshold
# Out:
# (0.500249500998004, 0.00017829753051046282)

# %% [markdown]
# ### Transfer Learning using Inception V3

# %% [markdown]
# Load images as rgb as Inception V3 requires input shape with 3 channels.

# %%
sub, features, labels, features_forged, features_real, features_dict, X_train, X_test, y_train, y_test, X_val, y_val = load_data(load_grayscale=False)
# Out:
# Searching folder 1
# Adding ../datasets/signatures_full/train/forged/forged_person/1/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/1/9.png with label 0
# Searching folder 10
# Adding ../datasets/signatures_full/train/forged/forged_person/10/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/10/9.png with label 0
# Searching folder 11
# Adding ../datasets/signatures_full/train/forged/forged_person/11/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/11/9.png with label 0
# Searching folder 12
# Adding ../datasets/signatures_full/train/forged/forged_person/12/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/12/9.png with label 0
# Searching folder 13
# Adding ../datasets/signatures_full/train/forged/forged_person/13/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/13/9.png with label 0
# Searching folder 14
# Adding ../datasets/signatures_full/train/forged/forged_person/14/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/14/9.png with label 0
# Searching folder 15
# Adding ../datasets/signatures_full/train/forged/forged_person/15/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/15/9.png with label 0
# Searching folder 16
# Adding ../datasets/signatures_full/train/forged/forged_person/16/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/16/9.png with label 0
# Searching folder 17
# Adding ../datasets/signatures_full/train/forged/forged_person/17/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/17/9.png with label 0
# Searching folder 18
# Adding ../datasets/signatures_full/train/forged/forged_person/18/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/18/9.png with label 0
# Searching folder 19
# Adding ../datasets/signatures_full/train/forged/forged_person/19/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/19/9.png with label 0
# Searching folder 2
# Adding ../datasets/signatures_full/train/forged/forged_person/2/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/2/9.png with label 0
# Searching folder 20
# Adding ../datasets/signatures_full/train/forged/forged_person/20/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/20/9.png with label 0
# Searching folder 21
# Adding ../datasets/signatures_full/train/forged/forged_person/21/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/21/9.png with label 0
# Searching folder 22
# Adding ../datasets/signatures_full/train/forged/forged_person/22/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/22/9.png with label 0
# Searching folder 23
# Adding ../datasets/signatures_full/train/forged/forged_person/23/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/23/9.png with label 0
# Searching folder 24
# Adding ../datasets/signatures_full/train/forged/forged_person/24/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/24/9.png with label 0
# Searching folder 25
# Adding ../datasets/signatures_full/train/forged/forged_person/25/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/25/9.png with label 0
# Searching folder 26
# Adding ../datasets/signatures_full/train/forged/forged_person/26/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/26/9.png with label 0
# Searching folder 27
# Adding ../datasets/signatures_full/train/forged/forged_person/27/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/27/9.png with label 0
# Searching folder 28
# Adding ../datasets/signatures_full/train/forged/forged_person/28/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/28/9.png with label 0
# Searching folder 29
# Adding ../datasets/signatures_full/train/forged/forged_person/29/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/29/9.png with label 0
# Searching folder 3
# Adding ../datasets/signatures_full/train/forged/forged_person/3/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/3/9.png with label 0
# Searching folder 30
# Adding ../datasets/signatures_full/train/forged/forged_person/30/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/30/9.png with label 0
# Searching folder 31
# Adding ../datasets/signatures_full/train/forged/forged_person/31/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/31/9.png with label 0
# Searching folder 32
# Adding ../datasets/signatures_full/train/forged/forged_person/32/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/32/9.png with label 0
# Searching folder 33
# Adding ../datasets/signatures_full/train/forged/forged_person/33/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/33/9.png with label 0
# Searching folder 34
# Adding ../datasets/signatures_full/train/forged/forged_person/34/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/34/9.png with label 0
# Searching folder 35
# Adding ../datasets/signatures_full/train/forged/forged_person/35/1.png with label 0
# ...
# Adding ../datasets/signatures_full/train/forged/forged_person/50/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/50/9.png with label 0
# Searching folder 51
# Adding ../datasets/signatures_full/train/forged/forged_person/51/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/51/9.png with label 0
# Searching folder 52
# Adding ../datasets/signatures_full/train/forged/forged_person/52/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/52/9.png with label 0
# Searching folder 53
# Adding ../datasets/signatures_full/train/forged/forged_person/53/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/53/9.png with label 0
# Searching folder 54
# Adding ../datasets/signatures_full/train/forged/forged_person/54/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/54/9.png with label 0
# Searching folder 55
# Adding ../datasets/signatures_full/train/forged/forged_person/55/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/55/9.png with label 0
# Searching folder 6
# Adding ../datasets/signatures_full/train/forged/forged_person/6/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/6/9.png with label 0
# Searching folder 7
# Adding ../datasets/signatures_full/train/forged/forged_person/7/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/7/9.png with label 0
# Searching folder 8
# Adding ../datasets/signatures_full/train/forged/forged_person/8/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/8/9.png with label 0
# Searching folder 9
# Adding ../datasets/signatures_full/train/forged/forged_person/9/1.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/10.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/11.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/12.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/13.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/14.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/15.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/16.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/17.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/18.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/19.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/2.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/20.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/3.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/4.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/5.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/6.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/7.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/8.png with label 0
# Adding ../datasets/signatures_full/train/forged/forged_person/9/9.png with label 0

# %%
X_features, y_labels = load_test_data(load_grayscale=False)
# Out:
# Searching folder 1
# Adding ../datasets/signatures_full/test/forged/forged_person/1/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/1/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/1/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/1/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/1/5.png with label 0
# Searching folder 2
# Adding ../datasets/signatures_full/test/forged/forged_person/2/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/2/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/2/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/2/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/2/5.png with label 0
# Searching folder 3
# Adding ../datasets/signatures_full/test/forged/forged_person/3/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/3/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/3/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/3/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/3/5.png with label 0
# Searching folder 4
# Adding ../datasets/signatures_full/test/forged/forged_person/4/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/4/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/4/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/4/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/4/5.png with label 0
# Searching folder 5
# Adding ../datasets/signatures_full/test/forged/forged_person/5/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/5/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/5/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/5/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/5/5.png with label 0
# Searching folder 6
# Adding ../datasets/signatures_full/test/forged/forged_person/6/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/6/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/6/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/6/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/6/5.png with label 0
# Searching folder 7
# Adding ../datasets/signatures_full/test/forged/forged_person/7/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/7/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/7/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/7/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/7/5.png with label 0
# Searching folder 8
# Adding ../datasets/signatures_full/test/forged/forged_person/8/1.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/8/2.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/8/3.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/8/4.png with label 0
# Adding ../datasets/signatures_full/test/forged/forged_person/8/5.png with label 0

# %%
# loading Inception
inception = tf.keras.applications.InceptionV3(
    include_top=False, input_shape=(150, 150, 3))

# %%
# freezing layers
for layer in inception.layers:
    layer.trainable = False

# %%
x = tf.keras.layers.Flatten()(layer.output)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.Dropout(.5)(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
inception_model = tf.keras.Model(inception.input, x)

# %%
rms = RMSprop(learning_rate=1e-4)
inception_model.compile(optimizer=rms,
                  loss='binary_crossentropy', metrics=['acc'])
inception_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 74, 74, 32)   864         ['input_7[0][0]']
#
#  batch_normalization_378 (Batch  (None, 74, 74, 32)  96          ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_376 (Activation)    (None, 74, 74, 32)   0           ['batch_normalization_378[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 72, 72, 32)   9216        ['activation_376[0][0]']
#
#  batch_normalization_379 (Batch  (None, 72, 72, 32)  96          ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 72, 72, 32)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 72, 72, 64)   18432       ['activation_377[0][0]']
#
#  batch_normalization_380 (Batch  (None, 72, 72, 64)  192         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 35, 35, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 35, 35, 80)   5120        ['max_pooling2d_19[0][0]']
#
#  batch_normalization_381 (Batch  (None, 35, 35, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 35, 35, 80)   0           ['batch_normalization_381[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 33, 33, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_382 (Batch  (None, 33, 33, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 33, 33, 192)  0           ['batch_normalization_382[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 16, 16, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_386 (Batch  (None, 16, 16, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_386[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 16, 16, 48)   9216        ['max_pooling2d_20[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_384 (Batch  (None, 16, 16, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 16, 16, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_384[0][0]']
#
#  activation_385 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_387[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 16, 16, 192)  0          ['max_pooling2d_20[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 16, 16, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_383 (Batch  (None, 16, 16, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 16, 16, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_388 (Batch  (None, 16, 16, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_389 (Batch  (None, 16, 16, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_383 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_385[0][0]']
#
#  activation_386 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_388[0][0]']
#
#  activation_387 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_389[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_393 (Batch  (None, 16, 16, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_393[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_391 (Batch  (None, 16, 16, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 16, 16, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_391[0][0]']
#
#  activation_392 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_394[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 16, 16, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_390 (Batch  (None, 16, 16, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 16, 16, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_395 (Batch  (None, 16, 16, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_396 (Batch  (None, 16, 16, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_390 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_392[0][0]']
#
#  activation_393 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_395[0][0]']
#
#  activation_394 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_396[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_400 (Batch  (None, 16, 16, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#  activation_398 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_400[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_398 (Batch  (None, 16, 16, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 16, 16, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_398[0][0]']
#
#  activation_399 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_401[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 16, 16, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_397 (Batch  (None, 16, 16, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 16, 16, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_402 (Batch  (None, 16, 16, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_403 (Batch  (None, 16, 16, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_397 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_399[0][0]']
#
#  activation_400 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_402[0][0]']
#
#  activation_401 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_403[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_405 (Batch  (None, 16, 16, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_405[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_406 (Batch  (None, 16, 16, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_406[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 7, 7, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_404[0][0]']
#
#  batch_normalization_404 (Batch  (None, 7, 7, 384)   1152        ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_407 (Batch  (None, 7, 7, 96)    288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 7, 7, 384)    0           ['batch_normalization_404[0][0]']
#
#  activation_405 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_407[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 7, 7, 288)   0           ['mixed2[0][0]']
#  )
#  mixed3 (Concatenate)           (None, 7, 7, 768)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_21[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_412 (Batch  (None, 7, 7, 128)   384         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_410[0][0]']
#
#  batch_normalization_413 (Batch  (None, 7, 7, 128)   384         ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_413[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_411[0][0]']
#
#  batch_normalization_409 (Batch  (None, 7, 7, 128)   384         ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 7, 7, 128)   384         ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_409[0][0]']
#
#  activation_412 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_414[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_412[0][0]']
#
#  batch_normalization_410 (Batch  (None, 7, 7, 128)   384         ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 7, 7, 128)   384         ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_410[0][0]']
#
#  activation_413 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_415[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 7, 7, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_408 (Batch  (None, 7, 7, 192)   576         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_411 (Batch  (None, 7, 7, 192)   576         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 7, 7, 192)   576         ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 7, 7, 192)   576         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_408[0][0]']
#
#  activation_409 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_411[0][0]']
#
#  activation_414 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_416[0][0]']
#
#  activation_415 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_417[0][0]']
#
#  mixed4 (Concatenate)           (None, 7, 7, 768)    0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_422 (Batch  (None, 7, 7, 160)   480         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_422[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_420[0][0]']
#
#  batch_normalization_423 (Batch  (None, 7, 7, 160)   480         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_423[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 7, 7, 160)   480         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 7, 7, 160)   480         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_424[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_422[0][0]']
#
#  batch_normalization_420 (Batch  (None, 7, 7, 160)   480         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 7, 7, 160)   480         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_425[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 7, 7, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_418 (Batch  (None, 7, 7, 192)   576         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_421 (Batch  (None, 7, 7, 192)   576         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 7, 7, 192)   576         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_427 (Batch  (None, 7, 7, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_418[0][0]']
#
#  activation_419 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_421[0][0]']
#
#  activation_424 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_426[0][0]']
#
#  activation_425 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_427[0][0]']
#
#  mixed5 (Concatenate)           (None, 7, 7, 768)    0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_432 (Batch  (None, 7, 7, 160)   480         ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_432[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_430[0][0]']
#
#  batch_normalization_433 (Batch  (None, 7, 7, 160)   480         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_433[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_431[0][0]']
#
#  batch_normalization_429 (Batch  (None, 7, 7, 160)   480         ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 7, 7, 160)   480         ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_429[0][0]']
#
#  activation_432 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_434[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_432[0][0]']
#
#  batch_normalization_430 (Batch  (None, 7, 7, 160)   480         ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 7, 7, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_430[0][0]']
#
#  activation_433 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_435[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 7, 7, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_428 (Batch  (None, 7, 7, 192)   576         ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 7, 7, 192)   576         ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_436 (Batch  (None, 7, 7, 192)   576         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_437 (Batch  (None, 7, 7, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_428[0][0]']
#
#  activation_429 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_436[0][0]']
#
#  activation_435 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_437[0][0]']
#
#  mixed6 (Concatenate)           (None, 7, 7, 768)    0           ['activation_426[0][0]',
#                                                                   'activation_429[0][0]',
#                                                                   'activation_434[0][0]',
#                                                                   'activation_435[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed6[0][0]']
# ...
#  Normalization)
#
#  activation_456 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_458[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 3, 3, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_455 (Batch  (None, 3, 3, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 3, 3, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_457 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_459[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 3, 3, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 3, 3, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_456 (Batch  (None, 3, 3, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 3, 3, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_460 (Batch  (None, 3, 3, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_461 (Batch  (None, 3, 3, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 3, 3, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_454 (Batch  (None, 3, 3, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_456[0][0]']
#
#  activation_455 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_457[0][0]']
#
#  activation_458 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_460[0][0]']
#
#  activation_459 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_461[0][0]']
#
#  batch_normalization_462 (Batch  (None, 3, 3, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_454[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 3, 3, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 3, 3, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_462[0][0]']
#
#  mixed9 (Concatenate)           (None, 3, 3, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 3, 3, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_467 (Batch  (None, 3, 3, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_467[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 3, 3, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_464 (Batch  (None, 3, 3, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 3, 3, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_466 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_468[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 3, 3, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 3, 3, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 3, 3, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 3, 3, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_469 (Batch  (None, 3, 3, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_470 (Batch  (None, 3, 3, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 3, 3, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_463 (Batch  (None, 3, 3, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_465[0][0]']
#
#  activation_464 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_466[0][0]']
#
#  activation_467 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_469[0][0]']
#
#  activation_468 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_470[0][0]']
#
#  batch_normalization_471 (Batch  (None, 3, 3, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_463[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 3, 3, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 3, 3, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_471[0][0]']
#
#  mixed10 (Concatenate)          (None, 3, 3, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
#  flatten_5 (Flatten)            (None, 18432)        0           ['mixed10[0][0]']
#
#  dense_42 (Dense)               (None, 1024)         18875392    ['flatten_5[0][0]']
#
#  dropout_23 (Dropout)           (None, 1024)         0           ['dense_42[0][0]']
#
#  dense_43 (Dense)               (None, 1)            1025        ['dropout_23[0][0]']
#
# ==================================================================================================
# Total params: 40,679,201
# Trainable params: 18,876,417
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
rms = RMSprop(learning_rate=1e-4)

inception_model.compile(optimizer=rms, loss='binary_crossentropy', metrics=['acc'])
inception.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 74, 74, 32)   864         ['input_7[0][0]']
#
#  batch_normalization_378 (Batch  (None, 74, 74, 32)  96          ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_376 (Activation)    (None, 74, 74, 32)   0           ['batch_normalization_378[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 72, 72, 32)   9216        ['activation_376[0][0]']
#
#  batch_normalization_379 (Batch  (None, 72, 72, 32)  96          ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 72, 72, 32)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 72, 72, 64)   18432       ['activation_377[0][0]']
#
#  batch_normalization_380 (Batch  (None, 72, 72, 64)  192         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 35, 35, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 35, 35, 80)   5120        ['max_pooling2d_19[0][0]']
#
#  batch_normalization_381 (Batch  (None, 35, 35, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 35, 35, 80)   0           ['batch_normalization_381[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 33, 33, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_382 (Batch  (None, 33, 33, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 33, 33, 192)  0           ['batch_normalization_382[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 16, 16, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_386 (Batch  (None, 16, 16, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_386[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 16, 16, 48)   9216        ['max_pooling2d_20[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_384 (Batch  (None, 16, 16, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 16, 16, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_384[0][0]']
#
#  activation_385 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_387[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 16, 16, 192)  0          ['max_pooling2d_20[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 16, 16, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_383 (Batch  (None, 16, 16, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 16, 16, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_388 (Batch  (None, 16, 16, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_389 (Batch  (None, 16, 16, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_383 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_385[0][0]']
#
#  activation_386 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_388[0][0]']
#
#  activation_387 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_389[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_393 (Batch  (None, 16, 16, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_393[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_391 (Batch  (None, 16, 16, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 16, 16, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_391[0][0]']
#
#  activation_392 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_394[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 16, 16, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_390 (Batch  (None, 16, 16, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 16, 16, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_395 (Batch  (None, 16, 16, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_396 (Batch  (None, 16, 16, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_390 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_392[0][0]']
#
#  activation_393 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_395[0][0]']
#
#  activation_394 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_396[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_400 (Batch  (None, 16, 16, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#  activation_398 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_400[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_398 (Batch  (None, 16, 16, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 16, 16, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_398[0][0]']
#
#  activation_399 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_401[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 16, 16, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_397 (Batch  (None, 16, 16, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 16, 16, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_402 (Batch  (None, 16, 16, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_403 (Batch  (None, 16, 16, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_397 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_399[0][0]']
#
#  activation_400 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_402[0][0]']
#
#  activation_401 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_403[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_405 (Batch  (None, 16, 16, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_405[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_406 (Batch  (None, 16, 16, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_406[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 7, 7, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_404[0][0]']
#
#  batch_normalization_404 (Batch  (None, 7, 7, 384)   1152        ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_407 (Batch  (None, 7, 7, 96)    288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 7, 7, 384)    0           ['batch_normalization_404[0][0]']
#
#  activation_405 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_407[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 7, 7, 288)   0           ['mixed2[0][0]']
#  )
#  mixed3 (Concatenate)           (None, 7, 7, 768)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_21[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_412 (Batch  (None, 7, 7, 128)   384         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_410[0][0]']
#
#  batch_normalization_413 (Batch  (None, 7, 7, 128)   384         ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_413[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_411[0][0]']
#
#  batch_normalization_409 (Batch  (None, 7, 7, 128)   384         ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 7, 7, 128)   384         ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_409[0][0]']
#
#  activation_412 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_414[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_412[0][0]']
#
#  batch_normalization_410 (Batch  (None, 7, 7, 128)   384         ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 7, 7, 128)   384         ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_410[0][0]']
#
#  activation_413 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_415[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 7, 7, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_408 (Batch  (None, 7, 7, 192)   576         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_411 (Batch  (None, 7, 7, 192)   576         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 7, 7, 192)   576         ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 7, 7, 192)   576         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_408[0][0]']
#
#  activation_409 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_411[0][0]']
#
#  activation_414 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_416[0][0]']
#
#  activation_415 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_417[0][0]']
#
#  mixed4 (Concatenate)           (None, 7, 7, 768)    0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_422 (Batch  (None, 7, 7, 160)   480         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_422[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_420[0][0]']
#
#  batch_normalization_423 (Batch  (None, 7, 7, 160)   480         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_423[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 7, 7, 160)   480         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 7, 7, 160)   480         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_424[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_422[0][0]']
#
#  batch_normalization_420 (Batch  (None, 7, 7, 160)   480         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 7, 7, 160)   480         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_425[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 7, 7, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_418 (Batch  (None, 7, 7, 192)   576         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_421 (Batch  (None, 7, 7, 192)   576         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 7, 7, 192)   576         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_427 (Batch  (None, 7, 7, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_418[0][0]']
#
#  activation_419 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_421[0][0]']
#
#  activation_424 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_426[0][0]']
#
#  activation_425 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_427[0][0]']
#
#  mixed5 (Concatenate)           (None, 7, 7, 768)    0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_432 (Batch  (None, 7, 7, 160)   480         ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_432[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_430[0][0]']
#
#  batch_normalization_433 (Batch  (None, 7, 7, 160)   480         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_433[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_431[0][0]']
#
#  batch_normalization_429 (Batch  (None, 7, 7, 160)   480         ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 7, 7, 160)   480         ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_429[0][0]']
#
#  activation_432 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_434[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_432[0][0]']
#
#  batch_normalization_430 (Batch  (None, 7, 7, 160)   480         ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 7, 7, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_430[0][0]']
#
#  activation_433 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_435[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 7, 7, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_428 (Batch  (None, 7, 7, 192)   576         ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 7, 7, 192)   576         ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_436 (Batch  (None, 7, 7, 192)   576         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_437 (Batch  (None, 7, 7, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_428[0][0]']
#
#  activation_429 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_436[0][0]']
#
#  activation_435 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_437[0][0]']
#
#  mixed6 (Concatenate)           (None, 7, 7, 768)    0           ['activation_426[0][0]',
#                                                                   'activation_429[0][0]',
#                                                                   'activation_434[0][0]',
#                                                                   'activation_435[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed6[0][0]']
# ...
#
#  mixed8 (Concatenate)           (None, 3, 3, 1280)   0           ['activation_447[0][0]',
#                                                                   'activation_451[0][0]',
#                                                                   'max_pooling2d_22[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 3, 3, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_458 (Batch  (None, 3, 3, 448)   1344        ['conv2d_456[0][0]']
#  Normalization)
#
#  activation_456 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_458[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 3, 3, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_455 (Batch  (None, 3, 3, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 3, 3, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_457 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_459[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 3, 3, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 3, 3, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_456 (Batch  (None, 3, 3, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 3, 3, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_460 (Batch  (None, 3, 3, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_461 (Batch  (None, 3, 3, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 3, 3, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_454 (Batch  (None, 3, 3, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_456[0][0]']
#
#  activation_455 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_457[0][0]']
#
#  activation_458 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_460[0][0]']
#
#  activation_459 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_461[0][0]']
#
#  batch_normalization_462 (Batch  (None, 3, 3, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_454[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 3, 3, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 3, 3, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_462[0][0]']
#
#  mixed9 (Concatenate)           (None, 3, 3, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 3, 3, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_467 (Batch  (None, 3, 3, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_467[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 3, 3, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_464 (Batch  (None, 3, 3, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 3, 3, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_466 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_468[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 3, 3, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 3, 3, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 3, 3, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 3, 3, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_469 (Batch  (None, 3, 3, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_470 (Batch  (None, 3, 3, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 3, 3, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_463 (Batch  (None, 3, 3, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_465[0][0]']
#
#  activation_464 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_466[0][0]']
#
#  activation_467 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_469[0][0]']
#
#  activation_468 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_470[0][0]']
#
#  batch_normalization_471 (Batch  (None, 3, 3, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_463[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 3, 3, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 3, 3, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_471[0][0]']
#
#  mixed10 (Concatenate)          (None, 3, 3, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor ="val_loss", patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/inception-rms-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
inception3_history = inception_model.fit(X_train, y_train, validation_data=(
    X_val, y_val), epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 39/39 [==============================] - ETA: 0s - loss: 144.3097 - acc: 0.5182
# Epoch 1: saving model to ../weights\inception-rms-model-01.h5
# 39/39 [==============================] - 8s 89ms/step - loss: 144.3097 - acc: 0.5182 - val_loss: 43.0578 - val_acc: 0.5472
# Epoch 2/50
# 39/39 [==============================] - ETA: 0s - loss: 80.3474 - acc: 0.5222
# Epoch 2: saving model to ../weights\inception-rms-model-02.h5
# 39/39 [==============================] - 2s 61ms/step - loss: 80.3474 - acc: 0.5222 - val_loss: 23.0609 - val_acc: 0.5690
# Epoch 3/50
# 39/39 [==============================] - ETA: 0s - loss: 56.0170 - acc: 0.5230
# Epoch 3: saving model to ../weights\inception-rms-model-03.h5
# 39/39 [==============================] - 2s 63ms/step - loss: 56.0170 - acc: 0.5230 - val_loss: 59.5204 - val_acc: 0.4552
# Epoch 4/50
# 38/39 [============================>.] - ETA: 0s - loss: 32.5195 - acc: 0.5370
# Epoch 4: saving model to ../weights\inception-rms-model-04.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 32.2723 - acc: 0.5360 - val_loss: 3.3753 - val_acc: 0.6949
# Epoch 5/50
# 38/39 [============================>.] - ETA: 0s - loss: 12.5558 - acc: 0.5329
# Epoch 5: saving model to ../weights\inception-rms-model-05.h5
# 39/39 [==============================] - 2s 61ms/step - loss: 12.5310 - acc: 0.5303 - val_loss: 0.8781 - val_acc: 0.6247
# Epoch 6/50
# 39/39 [==============================] - ETA: 0s - loss: 1.7132 - acc: 0.5473
# Epoch 6: saving model to ../weights\inception-rms-model-06.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 1.7132 - acc: 0.5473 - val_loss: 0.7059 - val_acc: 0.4673
# Epoch 7/50
# 39/39 [==============================] - ETA: 0s - loss: 1.1644 - acc: 0.5303
# Epoch 7: saving model to ../weights\inception-rms-model-07.h5
# 39/39 [==============================] - 2s 61ms/step - loss: 1.1644 - acc: 0.5303 - val_loss: 0.8073 - val_acc: 0.4794
# Epoch 8/50
# 39/39 [==============================] - ETA: 0s - loss: 1.3859 - acc: 0.5190
# Epoch 8: saving model to ../weights\inception-rms-model-08.h5
# 39/39 [==============================] - 2s 63ms/step - loss: 1.3859 - acc: 0.5190 - val_loss: 0.6699 - val_acc: 0.5617
# Epoch 9/50
# 39/39 [==============================] - ETA: 0s - loss: 0.8556 - acc: 0.5044
# Epoch 9: saving model to ../weights\inception-rms-model-09.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.8556 - acc: 0.5044 - val_loss: 0.6964 - val_acc: 0.4600
# Epoch 10/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.8579 - acc: 0.5296
# Epoch 10: saving model to ../weights\inception-rms-model-10.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.8549 - acc: 0.5311 - val_loss: 0.6716 - val_acc: 0.5835
# Epoch 11/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.7001 - acc: 0.5115
# Epoch 11: saving model to ../weights\inception-rms-model-11.h5
# 39/39 [==============================] - 2s 63ms/step - loss: 0.6997 - acc: 0.5117 - val_loss: 0.8328 - val_acc: 0.4552
# Epoch 11: early stopping

# %%
plot_history(inception3_history)
# Out:
# Train Loss:  0.6997246742248535
# Validation Loss:  0.8327557444572449
# Train Accuracy:  0.5117219090461731
# Validation Accuracy:  0.4552057981491089

# %%
preds = inception_model.predict(X_test)
pred_labels = []

# %%
# threshold is 0.5
for p in preds:
    if p >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
pred_labels = np.array(pred_labels)

# %%
print('Accuracy on test dataset: {}'.format(
    accuracy_score(y_test, pred_labels)))
# Out:
# Accuracy on test dataset: 0.5109090909090909

# %%
callbacks = [
    EarlyStopping(monitor ="val_loss", patience=3, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
        '../weights/inception-rms-model-{epoch:02d}.h5', verbose=1, restore_best_weights=True)
]

# %%
rms = RMSprop(learning_rate=1e-5)

inception_model.compile(optimizer=rms, loss='binary_crossentropy', metrics=['acc'])
inception.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 74, 74, 32)   864         ['input_7[0][0]']
#
#  batch_normalization_378 (Batch  (None, 74, 74, 32)  96          ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_376 (Activation)    (None, 74, 74, 32)   0           ['batch_normalization_378[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 72, 72, 32)   9216        ['activation_376[0][0]']
#
#  batch_normalization_379 (Batch  (None, 72, 72, 32)  96          ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 72, 72, 32)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 72, 72, 64)   18432       ['activation_377[0][0]']
#
#  batch_normalization_380 (Batch  (None, 72, 72, 64)  192         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 35, 35, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 35, 35, 80)   5120        ['max_pooling2d_19[0][0]']
#
#  batch_normalization_381 (Batch  (None, 35, 35, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 35, 35, 80)   0           ['batch_normalization_381[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 33, 33, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_382 (Batch  (None, 33, 33, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 33, 33, 192)  0           ['batch_normalization_382[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 16, 16, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_386 (Batch  (None, 16, 16, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_386[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 16, 16, 48)   9216        ['max_pooling2d_20[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_384 (Batch  (None, 16, 16, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 16, 16, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_384[0][0]']
#
#  activation_385 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_387[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 16, 16, 192)  0          ['max_pooling2d_20[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_20[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 16, 16, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_383 (Batch  (None, 16, 16, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 16, 16, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_388 (Batch  (None, 16, 16, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_389 (Batch  (None, 16, 16, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_383 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_385[0][0]']
#
#  activation_386 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_388[0][0]']
#
#  activation_387 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_389[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_393 (Batch  (None, 16, 16, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_393[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_391 (Batch  (None, 16, 16, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 16, 16, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_391[0][0]']
#
#  activation_392 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_394[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 16, 16, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_390 (Batch  (None, 16, 16, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 16, 16, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_395 (Batch  (None, 16, 16, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_396 (Batch  (None, 16, 16, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_390 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_392[0][0]']
#
#  activation_393 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_395[0][0]']
#
#  activation_394 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_396[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_400 (Batch  (None, 16, 16, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#  activation_398 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_400[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_398 (Batch  (None, 16, 16, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 16, 16, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_398[0][0]']
#
#  activation_399 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_401[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 16, 16, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_397 (Batch  (None, 16, 16, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 16, 16, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_402 (Batch  (None, 16, 16, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_403 (Batch  (None, 16, 16, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_397 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_399[0][0]']
#
#  activation_400 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_402[0][0]']
#
#  activation_401 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_403[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_405 (Batch  (None, 16, 16, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_405[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_406 (Batch  (None, 16, 16, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_406[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 7, 7, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_404[0][0]']
#
#  batch_normalization_404 (Batch  (None, 7, 7, 384)   1152        ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_407 (Batch  (None, 7, 7, 96)    288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 7, 7, 384)    0           ['batch_normalization_404[0][0]']
#
#  activation_405 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_407[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 7, 7, 288)   0           ['mixed2[0][0]']
#  )
#  mixed3 (Concatenate)           (None, 7, 7, 768)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_21[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_412 (Batch  (None, 7, 7, 128)   384         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_410[0][0]']
#
#  batch_normalization_413 (Batch  (None, 7, 7, 128)   384         ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_413[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_411[0][0]']
#
#  batch_normalization_409 (Batch  (None, 7, 7, 128)   384         ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 7, 7, 128)   384         ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_409[0][0]']
#
#  activation_412 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_414[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_412[0][0]']
#
#  batch_normalization_410 (Batch  (None, 7, 7, 128)   384         ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 7, 7, 128)   384         ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_410[0][0]']
#
#  activation_413 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_415[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 7, 7, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_408 (Batch  (None, 7, 7, 192)   576         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_411 (Batch  (None, 7, 7, 192)   576         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 7, 7, 192)   576         ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 7, 7, 192)   576         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_408[0][0]']
#
#  activation_409 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_411[0][0]']
#
#  activation_414 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_416[0][0]']
#
#  activation_415 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_417[0][0]']
#
#  mixed4 (Concatenate)           (None, 7, 7, 768)    0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_422 (Batch  (None, 7, 7, 160)   480         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_422[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_420[0][0]']
#
#  batch_normalization_423 (Batch  (None, 7, 7, 160)   480         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_423[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 7, 7, 160)   480         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 7, 7, 160)   480         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_424[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_422[0][0]']
#
#  batch_normalization_420 (Batch  (None, 7, 7, 160)   480         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 7, 7, 160)   480         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_425[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 7, 7, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_418 (Batch  (None, 7, 7, 192)   576         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_421 (Batch  (None, 7, 7, 192)   576         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 7, 7, 192)   576         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_427 (Batch  (None, 7, 7, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_418[0][0]']
#
#  activation_419 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_421[0][0]']
#
#  activation_424 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_426[0][0]']
#
#  activation_425 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_427[0][0]']
#
#  mixed5 (Concatenate)           (None, 7, 7, 768)    0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_432 (Batch  (None, 7, 7, 160)   480         ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_432[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_430[0][0]']
#
#  batch_normalization_433 (Batch  (None, 7, 7, 160)   480         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_433[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_431[0][0]']
#
#  batch_normalization_429 (Batch  (None, 7, 7, 160)   480         ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 7, 7, 160)   480         ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_429[0][0]']
#
#  activation_432 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_434[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_432[0][0]']
#
#  batch_normalization_430 (Batch  (None, 7, 7, 160)   480         ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 7, 7, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_430[0][0]']
#
#  activation_433 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_435[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 7, 7, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_428 (Batch  (None, 7, 7, 192)   576         ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 7, 7, 192)   576         ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_436 (Batch  (None, 7, 7, 192)   576         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_437 (Batch  (None, 7, 7, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_428[0][0]']
#
#  activation_429 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_436[0][0]']
#
#  activation_435 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_437[0][0]']
#
#  mixed6 (Concatenate)           (None, 7, 7, 768)    0           ['activation_426[0][0]',
#                                                                   'activation_429[0][0]',
#                                                                   'activation_434[0][0]',
#                                                                   'activation_435[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed6[0][0]']
# ...
#
#  mixed8 (Concatenate)           (None, 3, 3, 1280)   0           ['activation_447[0][0]',
#                                                                   'activation_451[0][0]',
#                                                                   'max_pooling2d_22[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 3, 3, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_458 (Batch  (None, 3, 3, 448)   1344        ['conv2d_456[0][0]']
#  Normalization)
#
#  activation_456 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_458[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 3, 3, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_455 (Batch  (None, 3, 3, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 3, 3, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_457 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_459[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 3, 3, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 3, 3, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_456 (Batch  (None, 3, 3, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 3, 3, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_460 (Batch  (None, 3, 3, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_461 (Batch  (None, 3, 3, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 3, 3, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_454 (Batch  (None, 3, 3, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_456[0][0]']
#
#  activation_455 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_457[0][0]']
#
#  activation_458 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_460[0][0]']
#
#  activation_459 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_461[0][0]']
#
#  batch_normalization_462 (Batch  (None, 3, 3, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_454[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 3, 3, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 3, 3, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_462[0][0]']
#
#  mixed9 (Concatenate)           (None, 3, 3, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 3, 3, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_467 (Batch  (None, 3, 3, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_467[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 3, 3, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_464 (Batch  (None, 3, 3, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 3, 3, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_466 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_468[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 3, 3, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 3, 3, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 3, 3, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 3, 3, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_469 (Batch  (None, 3, 3, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_470 (Batch  (None, 3, 3, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 3, 3, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_463 (Batch  (None, 3, 3, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_465[0][0]']
#
#  activation_464 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_466[0][0]']
#
#  activation_467 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_469[0][0]']
#
#  activation_468 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_470[0][0]']
#
#  batch_normalization_471 (Batch  (None, 3, 3, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_463[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 3, 3, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 3, 3, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_471[0][0]']
#
#  mixed10 (Concatenate)          (None, 3, 3, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
inception3_history = inception_model.fit(X_train, y_train, validation_data=(
    X_val, y_val), epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6600 - acc: 0.5913
# Epoch 1: saving model to ../weights\inception-rms-model-01.h5
# 39/39 [==============================] - 8s 110ms/step - loss: 0.6595 - acc: 0.5950 - val_loss: 0.6292 - val_acc: 0.6852
# Epoch 2/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6551 - acc: 0.6168
# Epoch 2: saving model to ../weights\inception-rms-model-02.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.6544 - acc: 0.6168 - val_loss: 0.6308 - val_acc: 0.6441
# Epoch 3/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6557 - acc: 0.5666
# Epoch 3: saving model to ../weights\inception-rms-model-03.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.6553 - acc: 0.5683 - val_loss: 0.6340 - val_acc: 0.6416
# Epoch 4/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6481 - acc: 0.5979
# Epoch 4: saving model to ../weights\inception-rms-model-04.h5
# 39/39 [==============================] - 2s 63ms/step - loss: 0.6479 - acc: 0.5982 - val_loss: 0.6162 - val_acc: 0.6925
# Epoch 5/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6425 - acc: 0.6209
# Epoch 5: saving model to ../weights\inception-rms-model-05.h5
# 39/39 [==============================] - 2s 63ms/step - loss: 0.6425 - acc: 0.6209 - val_loss: 0.6447 - val_acc: 0.6368
# Epoch 6/50
# 38/39 [============================>.] - ETA: 0s - loss: 0.6513 - acc: 0.6102
# Epoch 6: saving model to ../weights\inception-rms-model-06.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.6516 - acc: 0.6112 - val_loss: 0.6423 - val_acc: 0.6392
# Epoch 7/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6387 - acc: 0.6063
# Epoch 7: saving model to ../weights\inception-rms-model-07.h5
# 39/39 [==============================] - 2s 62ms/step - loss: 0.6387 - acc: 0.6063 - val_loss: 0.6291 - val_acc: 0.6755
# Epoch 7: early stopping

# %%
plot_history(inception3_history)
# Out:
# Train Loss:  0.6386943459510803
# Validation Loss:  0.6291314959526062
# Train Accuracy:  0.6063055992126465
# Validation Accuracy:  0.675544798374176

# %%
preds = inception_model.predict(X_test)
pred_labels = []

# %%
# threshold is 0.5
for p in preds:
    if p >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
pred_labels = np.array(pred_labels)

# %%
print('Accuracy on test dataset: {}'.format(
    accuracy_score(y_test, pred_labels)))
# Out:
# Accuracy on test dataset: 0.6454545454545455

# %% [markdown]
# #### Prediction on Test Dataset

# %%
preds = inception_model.predict(X_features)
pred_labels = []

# %%
# threshold is 0.5
for p in preds:
    if p >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
pred_labels = np.array(pred_labels)

# %%
print('Accuracy on test dataset: {}'.format(
    accuracy_score(y_labels, pred_labels)))
# Out:
# Accuracy on test dataset: 0.5
